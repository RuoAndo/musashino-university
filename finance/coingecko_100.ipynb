# %%
import time
import random
import requests
import pandas as pd
from datetime import datetime

VS = "usd"
DAYS = 90

BASE_LIST   = "https://api.coingecko.com/api/v3/coins/list"
BASE_CHART  = "https://api.coingecko.com/api/v3/coins/{id}/market_chart"

session = requests.Session()
session.headers.update({
    "User-Agent": "Mozilla/5.0 (compatible; stable-demo/1.0)"
})

# ===== 時刻表示関数 =====
def now():
    return datetime.now().strftime("%Y-%m-%d %H:%M:%S")

def fetch_all_coins():
    print(f"[{now()}] Start fetching full coin list ...")
    r = session.get(BASE_LIST, timeout=30)
    r.raise_for_status()
    print(f"[{now()}] Finished fetching coin list.")
    return r.json()

def fetch_market_chart(coin_id, days=90, vs="usd", max_retry=3):
    """指定コインの過去データ取得 (指数バックオフ)"""
    url = BASE_CHART.format(id=coin_id)
    params = {"vs_currency": vs, "days": days}

    for attempt in range(max_retry):
        print(f"[{now()}]   Request attempt {attempt+1} for {coin_id} ...")
        r = session.get(url, params=params, timeout=30)

        if r.status_code == 200:
            data = r.json()
            if "prices" not in data:
                raise RuntimeError(f"no 'prices' field: {coin_id}")
            df = pd.DataFrame(data["prices"], columns=["timestamp", "price"])
            df["timestamp"] = pd.to_datetime(df["timestamp"], unit="ms")
            return df

        if r.status_code == 429:
            wait_sec = 10 * (2 ** attempt)
            print(f"[{now()}]   429 received, waiting {wait_sec}s ...")
            time.sleep(wait_sec)
            continue

        r.raise_for_status()

    raise RuntimeError(f"Failed after retries: {coin_id}")

def main():
    start_time = time.time()
    print(f"\n[{now()}] ===== Program Started =====")

    # 1) 全銘柄リスト取得
    all_coins = fetch_all_coins()
    print(f"[{now()}] total coins available: {len(all_coins)}")

    # 2) ランダムに100銘柄を選択
    sample_n = 100
    coins_sampled = random.sample(all_coins, sample_n)

    for idx, coin in enumerate(coins_sampled, start=1):
        coin_id = coin["id"]
        symbol  = coin["symbol"]
        name    = coin["name"]

        print(f"\n[{now()}] === ({idx}/{sample_n}) Fetching {name} ({symbol}) id={coin_id} ===")

        try:
            df = fetch_market_chart(coin_id, DAYS, VS)
        except Exception as e:
            print(f"[{now()}]   -> error: {e}")
            continue

        # 保存ファイル名
        safe_symbol = symbol.upper()
        safe_id = coin_id.replace("/", "_")
        filename = f"{idx:03d}_{safe_symbol}_{safe_id}_last{DAYS}d_{VS}.csv"

        df.to_csv(filename, index=False)
        print(f"[{now()}]   -> saved: {filename}")

        # API制限対策：30秒待機
        print(f"[{now()}]   Waiting 30 seconds before next request...")
        time.sleep(30)

    end_time = time.time()
    minutes = (end_time - start_time) / 60
    print(f"\n[{now()}] ===== Program Finished =====")
    print(f"Total elapsed time: {minutes:.2f} minutes")

if __name__ == "__main__":
    main()
# Out:
# [2026-02-28 10:01:16] ===== Program Started =====
# [2026-02-28 10:01:16] Start fetching full coin list ...
# [2026-02-28 10:01:17] Finished fetching coin list.
# [2026-02-28 10:01:17] total coins available: 18742
#
# [2026-02-28 10:01:17] === (1/100) Fetching The Giraffes (giraffes) id=the-giraffes ===
# [2026-02-28 10:01:17]   Request attempt 1 for the-giraffes ...
# [2026-02-28 10:01:18]   -> saved: 001_GIRAFFES_the-giraffes_last90d_usd.csv
# [2026-02-28 10:01:18]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:01:48] === (2/100) Fetching REKT (rekt) id=rekt-04bbe51a-e290-450a-afb5-b2b43b80b20e ===
# [2026-02-28 10:01:48]   Request attempt 1 for rekt-04bbe51a-e290-450a-afb5-b2b43b80b20e ...
# [2026-02-28 10:01:49]   -> saved: 002_REKT_rekt-04bbe51a-e290-450a-afb5-b2b43b80b20e_last90d_usd.csv
# [2026-02-28 10:01:49]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:02:19] === (3/100) Fetching Alanyaspor Fan Token (ala) id=alanyaspor-fan-token ===
# [2026-02-28 10:02:19]   Request attempt 1 for alanyaspor-fan-token ...
# [2026-02-28 10:02:22]   -> saved: 003_ALA_alanyaspor-fan-token_last90d_usd.csv
# [2026-02-28 10:02:22]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:02:52] === (4/100) Fetching Xend Finance (rwa) id=xend-finance ===
# [2026-02-28 10:02:52]   Request attempt 1 for xend-finance ...
# [2026-02-28 10:02:54]   -> saved: 004_RWA_xend-finance_last90d_usd.csv
# [2026-02-28 10:02:54]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:03:24] === (5/100) Fetching Gakster (gak) id=gakster ===
# [2026-02-28 10:03:24]   Request attempt 1 for gakster ...
# [2026-02-28 10:03:27]   -> saved: 005_GAK_gakster_last90d_usd.csv
# [2026-02-28 10:03:27]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:03:57] === (6/100) Fetching Contango (tango) id=contango ===
# [2026-02-28 10:03:57]   Request attempt 1 for contango ...
# [2026-02-28 10:03:59]   -> saved: 006_TANGO_contango_last90d_usd.csv
# [2026-02-28 10:03:59]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:04:29] === (7/100) Fetching Gauntlet USD Alpha (gtusda) id=gauntlet-usd-alpha ===
# [2026-02-28 10:04:29]   Request attempt 1 for gauntlet-usd-alpha ...
# [2026-02-28 10:04:29]   -> saved: 007_GTUSDA_gauntlet-usd-alpha_last90d_usd.csv
# [2026-02-28 10:04:29]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:04:59] === (8/100) Fetching Flork ($flork) id=flork ===
# [2026-02-28 10:04:59]   Request attempt 1 for flork ...
# [2026-02-28 10:05:00]   -> saved: 008_$FLORK_flork_last90d_usd.csv
# [2026-02-28 10:05:00]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:05:30] === (9/100) Fetching Karmaverse (knot) id=karmaverse ===
# [2026-02-28 10:05:30]   Request attempt 1 for karmaverse ...
# [2026-02-28 10:05:32]   -> saved: 009_KNOT_karmaverse_last90d_usd.csv
# [2026-02-28 10:05:32]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:06:02] === (10/100) Fetching Ratecoin (rate) id=ratecoin-2 ===
# [2026-02-28 10:06:02]   Request attempt 1 for ratecoin-2 ...
# [2026-02-28 10:06:02]   -> saved: 010_RATE_ratecoin-2_last90d_usd.csv
# [2026-02-28 10:06:02]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:06:32] === (11/100) Fetching TRON (BSC) (trx) id=tron-bsc ===
# [2026-02-28 10:06:32]   Request attempt 1 for tron-bsc ...
# [2026-02-28 10:06:34]   -> saved: 011_TRX_tron-bsc_last90d_usd.csv
# [2026-02-28 10:06:34]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:07:04] === (12/100) Fetching VCW (vcw) id=vcw ===
# [2026-02-28 10:07:04]   Request attempt 1 for vcw ...
# [2026-02-28 10:07:05]   -> saved: 012_VCW_vcw_last90d_usd.csv
# [2026-02-28 10:07:05]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:07:35] === (13/100) Fetching Dinari SBUX (sbux.d) id=dinari-sbux ===
# [2026-02-28 10:07:35]   Request attempt 1 for dinari-sbux ...
# [2026-02-28 10:07:35]   -> saved: 013_SBUX.D_dinari-sbux_last90d_usd.csv
# [2026-02-28 10:07:35]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:08:05] === (14/100) Fetching KoinBay Token (kbt) id=koinbay-token ===
# [2026-02-28 10:08:05]   Request attempt 1 for koinbay-token ...
# [2026-02-28 10:08:06]   -> saved: 014_KBT_koinbay-token_last90d_usd.csv
# [2026-02-28 10:08:06]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:08:36] === (15/100) Fetching Broccoli The Gangsta (broc) id=broccoli-the-gangsta ===
# [2026-02-28 10:08:36]   Request attempt 1 for broccoli-the-gangsta ...
# [2026-02-28 10:08:36]   -> saved: 015_BROC_broccoli-the-gangsta_last90d_usd.csv
# [2026-02-28 10:08:36]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:09:06] === (16/100) Fetching Nailong (nailong) id=nailong ===
# [2026-02-28 10:09:06]   Request attempt 1 for nailong ...
# [2026-02-28 10:09:09]   -> saved: 016_NAILONG_nailong_last90d_usd.csv
# [2026-02-28 10:09:09]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:09:39] === (17/100) Fetching Liquidswap (lsd) id=liquidswap-2 ===
# [2026-02-28 10:09:39]   Request attempt 1 for liquidswap-2 ...
# [2026-02-28 10:09:39]   -> saved: 017_LSD_liquidswap-2_last90d_usd.csv
# [2026-02-28 10:09:39]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:10:09] === (18/100) Fetching Nexus Credit System (ncrs) id=nexus-credit-system ===
# [2026-02-28 10:10:09]   Request attempt 1 for nexus-credit-system ...
# [2026-02-28 10:10:09]   -> saved: 018_NCRS_nexus-credit-system_last90d_usd.csv
# [2026-02-28 10:10:09]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:10:39] === (19/100) Fetching Gauntlet USDC PRIME V2 (gtusdcp) id=gauntlet-usdc-prime ===
# [2026-02-28 10:10:39]   Request attempt 1 for gauntlet-usdc-prime ...
# [2026-02-28 10:10:40]   -> saved: 019_GTUSDCP_gauntlet-usdc-prime_last90d_usd.csv
# [2026-02-28 10:10:40]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:11:10] === (20/100) Fetching Law of Attraction (loa) id=law-of-attraction-2 ===
# [2026-02-28 10:11:10]   Request attempt 1 for law-of-attraction-2 ...
# [2026-02-28 10:11:12]   -> saved: 020_LOA_law-of-attraction-2_last90d_usd.csv
# [2026-02-28 10:11:12]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:11:42] === (21/100) Fetching Itheum (itheum) id=itheum ===
# [2026-02-28 10:11:42]   Request attempt 1 for itheum ...
# [2026-02-28 10:11:43]   -> saved: 021_ITHEUM_itheum_last90d_usd.csv
# [2026-02-28 10:11:43]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:12:13] === (22/100) Fetching Aurora (aurora) id=aurora-near ===
# [2026-02-28 10:12:13]   Request attempt 1 for aurora-near ...
# [2026-02-28 10:12:15]   -> saved: 022_AURORA_aurora-near_last90d_usd.csv
# [2026-02-28 10:12:15]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:12:45] === (23/100) Fetching Whale (whale) id=whale-3 ===
# [2026-02-28 10:12:45]   Request attempt 1 for whale-3 ...
# [2026-02-28 10:12:46]   -> saved: 023_WHALE_whale-3_last90d_usd.csv
# [2026-02-28 10:12:46]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:13:16] === (24/100) Fetching Revest Finance (rvst) id=revest-finance ===
# [2026-02-28 10:13:16]   Request attempt 1 for revest-finance ...
# [2026-02-28 10:13:18]   -> saved: 024_RVST_revest-finance_last90d_usd.csv
# [2026-02-28 10:13:18]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:13:48] === (25/100) Fetching Dominion (dom) id=dominion ===
# [2026-02-28 10:13:48]   Request attempt 1 for dominion ...
# [2026-02-28 10:13:49]   -> saved: 025_DOM_dominion_last90d_usd.csv
# [2026-02-28 10:13:49]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:14:19] === (26/100) Fetching Polar Inu (polar) id=polar-inu ===
# [2026-02-28 10:14:19]   Request attempt 1 for polar-inu ...
# [2026-02-28 10:14:20]   -> saved: 026_POLAR_polar-inu_last90d_usd.csv
# [2026-02-28 10:14:20]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:14:50] === (27/100) Fetching Bonk 2.0 (bonk 2.0) id=bonk-2-0 ===
# [2026-02-28 10:14:50]   Request attempt 1 for bonk-2-0 ...
# [2026-02-28 10:14:50]   -> saved: 027_BONK 2.0_bonk-2-0_last90d_usd.csv
# [2026-02-28 10:14:50]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:15:20] === (28/100) Fetching INFINITY (infinity) id=infinity-3 ===
# [2026-02-28 10:15:20]   Request attempt 1 for infinity-3 ...
# [2026-02-28 10:15:21]   -> saved: 028_INFINITY_infinity-3_last90d_usd.csv
# [2026-02-28 10:15:21]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:15:51] === (29/100) Fetching Kyros Restaked JTO (kyjto) id=kyros-restaked-jto ===
# [2026-02-28 10:15:51]   Request attempt 1 for kyros-restaked-jto ...
# [2026-02-28 10:15:51]   -> saved: 029_KYJTO_kyros-restaked-jto_last90d_usd.csv
# [2026-02-28 10:15:51]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:16:21] === (30/100) Fetching Nyan Cat (nyan) id=nyan-cat-2 ===
# [2026-02-28 10:16:21]   Request attempt 1 for nyan-cat-2 ...
# [2026-02-28 10:16:21]   -> saved: 030_NYAN_nyan-cat-2_last90d_usd.csv
# [2026-02-28 10:16:21]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:16:51] === (31/100) Fetching DogKing On XLayer (dogking) id=dogking-on-xlayer ===
# [2026-02-28 10:16:51]   Request attempt 1 for dogking-on-xlayer ...
# [2026-02-28 10:16:52]   -> saved: 031_DOGKING_dogking-on-xlayer_last90d_usd.csv
# [2026-02-28 10:16:52]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:17:22] === (32/100) Fetching ZetaChain Bridged USDT.BSC (ZetaChain) (usdt.bsc) id=zetachain-bridged-usdt-bsc-zetachain ===
# [2026-02-28 10:17:22]   Request attempt 1 for zetachain-bridged-usdt-bsc-zetachain ...
# [2026-02-28 10:17:25]   -> saved: 032_USDT.BSC_zetachain-bridged-usdt-bsc-zetachain_last90d_usd.csv
# [2026-02-28 10:17:25]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:17:55] === (33/100) Fetching IMGN Labs (imgn) id=imgn-labs ===
# [2026-02-28 10:17:55]   Request attempt 1 for imgn-labs ...
# [2026-02-28 10:17:57]   -> saved: 033_IMGN_imgn-labs_last90d_usd.csv
# [2026-02-28 10:17:57]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:18:27] === (34/100) Fetching Layer One X (l1x) id=layer-one-x-2 ===
# [2026-02-28 10:18:27]   Request attempt 1 for layer-one-x-2 ...
# [2026-02-28 10:18:29]   -> saved: 034_L1X_layer-one-x-2_last90d_usd.csv
# [2026-02-28 10:18:29]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:18:59] === (35/100) Fetching 21.co Wrapped AVAX (21avax) id=wrapped-avax-21-co ===
# [2026-02-28 10:18:59]   Request attempt 1 for wrapped-avax-21-co ...
# [2026-02-28 10:18:59]   -> saved: 035_21AVAX_wrapped-avax-21-co_last90d_usd.csv
# [2026-02-28 10:18:59]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:19:29] === (36/100) Fetching silver coin (silver) id=silver-coin-2 ===
# [2026-02-28 10:19:29]   Request attempt 1 for silver-coin-2 ...
# [2026-02-28 10:19:30]   -> saved: 036_SILVER_silver-coin-2_last90d_usd.csv
# [2026-02-28 10:19:30]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:20:00] === (37/100) Fetching SophiaVerse (soph) id=sophiaverse ===
# [2026-02-28 10:20:00]   Request attempt 1 for sophiaverse ...
# [2026-02-28 10:20:03]   -> saved: 037_SOPH_sophiaverse_last90d_usd.csv
# [2026-02-28 10:20:03]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:20:33] === (38/100) Fetching RIPS (rips) id=rips ===
# [2026-02-28 10:20:33]   Request attempt 1 for rips ...
# [2026-02-28 10:20:34]   -> saved: 038_RIPS_rips_last90d_usd.csv
# [2026-02-28 10:20:34]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:21:04] === (39/100) Fetching Just a pulse guy (pulseguy) id=just-a-pulse-guy ===
# [2026-02-28 10:21:04]   Request attempt 1 for just-a-pulse-guy ...
# [2026-02-28 10:21:06]   -> saved: 039_PULSEGUY_just-a-pulse-guy_last90d_usd.csv
# [2026-02-28 10:21:06]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:21:36] === (40/100) Fetching Co Bra (cobra) id=co-bra ===
# [2026-02-28 10:21:36]   Request attempt 1 for co-bra ...
# [2026-02-28 10:21:37]   -> saved: 040_COBRA_co-bra_last90d_usd.csv
# [2026-02-28 10:21:37]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:22:07] === (41/100) Fetching VitaRNA (vitarna) id=vitarna ===
# [2026-02-28 10:22:07]   Request attempt 1 for vitarna ...
# [2026-02-28 10:22:09]   -> saved: 041_VITARNA_vitarna_last90d_usd.csv
# [2026-02-28 10:22:09]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:22:39] === (42/100) Fetching Kogin by Virtuals (kogin) id=kogin-by-virtuals ===
# [2026-02-28 10:22:39]   Request attempt 1 for kogin-by-virtuals ...
# [2026-02-28 10:22:41]   -> saved: 042_KOGIN_kogin-by-virtuals_last90d_usd.csv
# [2026-02-28 10:22:41]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:23:11] === (43/100) Fetching Novastro (xnl) id=novas ===
# [2026-02-28 10:23:11]   Request attempt 1 for novas ...
# [2026-02-28 10:23:13]   -> saved: 043_XNL_novas_last90d_usd.csv
# [2026-02-28 10:23:13]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:23:43] === (44/100) Fetching Kollector (kltr) id=kollector ===
# [2026-02-28 10:23:43]   Request attempt 1 for kollector ...
# [2026-02-28 10:23:43]   -> saved: 044_KLTR_kollector_last90d_usd.csv
# [2026-02-28 10:23:43]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:24:13] === (45/100) Fetching Agentlauncher (cvai) id=agentlauncher-token-cvai ===
# [2026-02-28 10:24:13]   Request attempt 1 for agentlauncher-token-cvai ...
# [2026-02-28 10:24:16]   -> saved: 045_CVAI_agentlauncher-token-cvai_last90d_usd.csv
# [2026-02-28 10:24:16]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:24:46] === (46/100) Fetching edeXa (edx) id=edexa ===
# [2026-02-28 10:24:46]   Request attempt 1 for edexa ...
# [2026-02-28 10:24:48]   -> saved: 046_EDX_edexa_last90d_usd.csv
# [2026-02-28 10:24:48]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:25:18] === (47/100) Fetching LEON AI (leon) id=leon-ai ===
# [2026-02-28 10:25:18]   Request attempt 1 for leon-ai ...
# [2026-02-28 10:25:19]   -> saved: 047_LEON_leon-ai_last90d_usd.csv
# [2026-02-28 10:25:19]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:25:49] === (48/100) Fetching Big Back Bitcoin (bbbtc) id=big-back-bitcoin ===
# [2026-02-28 10:25:49]   Request attempt 1 for big-back-bitcoin ...
# [2026-02-28 10:25:51]   -> saved: 048_BBBTC_big-back-bitcoin_last90d_usd.csv
# [2026-02-28 10:25:51]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:26:21] === (49/100) Fetching Dinari SPUS (spus.d) id=dinari-spus ===
# [2026-02-28 10:26:21]   Request attempt 1 for dinari-spus ...
# [2026-02-28 10:26:21]   -> saved: 049_SPUS.D_dinari-spus_last90d_usd.csv
# [2026-02-28 10:26:21]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:26:51] === (50/100) Fetching MAGA Hat (maga) id=maga-hat ===
# [2026-02-28 10:26:51]   Request attempt 1 for maga-hat ...
# [2026-02-28 10:26:54]   -> saved: 050_MAGA_maga-hat_last90d_usd.csv
# [2026-02-28 10:26:54]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:27:24] === (51/100) Fetching DIVA Protocol (diva) id=diva-protocol ===
# [2026-02-28 10:27:24]   Request attempt 1 for diva-protocol ...
# [2026-02-28 10:27:25]   -> saved: 051_DIVA_diva-protocol_last90d_usd.csv
# [2026-02-28 10:27:25]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:27:55] === (52/100) Fetching Cipher Mining (Ondo Tokenized Stock) (cifron) id=cipher-mining-ondo-tokenized-stock ===
# [2026-02-28 10:27:55]   Request attempt 1 for cipher-mining-ondo-tokenized-stock ...
# [2026-02-28 10:27:55]   -> saved: 052_CIFRON_cipher-mining-ondo-tokenized-stock_last90d_usd.csv
# [2026-02-28 10:27:55]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:28:25] === (53/100) Fetching Soul Graph (grph) id=soul-graph ===
# [2026-02-28 10:28:25]   Request attempt 1 for soul-graph ...
# [2026-02-28 10:28:28]   -> saved: 053_GRPH_soul-graph_last90d_usd.csv
# [2026-02-28 10:28:28]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:28:58] === (54/100) Fetching Real BIG Coin (rbc) id=real-big-coin ===
# [2026-02-28 10:28:58]   Request attempt 1 for real-big-coin ...
# [2026-02-28 10:28:59]   -> saved: 054_RBC_real-big-coin_last90d_usd.csv
# [2026-02-28 10:28:59]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:29:29] === (55/100) Fetching enfineo (enf) id=enfineo ===
# [2026-02-28 10:29:29]   Request attempt 1 for enfineo ...
# [2026-02-28 10:29:31]   -> saved: 055_ENF_enfineo_last90d_usd.csv
# [2026-02-28 10:29:31]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:30:01] === (56/100) Fetching Frogonsol (frog) id=frogonsol ===
# [2026-02-28 10:30:01]   Request attempt 1 for frogonsol ...
# [2026-02-28 10:30:02]   -> saved: 056_FROG_frogonsol_last90d_usd.csv
# [2026-02-28 10:30:02]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:30:32] === (57/100) Fetching Gold (xau) id=gold-8 ===
# [2026-02-28 10:30:32]   Request attempt 1 for gold-8 ...
# [2026-02-28 10:30:35]   -> saved: 057_XAU_gold-8_last90d_usd.csv
# [2026-02-28 10:30:35]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:31:05] === (58/100) Fetching Jobchain (job) id=jobchain ===
# [2026-02-28 10:31:05]   Request attempt 1 for jobchain ...
# [2026-02-28 10:31:05]   -> saved: 058_JOB_jobchain_last90d_usd.csv
# [2026-02-28 10:31:05]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:31:35] === (59/100) Fetching AlphaBlockAI (alpha) id=alphablockai ===
# [2026-02-28 10:31:35]   Request attempt 1 for alphablockai ...
# [2026-02-28 10:31:38]   -> saved: 059_ALPHA_alphablockai_last90d_usd.csv
# [2026-02-28 10:31:38]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:32:08] === (60/100) Fetching 脸谱 (脸谱) id=lianpu ===
# [2026-02-28 10:32:08]   Request attempt 1 for lianpu ...
# [2026-02-28 10:32:10]   -> saved: 060_脸谱_lianpu_last90d_usd.csv
# [2026-02-28 10:32:10]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:32:40] === (61/100) Fetching DPIN [OLD] (dpin) id=dpin ===
# [2026-02-28 10:32:40]   Request attempt 1 for dpin ...
# [2026-02-28 10:32:41]   -> saved: 061_DPIN_dpin_last90d_usd.csv
# [2026-02-28 10:32:41]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:33:11] === (62/100) Fetching Functionland (fula) id=functionland ===
# [2026-02-28 10:33:11]   Request attempt 1 for functionland ...
# [2026-02-28 10:33:13]   -> saved: 062_FULA_functionland_last90d_usd.csv
# [2026-02-28 10:33:13]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:33:43] === (63/100) Fetching SPICE pUSD Vault (pusdnote) id=spice-pusd-vault ===
# [2026-02-28 10:33:43]   Request attempt 1 for spice-pusd-vault ...
# [2026-02-28 10:33:44]   -> saved: 063_PUSDNOTE_spice-pusd-vault_last90d_usd.csv
# [2026-02-28 10:33:44]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:34:14] === (64/100) Fetching ༼ つ ◕_◕ ༽つ (gib) id=_ ===
# [2026-02-28 10:34:14]   Request attempt 1 for _ ...
# [2026-02-28 10:34:15]   -> saved: 064_GIB___last90d_usd.csv
# [2026-02-28 10:34:15]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:34:45] === (65/100) Fetching WaultSwap (wex) id=waultswap ===
# [2026-02-28 10:34:45]   Request attempt 1 for waultswap ...
# [2026-02-28 10:34:48]   -> saved: 065_WEX_waultswap_last90d_usd.csv
# [2026-02-28 10:34:48]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:35:18] === (66/100) Fetching Pandora Finance (pan) id=pandora-finance ===
# [2026-02-28 10:35:18]   Request attempt 1 for pandora-finance ...
# [2026-02-28 10:35:18]   -> saved: 066_PAN_pandora-finance_last90d_usd.csv
# [2026-02-28 10:35:18]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:35:48] === (67/100) Fetching NuCypher (nu) id=nucypher ===
# [2026-02-28 10:35:48]   Request attempt 1 for nucypher ...
# [2026-02-28 10:35:50]   -> saved: 067_NU_nucypher_last90d_usd.csv
# [2026-02-28 10:35:50]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:36:20] === (68/100) Fetching Immutable (dara) id=immutable ===
# [2026-02-28 10:36:20]   Request attempt 1 for immutable ...
# [2026-02-28 10:36:21]   -> saved: 068_DARA_immutable_last90d_usd.csv
# [2026-02-28 10:36:21]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:36:51] === (69/100) Fetching GOTM (gotm) id=gotm ===
# [2026-02-28 10:36:51]   Request attempt 1 for gotm ...
# [2026-02-28 10:36:53]   -> saved: 069_GOTM_gotm_last90d_usd.csv
# [2026-02-28 10:36:53]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:37:23] === (70/100) Fetching Openfabric AI (ofn) id=openfabric ===
# [2026-02-28 10:37:23]   Request attempt 1 for openfabric ...
# [2026-02-28 10:37:26]   -> saved: 070_OFN_openfabric_last90d_usd.csv
# [2026-02-28 10:37:26]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:37:56] === (71/100) Fetching flopper (flop) id=flopper ===
# [2026-02-28 10:37:56]   Request attempt 1 for flopper ...
# [2026-02-28 10:37:57]   -> saved: 071_FLOP_flopper_last90d_usd.csv
# [2026-02-28 10:37:57]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:38:27] === (72/100) Fetching $REKT (rekt) id=rektcoin ===
# [2026-02-28 10:38:27]   Request attempt 1 for rektcoin ...
# [2026-02-28 10:38:27]   -> saved: 072_REKT_rektcoin_last90d_usd.csv
# [2026-02-28 10:38:27]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:38:57] === (73/100) Fetching WienerAI (wai) id=wienerai ===
# [2026-02-28 10:38:57]   Request attempt 1 for wienerai ...
# [2026-02-28 10:38:58]   -> saved: 073_WAI_wienerai_last90d_usd.csv
# [2026-02-28 10:38:58]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:39:28] === (74/100) Fetching LP Yearn CRV Vault (lp-ycrv) id=lp-yearn-crv-vault ===
# [2026-02-28 10:39:28]   Request attempt 1 for lp-yearn-crv-vault ...
# [2026-02-28 10:39:29]   -> saved: 074_LP-YCRV_lp-yearn-crv-vault_last90d_usd.csv
# [2026-02-28 10:39:29]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:39:59] === (75/100) Fetching Bitsota (sn94) id=eastworld ===
# [2026-02-28 10:39:59]   Request attempt 1 for eastworld ...
# [2026-02-28 10:40:01]   -> saved: 075_SN94_eastworld_last90d_usd.csv
# [2026-02-28 10:40:01]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:40:31] === (76/100) Fetching This is fine (fine) id=this-is-fine-2 ===
# [2026-02-28 10:40:31]   Request attempt 1 for this-is-fine-2 ...
# [2026-02-28 10:40:33]   -> saved: 076_FINE_this-is-fine-2_last90d_usd.csv
# [2026-02-28 10:40:33]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:41:03] === (77/100) Fetching Hedera (hbar) id=hedera-hashgraph ===
# [2026-02-28 10:41:03]   Request attempt 1 for hedera-hashgraph ...
# [2026-02-28 10:41:06]   -> saved: 077_HBAR_hedera-hashgraph_last90d_usd.csv
# [2026-02-28 10:41:06]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:41:36] === (78/100) Fetching Overnight Finance (ovn) id=overnight-finance ===
# [2026-02-28 10:41:36]   Request attempt 1 for overnight-finance ...
# [2026-02-28 10:41:38]   -> saved: 078_OVN_overnight-finance_last90d_usd.csv
# [2026-02-28 10:41:38]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:42:08] === (79/100) Fetching I love puppies (puppies) id=i-love-puppies ===
# [2026-02-28 10:42:08]   Request attempt 1 for i-love-puppies ...
# [2026-02-28 10:42:08]   -> saved: 079_PUPPIES_i-love-puppies_last90d_usd.csv
# [2026-02-28 10:42:08]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:42:38] === (80/100) Fetching BlackWork (blwk) id=blackwork ===
# [2026-02-28 10:42:38]   Request attempt 1 for blackwork ...
# [2026-02-28 10:42:39]   -> saved: 080_BLWK_blackwork_last90d_usd.csv
# [2026-02-28 10:42:39]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:43:09] === (81/100) Fetching BRLA Digital BRLA (brla) id=brla-digital-brla ===
# [2026-02-28 10:43:09]   Request attempt 1 for brla-digital-brla ...
# [2026-02-28 10:43:09]   -> saved: 081_BRLA_brla-digital-brla_last90d_usd.csv
# [2026-02-28 10:43:09]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:43:39] === (82/100) Fetching Orta Chain (orta) id=orta-chain ===
# [2026-02-28 10:43:39]   Request attempt 1 for orta-chain ...
# [2026-02-28 10:43:40]   -> saved: 082_ORTA_orta-chain_last90d_usd.csv
# [2026-02-28 10:43:40]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:44:10] === (83/100) Fetching Razor Network (razor) id=razor-network ===
# [2026-02-28 10:44:10]   Request attempt 1 for razor-network ...
# [2026-02-28 10:44:11]   -> saved: 083_RAZOR_razor-network_last90d_usd.csv
# [2026-02-28 10:44:11]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:44:41] === (84/100) Fetching Wrapped Aave Ethereum USDT (waethusdt) id=wrapped-aave-ethereum-usdt ===
# [2026-02-28 10:44:41]   Request attempt 1 for wrapped-aave-ethereum-usdt ...
# [2026-02-28 10:44:44]   -> saved: 084_WAETHUSDT_wrapped-aave-ethereum-usdt_last90d_usd.csv
# [2026-02-28 10:44:44]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:45:14] === (85/100) Fetching DAOhaus (haus) id=daohaus ===
# [2026-02-28 10:45:14]   Request attempt 1 for daohaus ...
# [2026-02-28 10:45:16]   -> saved: 085_HAUS_daohaus_last90d_usd.csv
# [2026-02-28 10:45:16]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:45:46] === (86/100) Fetching Utopian Contributor Coin (utcc) id=utopian-contributor-coin ===
# [2026-02-28 10:45:46]   Request attempt 1 for utopian-contributor-coin ...
# [2026-02-28 10:45:48]   -> saved: 086_UTCC_utopian-contributor-coin_last90d_usd.csv
# [2026-02-28 10:45:48]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:46:18] === (87/100) Fetching VanEck Treasury Fund (vbill) id=vaneck-treasury-fund ===
# [2026-02-28 10:46:18]   Request attempt 1 for vaneck-treasury-fund ...
# [2026-02-28 10:46:20]   -> saved: 087_VBILL_vaneck-treasury-fund_last90d_usd.csv
# [2026-02-28 10:46:20]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:46:50] === (88/100) Fetching Fanpla (fpl) id=fanpla ===
# [2026-02-28 10:46:50]   Request attempt 1 for fanpla ...
# [2026-02-28 10:46:52]   -> saved: 088_FPL_fanpla_last90d_usd.csv
# [2026-02-28 10:46:52]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:47:22] === (89/100) Fetching Chirper AI (chirp) id=chirper-ai ===
# [2026-02-28 10:47:22]   Request attempt 1 for chirper-ai ...
# [2026-02-28 10:47:24]   -> saved: 089_CHIRP_chirper-ai_last90d_usd.csv
# [2026-02-28 10:47:24]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:47:54] === (90/100) Fetching Joi (joi) id=joi ===
# [2026-02-28 10:47:54]   Request attempt 1 for joi ...
# [2026-02-28 10:47:55]   -> saved: 090_JOI_joi_last90d_usd.csv
# [2026-02-28 10:47:55]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:48:25] === (91/100) Fetching Relation Native Token (rel) id=relation-native-token ===
# [2026-02-28 10:48:25]   Request attempt 1 for relation-native-token ...
# [2026-02-28 10:48:26]   -> saved: 091_REL_relation-native-token_last90d_usd.csv
# [2026-02-28 10:48:26]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:48:56] === (92/100) Fetching Goatseus Poppimus (popgoat) id=goatseus-poppimus ===
# [2026-02-28 10:48:56]   Request attempt 1 for goatseus-poppimus ...
# [2026-02-28 10:48:57]   -> saved: 092_POPGOAT_goatseus-poppimus_last90d_usd.csv
# [2026-02-28 10:48:57]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:49:27] === (93/100) Fetching L2 Standard Bridged DAI (Base) (dai) id=l2-standard-bridged-dai-base ===
# [2026-02-28 10:49:27]   Request attempt 1 for l2-standard-bridged-dai-base ...
# [2026-02-28 10:49:29]   -> saved: 093_DAI_l2-standard-bridged-dai-base_last90d_usd.csv
# [2026-02-28 10:49:29]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:49:59] === (94/100) Fetching UPCX (upc) id=upcx ===
# [2026-02-28 10:49:59]   Request attempt 1 for upcx ...
# [2026-02-28 10:49:59]   -> saved: 094_UPC_upcx_last90d_usd.csv
# [2026-02-28 10:49:59]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:50:29] === (95/100) Fetching Hashtagger (mooo) id=hashtagger ===
# [2026-02-28 10:50:29]   Request attempt 1 for hashtagger ...
# [2026-02-28 10:50:32]   -> saved: 095_MOOO_hashtagger_last90d_usd.csv
# [2026-02-28 10:50:32]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:51:02] === (96/100) Fetching Skycastle (sky) id=skycastle ===
# [2026-02-28 10:51:02]   Request attempt 1 for skycastle ...
# [2026-02-28 10:51:04]   -> saved: 096_SKY_skycastle_last90d_usd.csv
# [2026-02-28 10:51:04]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:51:34] === (97/100) Fetching BinaryDAO (byte) id=binarydao ===
# [2026-02-28 10:51:34]   Request attempt 1 for binarydao ...
# [2026-02-28 10:51:35]   -> saved: 097_BYTE_binarydao_last90d_usd.csv
# [2026-02-28 10:51:35]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:52:05] === (98/100) Fetching Epik Prime (epik) id=epik-prime ===
# [2026-02-28 10:52:05]   Request attempt 1 for epik-prime ...
# [2026-02-28 10:52:07]   -> saved: 098_EPIK_epik-prime_last90d_usd.csv
# [2026-02-28 10:52:07]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:52:37] === (99/100) Fetching All Your Base (ayb) id=all-your-base-2 ===
# [2026-02-28 10:52:37]   Request attempt 1 for all-your-base-2 ...
# [2026-02-28 10:52:37]   -> saved: 099_AYB_all-your-base-2_last90d_usd.csv
# [2026-02-28 10:52:37]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:53:07] === (100/100) Fetching Mato The Mouse (mato) id=mato-the-mouse ===
# [2026-02-28 10:53:07]   Request attempt 1 for mato-the-mouse ...
# [2026-02-28 10:53:08]   -> saved: 100_MATO_mato-the-mouse_last90d_usd.csv
# [2026-02-28 10:53:08]   Waiting 30 seconds before next request...
#
# [2026-02-28 10:53:38] ===== Program Finished =====
# Total elapsed time: 52.36 minutes
