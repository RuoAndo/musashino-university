# %%
# -*- coding: utf-8 -*-

from pathlib import Path
from datetime import datetime
import time

import pandas as pd
import matplotlib.pyplot as plt


# ==========================
# 設定
# ==========================
CSV_PATH = Path(
    r"D:\musashino-university\finance\change_point_output"
    r"\change_point_daily_counts_25combos_20260510_142302.csv"
)

OUTPUT_DIR = CSV_PATH.parent

METHOD_PLOT_DIR = OUTPUT_DIR / "plots_by_method"
RANKING_PLOT_DIR = OUTPUT_DIR / "plots_date_ranking"

OUT_METHOD_CSV = OUTPUT_DIR / "change_point_daily_counts_by_method_20260510_142302.csv"
OUT_METHOD_OVERLAY_PNG = OUTPUT_DIR / "daily_change_point_by_method_overlay.png"

OUT_DATE_RANKING_CSV = OUTPUT_DIR / "daily_total_change_point_ranking_20260510_142302.csv"
OUT_DATE_RANKING_TOP_PNG = OUTPUT_DIR / "daily_total_change_point_ranking_top30.png"

SAVE_ENCODING = "utf-8-sig"

METHOD_ORDER = ["pelt", "binseg", "bottomup", "dynp", "window"]

FIGSIZE_METHOD_OVERLAY = (18, 8)
FIGSIZE_METHOD_SINGLE = (16, 6)
FIGSIZE_RANKING = (14, 10)

DPI = 150

SHOW_METHOD_OVERLAY = True
SHOW_METHOD_SINGLE = True
SHOW_DATE_RANKING = True

TOP_N_DATES = 30


# ==========================
# ログ
# ==========================
START_TIME = time.time()

def log(msg):
    elapsed = time.time() - START_TIME
    now = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    print(f"[{now} | +{elapsed:,.1f}s] {msg}")


# ==========================
# 準備
# ==========================
METHOD_PLOT_DIR.mkdir(parents=True, exist_ok=True)
RANKING_PLOT_DIR.mkdir(parents=True, exist_ok=True)

log("CSV読み込み開始")

df = pd.read_csv(CSV_PATH, encoding=SAVE_ENCODING)

required_cols = {
    "method",
    "model",
    "combo",
    "date",
    "change_point_count"
}

missing_cols = required_cols - set(df.columns)
if missing_cols:
    raise ValueError(f"必要な列がありません: {missing_cols}")

df["date"] = pd.to_datetime(df["date"])
df["change_point_count"] = pd.to_numeric(
    df["change_point_count"],
    errors="coerce"
).fillna(0).astype(int)

df = df.sort_values("date")

log(f"読み込み完了: {CSV_PATH}")
log(f"行数: {len(df):,}")
log(f"method数: {df['method'].nunique()}")
log(f"combo数: {df['combo'].nunique()}")


# ==========================
# 1. method 5種類ごとに日別集計
# ==========================
log("=" * 70)
log("method別の日別集計を開始")

method_daily = (
    df.groupby(["date", "method"], as_index=False)["change_point_count"]
      .sum()
      .rename(columns={"change_point_count": "method_change_point_count"})
)

method_daily["method"] = pd.Categorical(
    method_daily["method"],
    categories=METHOD_ORDER,
    ordered=True
)

method_daily = method_daily.sort_values(["method", "date"])

method_daily.to_csv(
    OUT_METHOD_CSV,
    index=False,
    encoding=SAVE_ENCODING
)

log(f"method別CSV保存完了: {OUT_METHOD_CSV}")


# ==========================
# 2. method別ピボット
# ==========================
pivot = (
    method_daily.pivot_table(
        index="date",
        columns="method",
        values="method_change_point_count",
        aggfunc="sum",
        fill_value=0
    )
    .reset_index()
)

for method in METHOD_ORDER:
    if method not in pivot.columns:
        pivot[method] = 0

pivot = pivot[["date"] + METHOD_ORDER]
pivot = pivot.sort_values("date")


# ==========================
# 3. method 5種類の重ね描画
# ==========================
log("=" * 70)
log("method 5種類の重ね描画を開始")

plt.figure(figsize=FIGSIZE_METHOD_OVERLAY)

for method in METHOD_ORDER:
    plt.plot(
        pivot["date"],
        pivot[method],
        linewidth=2,
        label=method
    )

plt.title("Daily Change Point Counts by Method")
plt.xlabel("Date")
plt.ylabel("Change Point Count")
plt.grid(True)

plt.legend(
    bbox_to_anchor=(1.02, 1),
    loc="upper left"
)

plt.tight_layout()

plt.savefig(
    OUT_METHOD_OVERLAY_PNG,
    dpi=DPI,
    bbox_inches="tight"
)

log(f"method重ね描画PNG保存完了: {OUT_METHOD_OVERLAY_PNG}")

if SHOW_METHOD_OVERLAY:
    plt.show()

plt.close()


# ==========================
# 4. methodごとの個別描画
# ==========================
log("=" * 70)
log("methodごとの個別描画を開始")

for i, method in enumerate(METHOD_ORDER, start=1):

    log(f"[{i}/{len(METHOD_ORDER)}] method={method}")

    plt.figure(figsize=FIGSIZE_METHOD_SINGLE)

    plt.plot(
        pivot["date"],
        pivot[method],
        linewidth=2
    )

    plt.title(f"Daily Change Point Counts - method={method}")
    plt.xlabel("Date")
    plt.ylabel("Change Point Count")
    plt.grid(True)

    plt.tight_layout()

    out_png = METHOD_PLOT_DIR / f"daily_change_point_method_{method}.png"

    plt.savefig(out_png, dpi=DPI)

    log(f"保存完了: {out_png}")

    if SHOW_METHOD_SINGLE:
        plt.show()

    plt.close()


# ==========================
# 5. method別ランキング
# ==========================
log("=" * 70)
log("method別ランキングを作成")

method_ranking = []

for method in METHOD_ORDER:
    max_idx = pivot[method].idxmax()

    method_ranking.append({
        "method": method,
        "total_count": int(pivot[method].sum()),
        "max_count": int(pivot.loc[max_idx, method]),
        "max_date": pivot.loc[max_idx, "date"].strftime("%Y-%m-%d")
    })

method_ranking_df = pd.DataFrame(method_ranking)

method_ranking_df = method_ranking_df.sort_values(
    ["total_count", "max_count"],
    ascending=False
)

OUT_METHOD_RANKING_CSV = OUTPUT_DIR / "change_point_method_ranking_20260510_142302.csv"

method_ranking_df.to_csv(
    OUT_METHOD_RANKING_CSV,
    index=False,
    encoding=SAVE_ENCODING
)

print()
print("=== method別ランキング ===")
print(method_ranking_df.to_string(index=False))

log(f"method別ランキングCSV保存完了: {OUT_METHOD_RANKING_CSV}")


# ==========================
# 6. 日付別総変化点ランキング
# ==========================
log("=" * 70)
log("日付別総変化点ランキングを作成")

date_total = (
    df.groupby("date", as_index=False)["change_point_count"]
      .sum()
      .rename(columns={"change_point_count": "total_change_point_count"})
)

date_total = date_total.sort_values(
    "total_change_point_count",
    ascending=False
)

date_total.to_csv(
    OUT_DATE_RANKING_CSV,
    index=False,
    encoding=SAVE_ENCODING
)

log(f"日付別ランキングCSV保存完了: {OUT_DATE_RANKING_CSV}")

print()
print(f"=== 日付別総変化点ランキング TOP{TOP_N_DATES} ===")
print(date_total.head(TOP_N_DATES).to_string(index=False))


# ==========================
# 7. 日付別ランキングTOP Nを棒グラフ化
# ==========================
log("=" * 70)
log(f"日付別ランキングTOP{TOP_N_DATES}の棒グラフを作成")

top_dates = date_total.head(TOP_N_DATES).copy()

top_dates["date_str"] = top_dates["date"].dt.strftime("%Y-%m-%d")

# 見やすいように棒グラフでは下から上に増える順へ反転
top_dates_plot = top_dates.sort_values(
    "total_change_point_count",
    ascending=True
)

plt.figure(figsize=FIGSIZE_RANKING)

plt.barh(
    top_dates_plot["date_str"],
    top_dates_plot["total_change_point_count"]
)

plt.title(f"Top {TOP_N_DATES} Dates by Total Change Point Count")
plt.xlabel("Total Change Point Count")
plt.ylabel("Date")
plt.grid(axis="x")

plt.tight_layout()

plt.savefig(
    OUT_DATE_RANKING_TOP_PNG,
    dpi=DPI,
    bbox_inches="tight"
)

log(f"日付別ランキングPNG保存完了: {OUT_DATE_RANKING_TOP_PNG}")

if SHOW_DATE_RANKING:
    plt.show()

plt.close()


# ==========================
# 8. 日付ランキングTOP Nのmethod内訳CSV
# ==========================
log("=" * 70)
log(f"TOP{TOP_N_DATES}日付のmethod別内訳を作成")

top_date_set = set(top_dates["date"])

top_method_breakdown = method_daily[
    method_daily["date"].isin(top_date_set)
].copy()

top_method_breakdown["date_total"] = top_method_breakdown["date"].map(
    date_total.set_index("date")["total_change_point_count"]
)

top_method_breakdown = top_method_breakdown.sort_values(
    ["date_total", "date", "method"],
    ascending=[False, True, True]
)

OUT_TOP_METHOD_BREAKDOWN_CSV = OUTPUT_DIR / (
    f"daily_total_change_point_top{TOP_N_DATES}_method_breakdown_20260510_142302.csv"
)

top_method_breakdown.to_csv(
    OUT_TOP_METHOD_BREAKDOWN_CSV,
    index=False,
    encoding=SAVE_ENCODING
)

log(f"TOP日付のmethod別内訳CSV保存完了: {OUT_TOP_METHOD_BREAKDOWN_CSV}")


# ==========================
# 終了
# ==========================
log("=" * 70)
log("処理完了")

log(f"method別CSV: {OUT_METHOD_CSV}")
log(f"method重ね描画PNG: {OUT_METHOD_OVERLAY_PNG}")
log(f"method個別PNG保存先: {METHOD_PLOT_DIR}")
log(f"methodランキングCSV: {OUT_METHOD_RANKING_CSV}")
log(f"日付別ランキングCSV: {OUT_DATE_RANKING_CSV}")
log(f"日付別ランキングPNG: {OUT_DATE_RANKING_TOP_PNG}")
log(f"TOP日付method内訳CSV: {OUT_TOP_METHOD_BREAKDOWN_CSV}")
log(f"総処理時間: {time.time() - START_TIME:,.1f}s")
# Out:
# [2026-05-20 09:53:03 | +0.0s] CSV読み込み開始
# [2026-05-20 09:53:04 | +0.5s] 読み込み完了: D:\musashino-university\finance\change_point_output\change_point_daily_counts_25combos_20260510_142302.csv
# [2026-05-20 09:53:04 | +0.5s] 行数: 2,664
# [2026-05-20 09:53:04 | +0.5s] method数: 5
# [2026-05-20 09:53:04 | +0.5s] combo数: 24
# [2026-05-20 09:53:04 | +0.5s] ======================================================================
# [2026-05-20 09:53:04 | +0.5s] method別の日別集計を開始
# [2026-05-20 09:53:04 | +0.7s] method別CSV保存完了: D:\musashino-university\finance\change_point_output\change_point_daily_counts_by_method_20260510_142302.csv
# [2026-05-20 09:53:04 | +0.8s] ======================================================================
# [2026-05-20 09:53:04 | +0.8s] method 5種類の重ね描画を開始
# C:\Users\user\AppData\Local\Temp\ipykernel_113064\3817653636.py:127: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   method_daily.pivot_table(
# [2026-05-20 09:53:06 | +2.2s] method重ね描画PNG保存完了: D:\musashino-university\finance\change_point_output\daily_change_point_by_method_overlay.png
# [2026-05-20 09:53:06 | +2.9s] ======================================================================
# [2026-05-20 09:53:06 | +2.9s] methodごとの個別描画を開始
# [2026-05-20 09:53:06 | +2.9s] [1/5] method=pelt
# [2026-05-20 09:53:07 | +3.9s] 保存完了: D:\musashino-university\finance\change_point_output\plots_by_method\daily_change_point_method_pelt.png
# [2026-05-20 09:53:08 | +4.3s] [2/5] method=binseg
# [2026-05-20 09:53:09 | +5.4s] 保存完了: D:\musashino-university\finance\change_point_output\plots_by_method\daily_change_point_method_binseg.png
# [2026-05-20 09:53:10 | +6.1s] [3/5] method=bottomup
# [2026-05-20 09:53:10 | +7.0s] 保存完了: D:\musashino-university\finance\change_point_output\plots_by_method\daily_change_point_method_bottomup.png
# [2026-05-20 09:53:11 | +7.5s] [4/5] method=dynp
# [2026-05-20 09:53:12 | +9.0s] 保存完了: D:\musashino-university\finance\change_point_output\plots_by_method\daily_change_point_method_dynp.png
# [2026-05-20 09:53:13 | +9.4s] [5/5] method=window
# [2026-05-20 09:53:14 | +10.3s] 保存完了: D:\musashino-university\finance\change_point_output\plots_by_method\daily_change_point_method_window.png
# [2026-05-20 09:53:14 | +10.8s] ======================================================================
# [2026-05-20 09:53:14 | +10.8s] method別ランキングを作成
#
# === method別ランキング ===
#   method  total_count  max_count   max_date
#     pelt       743531      12194 2026-02-06
#     dynp       151904       3509 2026-02-06
# bottomup       151542       6023 2026-04-13
#   window       135770       2804 2026-02-06
#   binseg       132344       4843 2026-02-06
# [2026-05-20 09:53:14 | +10.9s] method別ランキングCSV保存完了: D:\musashino-university\finance\change_point_output\change_point_method_ranking_20260510_142302.csv
# [2026-05-20 09:53:14 | +10.9s] ======================================================================
# [2026-05-20 09:53:14 | +10.9s] 日付別総変化点ランキングを作成
# [2026-05-20 09:53:14 | +11.0s] 日付別ランキングCSV保存完了: D:\musashino-university\finance\change_point_output\daily_total_change_point_ranking_20260510_142302.csv
#
# === 日付別総変化点ランキング TOP30 ===
#       date  total_change_point_count
# 2026-02-06                     26810
# 2026-02-05                     22249
# 2026-01-31                     22174
# 2026-02-03                     20209
# 2026-01-21                     19016
# 2026-02-02                     18610
# 2026-02-25                     18348
# 2026-04-13                     18226
# 2026-02-04                     18210
# 2026-01-15                     18184
# 2026-01-19                     17387
# 2026-01-29                     17100
# 2026-04-12                     16888
# 2026-02-07                     16725
# 2026-03-04                     16712
# 2026-03-02                     16309
# 2026-02-01                     16184
# 2026-03-23                     16037
# 2026-01-20                     16000
# 2026-02-23                     15995
# 2026-03-18                     15940
# 2026-01-30                     15908
# 2026-02-28                     15661
# 2026-03-13                     15621
# 2026-02-12                     15442
# 2026-02-09                     15376
# 2026-02-13                     15166
# 2026-03-16                     15134
# 2026-01-27                     15133
# 2026-02-27                     15088
# [2026-05-20 09:53:14 | +11.0s] ======================================================================
# [2026-05-20 09:53:14 | +11.0s] 日付別ランキングTOP30の棒グラフを作成
# [2026-05-20 09:53:16 | +12.9s] 日付別ランキングPNG保存完了: D:\musashino-university\finance\change_point_output\daily_total_change_point_ranking_top30.png
# [2026-05-20 09:53:17 | +13.4s] ======================================================================
# [2026-05-20 09:53:17 | +13.4s] TOP30日付のmethod別内訳を作成
# [2026-05-20 09:53:17 | +13.5s] TOP日付のmethod別内訳CSV保存完了: D:\musashino-university\finance\change_point_output\daily_total_change_point_top30_method_breakdown_20260510_142302.csv
# [2026-05-20 09:53:17 | +13.5s] ======================================================================
# [2026-05-20 09:53:17 | +13.5s] 処理完了
# [2026-05-20 09:53:17 | +13.5s] method別CSV: D:\musashino-university\finance\change_point_output\change_point_daily_counts_by_method_20260510_142302.csv
# [2026-05-20 09:53:17 | +13.5s] method重ね描画PNG: D:\musashino-university\finance\change_point_output\daily_change_point_by_method_overlay.png
# [2026-05-20 09:53:17 | +13.5s] method個別PNG保存先: D:\musashino-university\finance\change_point_output\plots_by_method
# [2026-05-20 09:53:17 | +13.5s] methodランキングCSV: D:\musashino-university\finance\change_point_output\change_point_method_ranking_20260510_142302.csv
# [2026-05-20 09:53:17 | +13.5s] 日付別ランキングCSV: D:\musashino-university\finance\change_point_output\daily_total_change_point_ranking_20260510_142302.csv
# [2026-05-20 09:53:17 | +13.5s] 日付別ランキングPNG: D:\musashino-university\finance\change_point_output\daily_total_change_point_ranking_top30.png
# [2026-05-20 09:53:17 | +13.5s] TOP日付method内訳CSV: D:\musashino-university\finance\change_point_output\daily_total_change_point_top30_method_breakdown_20260510_142302.csv
# [2026-05-20 09:53:17 | +13.5s] 総処理時間: 13.5s
