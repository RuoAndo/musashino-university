# %%
import random
from pathlib import Path
from datetime import datetime

import pandas as pd
import numpy as np
from statsmodels.tsa.ar_model import AutoReg
import ruptures as rpt


# ------------------------
# 設定
# ------------------------
NUM_COINS = 100
DATA_DIR = Path.cwd() / "coingecko_by_coin"
OUTPUT_SUMMARY_CSV = Path.cwd() / "change_point_summary.csv"
OUTPUT_PAIRS_CSV = Path.cwd() / "change_point_pairs.csv"

AR_LAGS = 5
CHANGE_MODEL = "rbf"
CHANGE_PEN_BASE = 3.0
MIN_CHANGE_DISTANCE = 5

PRICE_COL_CANDIDATES = ["price", "Price", "close", "Close"]
TIME_COL_CANDIDATES = ["timestamp", "Timestamp", "date", "Date", "time", "Time"]


def log(msg: str):
    print(f"[{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}] {msg}")


# ------------------------
# CSV一覧を取得
# ------------------------
def find_coin_files(data_dir: Path):
    if not data_dir.exists():
        raise FileNotFoundError(f"フォルダが見つかりません: {data_dir}")

    files = sorted(data_dir.glob("*.csv"))
    if not files:
        raise FileNotFoundError(f"CSVファイルが見つかりません: {data_dir}")

    return files


# ------------------------
# 列名を自動判定
# ------------------------
def detect_column(df: pd.DataFrame, candidates: list, col_type: str):
    for c in candidates:
        if c in df.columns:
            return c
    raise ValueError(
        f"{col_type}列が見つかりません。候補: {candidates}, 実際の列: {list(df.columns)}"
    )


# ------------------------
# CSV読み込み
# ------------------------
def load_coin_csv(file_path: Path):
    df = pd.read_csv(file_path)

    time_col = detect_column(df, TIME_COL_CANDIDATES, "時刻")
    price_col = detect_column(df, PRICE_COL_CANDIDATES, "価格")

    df = df[[time_col, price_col]].copy()
    df.columns = ["timestamp", "price"]

    df["timestamp"] = pd.to_datetime(df["timestamp"], errors="coerce")
    df["price"] = pd.to_numeric(df["price"], errors="coerce")

    df = df.dropna(subset=["timestamp", "price"]).copy()
    df = df[df["price"] > 0].copy()
    df = df.drop_duplicates(subset=["timestamp"]).sort_values("timestamp").reset_index(drop=True)

    if len(df) == 0:
        raise ValueError(f"有効なデータがありません: {file_path.name}")

    return df


# ------------------------
# ファイル名から銘柄名を推定
# ------------------------
def symbol_from_filename(file_path: Path):
    return file_path.stem


# ------------------------
# 対数収益率を作成
# ------------------------
def make_log_returns(df: pd.DataFrame):
    prices = df["price"].values.astype(float)

    if len(prices) < 2:
        return pd.DataFrame(columns=["timestamp", "log_return"])

    log_returns = np.diff(np.log(prices))
    return_times = df["timestamp"].iloc[1:].reset_index(drop=True)

    ret_df = pd.DataFrame({
        "timestamp": return_times,
        "log_return": log_returns
    })

    ret_df = ret_df.replace([np.inf, -np.inf], np.nan).dropna().reset_index(drop=True)
    return ret_df


# ------------------------
# AR を対数収益率に適用
# ------------------------
def apply_ar_returns_in_sample(ret_df: pd.DataFrame, symbol: str, lags: int = 5):
    series = pd.Series(ret_df["log_return"].values.astype(float))

    if len(series) <= lags + 5:
        log(f"[{symbol}] 対数収益率データが短すぎるため AR をスキップします")
        return None, None

    model = AutoReg(series, lags=lags, old_names=False)
    res = model.fit()

    fitted = res.fittedvalues
    actual = series.iloc[lags:]

    min_len = min(len(actual), len(fitted))
    actual = actual.iloc[:min_len]
    fitted = fitted.iloc[:min_len]

    mse = float(((actual.values - fitted.values) ** 2).mean())
    rmse = float(np.sqrt(mse))

    log(f"[{symbol}] AR({lags}) on returns: MSE={mse:.6e}, RMSE={rmse:.6e}")
    return mse, rmse


# ------------------------
# 変化点の間引き
# ------------------------
def filter_change_points_by_distance(bkps, min_distance):
    filtered = []
    for b in bkps:
        if not filtered or (b - filtered[-1] >= min_distance):
            filtered.append(b)
    return filtered


# ------------------------
# 変化点検知
# ------------------------
def detect_change_points(ret_df: pd.DataFrame, symbol: str,
                         model_name="rbf", pen_base=3.0, min_distance=5):
    returns = ret_df["log_return"].values.astype(float)

    if len(returns) < 10:
        log(f"[{symbol}] 変化点検知用データが短すぎるためスキップします")
        return [], [], np.array([]), pd.Series(dtype="datetime64[ns]")

    std = returns.std()
    if std < 1e-12:
        log(f"[{symbol}] 収益率の分散がほぼ0のため変化点検知をスキップします")
        return [], [], returns, ret_df["timestamp"]

    returns_scaled = (returns - returns.mean()) / (std + 1e-8)
    signal = returns_scaled.reshape(-1, 1)

    pen_value = pen_base * np.log(len(signal))
    algo = rpt.Pelt(model=model_name).fit(signal)
    bkps = algo.predict(pen=pen_value)

    valid_bkps = [b for b in bkps if b < len(returns)]
    valid_bkps = filter_change_points_by_distance(valid_bkps, min_distance)

    log(f"[{symbol}] change points (raw): {bkps}")
    log(f"[{symbol}] change points (filtered): {valid_bkps}")

    return bkps, valid_bkps, returns_scaled, ret_df["timestamp"]


# ------------------------
# 変化点候補の表示
# ------------------------
def summarize_change_points(ret_df: pd.DataFrame, symbol: str, valid_bkps):
    print(f"\n=== {symbol} の変化点候補 ===")

    if not valid_bkps:
        print("変化点は検出されませんでした。")
        return

    for i, b in enumerate(valid_bkps, start=1):
        if b < len(ret_df):
            t = ret_df["timestamp"].iloc[b]
            r = ret_df["log_return"].iloc[b]
            print(f"{i}. {t.strftime('%Y-%m-%d %H:%M:%S')} 付近, log_return={r:.6f}")


# ------------------------
# 変化点の日付抽出
# ------------------------
def extract_change_point_dates(ret_df: pd.DataFrame, valid_bkps):
    dates = []
    for b in valid_bkps:
        if b < len(ret_df):
            dates.append(ret_df["timestamp"].iloc[b])
    return dates


# ------------------------
# 変化点強度抽出
# ------------------------
def extract_change_point_strengths(ret_df: pd.DataFrame, valid_bkps):
    returns = ret_df["log_return"].values.astype(float)
    strengths = []

    for b in valid_bkps:
        if 1 <= b < len(returns):
            strength = abs(returns[b] - returns[b - 1])
        elif b == 0 and len(returns) > 0:
            strength = abs(returns[b])
        else:
            strength = np.nan
        strengths.append(float(strength) if pd.notna(strength) else np.nan)

    return strengths


# ------------------------
# {銘柄, 日付} ペアを作成
# ------------------------
def build_symbol_date_pairs(change_point_summary: dict):
    pairs = []

    for symbol, rows in change_point_summary.items():
        for row in rows:
            pairs.append({
                "symbol": symbol,
                "date": row["date"],
                "strength": row["strength"],
            })

    pairs.sort(key=lambda x: (x["date"], x["symbol"]))
    return pairs


# ------------------------
# {銘柄, 日付} 形式で表示
# ------------------------
def print_pair_format(change_point_summary: dict):
    print("\n==============================")
    print("変化点一覧 {銘柄, 日付}")
    print("==============================")

    pairs = build_symbol_date_pairs(change_point_summary)

    if not pairs:
        print("データなし")
        return

    for row in pairs:
        print(
            f"{{{row['symbol']}, {row['date'].strftime('%Y-%m-%d %H:%M:%S')}}}"
        )


# ------------------------
# 銘柄別サマリーDataFrame作成
# ------------------------
def build_summary_dataframe(results: list):
    rows = []

    for r in results:
        cp_dates = r.get("change_points", [])
        cp_strengths = r.get("change_strengths", [])

        cp_dates_str = " | ".join(
            [d.strftime("%Y-%m-%d %H:%M:%S") for d in cp_dates]
        ) if cp_dates else ""

        cp_strengths_str = " | ".join(
            [f"{x:.6f}" for x in cp_strengths]
        ) if cp_strengths else ""

        rows.append({
            "symbol": r.get("symbol"),
            "rows": r.get("rows"),
            "return_rows": r.get("return_rows"),
            "start_time": r.get("start_time"),
            "end_time": r.get("end_time"),
            "min_price": r.get("min_price"),
            "max_price": r.get("max_price"),
            "last_price": r.get("last_price"),
            "mse": r.get("mse"),
            "rmse": r.get("rmse"),
            "n_change_points": len(cp_dates),
            "change_points": cp_dates_str,
            "change_strengths": cp_strengths_str,
        })

    return pd.DataFrame(rows)


# ------------------------
# {銘柄, 日付} 用DataFrame作成
# ------------------------
def build_pairs_dataframe(change_point_summary: dict):
    pairs = build_symbol_date_pairs(change_point_summary)

    if not pairs:
        return pd.DataFrame(columns=["symbol", "date", "strength"])

    df_pairs = pd.DataFrame(pairs)
    df_pairs["date"] = pd.to_datetime(df_pairs["date"], errors="coerce")
    return df_pairs


# ------------------------
# ランキング表示
# ------------------------
def print_rankings(summary_df: pd.DataFrame):
    print("\n==============================")
    print("ランキング")
    print("==============================")

    valid_rmse = summary_df.dropna(subset=["rmse"]).sort_values("rmse")
    if len(valid_rmse) > 0:
        print("\n[AR RMSE が小さい上位10件]")
        for i, (_, row) in enumerate(valid_rmse.head(10).iterrows(), start=1):
            print(f"{i}. {row['symbol']}  RMSE={row['rmse']:.6f}")

        print("\n[AR RMSE が大きい上位10件]")
        for i, (_, row) in enumerate(
            valid_rmse.sort_values("rmse", ascending=False).head(10).iterrows(),
            start=1
        ):
            print(f"{i}. {row['symbol']}  RMSE={row['rmse']:.6f}")
    else:
        print("\nRMSEを計算できた銘柄がありません。")

    cp_rank = summary_df.sort_values("n_change_points", ascending=False)
    if len(cp_rank) > 0:
        print("\n[変化点が多い上位10件]")
        for i, (_, row) in enumerate(cp_rank.head(10).iterrows(), start=1):
            print(f"{i}. {row['symbol']}  変化点数={int(row['n_change_points'])}")


# ------------------------
# メイン処理
# ------------------------
def main():
    random.seed(42)
    np.random.seed(42)

    coin_files = find_coin_files(DATA_DIR)

    if NUM_COINS > len(coin_files):
        raise ValueError(f"NUM_COINS={NUM_COINS} は CSV数 {len(coin_files)} を超えています。")

    log(f"=== {DATA_DIR} からランダムに {NUM_COINS} 個選択 ===")

    selected_files = random.sample(coin_files, NUM_COINS)

    print(f"選ばれた{NUM_COINS}ファイル:")
    for f in selected_files:
        print(" -", f.name)

    dfs = {}
    returns_map = {}
    results = []
    change_point_summary = {}

    # ------------------------
    # データ読み込み
    # ------------------------
    log("=== データ読み込み開始 ===")
    for idx, file_path in enumerate(selected_files, start=1):
        symbol = symbol_from_filename(file_path)

        try:
            log(f"({idx}/{NUM_COINS}) Loading {file_path.name} ...")
            df = load_coin_csv(file_path)
            ret_df = make_log_returns(df)

            dfs[symbol] = df
            returns_map[symbol] = ret_df

            log(
                f"[{symbol}] rows={len(df)} "
                f"period={df['timestamp'].iloc[0]} -> {df['timestamp'].iloc[-1]}"
            )
        except Exception as e:
            log(f"[{symbol}] 読み込み失敗: {e}")

    if not dfs:
        log("読み込めた銘柄がありません。終了します。")
        return None, None

    # ------------------------
    # AR + 変化点検知
    # ------------------------
    log("=== AR・変化点検知開始 ===")
    for symbol, df in dfs.items():
        ret_df = returns_map[symbol]

        mse = None
        rmse = None
        cp_dates = []
        cp_strengths = []

        try:
            mse, rmse = apply_ar_returns_in_sample(ret_df, symbol, lags=AR_LAGS)
        except Exception as e:
            log(f"[{symbol}] AR失敗: {e}")

        try:
            bkps, valid_bkps, returns_scaled, return_times = detect_change_points(
                ret_df,
                symbol,
                model_name=CHANGE_MODEL,
                pen_base=CHANGE_PEN_BASE,
                min_distance=MIN_CHANGE_DISTANCE,
            )
            summarize_change_points(ret_df, symbol, valid_bkps)
            cp_dates = extract_change_point_dates(ret_df, valid_bkps)
            cp_strengths = extract_change_point_strengths(ret_df, valid_bkps)

            change_point_summary[symbol] = [
                {"date": d, "strength": s}
                for d, s in zip(cp_dates, cp_strengths)
            ]
        except Exception as e:
            log(f"[{symbol}] 変化点検知失敗: {e}")
            change_point_summary[symbol] = []

        results.append({
            "symbol": symbol,
            "rows": len(df),
            "return_rows": len(ret_df),
            "start_time": df["timestamp"].iloc[0].strftime("%Y-%m-%d %H:%M:%S"),
            "end_time": df["timestamp"].iloc[-1].strftime("%Y-%m-%d %H:%M:%S"),
            "min_price": float(df["price"].min()),
            "max_price": float(df["price"].max()),
            "last_price": float(df["price"].iloc[-1]),
            "mse": mse,
            "rmse": rmse,
            "change_points": cp_dates,
            "change_strengths": cp_strengths,
        })

    # ------------------------
    # DataFrame化
    # ------------------------
    summary_df = build_summary_dataframe(results)
    pairs_df = build_pairs_dataframe(change_point_summary)

    # ------------------------
    # 銘柄別サマリー表示
    # ------------------------
    print("\n==============================")
    print("銘柄別サマリー")
    print("==============================")
    print(summary_df)

    # ------------------------
    # ランキング
    # ------------------------
    print_rankings(summary_df)

    # ------------------------
    # 最後に {銘柄, 日付} 形式で出力
    # ------------------------
    print_pair_format(change_point_summary)

    # ------------------------
    # DataFrame表示
    # ------------------------
    print("\n==============================")
    print("summary_df")
    print("==============================")
    print(summary_df)

    print("\n==============================")
    print("pairs_df")
    print("==============================")
    print(pairs_df)

    # ------------------------
    # CSV保存
    # ------------------------
    try:
        summary_df.to_csv(OUTPUT_SUMMARY_CSV, index=False, encoding="utf-8-sig")
        log(f"summary_df を保存しました: {OUTPUT_SUMMARY_CSV}")
    except Exception as e:
        log(f"summary_df 保存失敗: {e}")

    try:
        if len(pairs_df) > 0:
            pairs_df_to_save = pairs_df.copy()
            pairs_df_to_save["date"] = pairs_df_to_save["date"].dt.strftime("%Y-%m-%d %H:%M:%S")
            pairs_df_to_save.to_csv(OUTPUT_PAIRS_CSV, index=False, encoding="utf-8-sig")
            log(f"pairs_df を保存しました: {OUTPUT_PAIRS_CSV}")
        else:
            log("pairs_df は空のため CSV 保存をスキップしました。")
    except Exception as e:
        log(f"pairs_df 保存失敗: {e}")

    return summary_df, pairs_df


if __name__ == "__main__":
    summary_df, pairs_df = main()
# Out:
# [2026-04-11 01:33:37] === d:\musashino-university\finance\coingecko_by_coin からランダムに 100 個選択 ===
# 選ばれた100ファイル:
#  - sierra-2_sierra.csv
#  - cronos-zkevm-bridged-cro-cronos-zkevm_cro.csv
#  - baby-bottle_bott.csv
#  - usa_usat.csv
#  - gata_gata.csv
#  - football-world-community_fwc.csv
#  - fartful_fartful.csv
#  - degate_dg.csv
#  - coinxpad_cxpad.csv
#  - spodermen_spoody.csv
#  - proof-platform_proof.csv
#  - celo-australian-dollar_audm.csv
#  - sag3-ai-by-virtuals_sag3.csv
#  - moth-2_moth.csv
#  - based-doge_bdoge.csv
#  - wrapped-microstrategy-xstock_wmstrx.csv
#  - the-1-billion-horse_unicorn.csv
#  - epic-chain_epic.csv
#  - fight-for-justice_ffj.csv
#  - paraswap_psp.csv
#  - satori_sn119.csv
#  - topblast_bl4st.csv
#  - protoken_pro.csv
#  - el-gato-3_gato.csv
#  - titcoin-2_titcoin.csv
#  - mooncat_mooncat.csv
#  - vesper-finance_vsp.csv
#  - nest-mineral-vault_nmnrl.csv
#  - wifejak_wife.csv
#  - acet-token_act.csv
#  - diemlibre_dlb.csv
#  - starknet-brother_brother.csv
#  - imagen-ai_image.csv
#  - radium_val.csv
#  - diamond_dmd.csv
#  - solana-life_sol人生.csv
#  - yield-yak_yak.csv
#  - tweetdm_inbox.csv
#  - speculate-dao_spec.csv
#  - dragonmaster-token_dmt.csv
#  - black-panther-fi_black.csv
#  - ditto-staked-aptos_stapt.csv
#  - prosper_pros.csv
#  - nimiq-2_nim.csv
#  - goztepe-s-k-fan-token_goz.csv
#  - dapp_dapp.csv
#  - lil-bub-on-sol_bub.csv
#  - axel-win_axel.csv
#  - keyfi_keyfi.csv
#  - slurp-2_slurp.csv
#  - fuse-bridged-wbtc-fuse_wbtc.csv
#  - blobana-pet_blob.csv
#  - oddz_oddz.csv
#  - bifrost-voucher-eth_veth.csv
#  - productclank_$pro.csv
#  - delphinus-lab_zkwasm.csv
#  - hachiko-2_hachiko.csv
#  - green-shiba-inu_ginux.csv
#  - domenation-token_domen.csv
#  - gelato-2_gel.csv
#  - clustering_result.csv
#  - stafi_fis.csv
#  - nexo_nexo.csv
#  - xbanana_xbanana.csv
#  - saitabit_saitabit.csv
#  - kvants-ai_kvai.csv
#  - regent-2_regent.csv
#  - nyan-meme-coin_nyan.csv
#  - legal_legal.csv
#  - wrapped-ace_wace.csv
#  - lovely-inu-finance_lovely.csv
#  - shikoku-inu_shiko.csv
#  - enki-2_enki.csv
#  - otherdeedstrategy_deedstr.csv
#  - hypr_hypr.csv
#  - summary_100_20260325_101607.csv
#  - water-coin_water.csv
#  - mubarakah_mubarakah.csv
#  - dinari-amd_amd.d.csv
#  - brolana_bros.csv
#  - polymarket_poly.csv
# [2026-04-11 01:33:44] [ski-mask-pup_skipup] rows=1122 period=2025-12-25 02:01:52.204000 -> 2026-03-24 01:03:38.084000
# [2026-04-11 01:33:44] === AR・変化点検知開始 ===
# [2026-04-11 01:33:44] [sierra-2_sierra] AR(5) on returns: MSE=6.025890e-07, RMSE=7.762660e-04
# [2026-04-11 01:34:56] [sierra-2_sierra] change points (raw): [2035]
# [2026-04-11 01:34:56] [sierra-2_sierra] change points (filtered): []
#
# === sierra-2_sierra の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 01:34:56] [cronos-zkevm-bridged-cro-cronos-zkevm_cro] AR(5) on returns: MSE=4.096489e-05, RMSE=6.400382e-03
# [2026-04-11 01:37:05] [cronos-zkevm-bridged-cro-cronos-zkevm_cro] change points (raw): [2160]
# [2026-04-11 01:37:05] [cronos-zkevm-bridged-cro-cronos-zkevm_cro] change points (filtered): []
#
# === cronos-zkevm-bridged-cro-cronos-zkevm_cro の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 01:37:05] [baby-bottle_bott] AR(5) on returns: MSE=5.377472e-05, RMSE=7.333125e-03
# [2026-04-11 01:37:06] [baby-bottle_bott] change points (raw): [416]
# [2026-04-11 01:37:06] [baby-bottle_bott] change points (filtered): []
#
# === baby-bottle_bott の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 01:37:06] [usa_usat] AR(5) on returns: MSE=4.447447e-08, RMSE=2.108897e-04
# [2026-04-11 01:37:27] [usa_usat] change points (raw): [1356]
# [2026-04-11 01:37:27] [usa_usat] change points (filtered): []
#
# === usa_usat の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 01:37:27] [gata_gata] AR(5) on returns: MSE=3.685864e-04, RMSE=1.919861e-02
# [2026-04-11 01:39:01] [gata_gata] change points (raw): [300, 1290, 2161]
# [2026-04-11 01:39:01] [gata_gata] change points (filtered): [300, 1290]
#
# === gata_gata の変化点候補 ===
# 1. 2026-01-06 15:04:15 付近, log_return=-0.001447
# 2. 2026-02-16 21:04:16 付近, log_return=0.004112
# [2026-04-11 01:39:01] [football-world-community_fwc] AR(5) on returns: MSE=3.020575e-03, RMSE=5.495975e-02
# [2026-04-11 01:39:18] [football-world-community_fwc] change points (raw): [1130, 1355, 1615, 2161]
# [2026-04-11 01:39:18] [football-world-community_fwc] change points (filtered): [1130, 1355, 1615]
#
# === football-world-community_fwc の変化点候補 ===
# 1. 2026-02-10 05:03:05 付近, log_return=0.000499
# 2. 2026-02-19 14:00:41 付近, log_return=0.005964
# 3. 2026-03-02 10:02:48 付近, log_return=0.028134
# [2026-04-11 01:39:18] [fartful_fartful] AR(5) on returns: MSE=1.223118e-02, RMSE=1.105947e-01
# [2026-04-11 01:39:18] [fartful_fartful] change points (raw): [515]
# [2026-04-11 01:39:18] [fartful_fartful] change points (filtered): []
#
# === fartful_fartful の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 01:39:18] [degate_dg] AR(5) on returns: MSE=2.975273e-05, RMSE=5.454606e-03
# [2026-04-11 01:39:58] [degate_dg] change points (raw): [1606]
# [2026-04-11 01:39:58] [degate_dg] change points (filtered): []
#
# === degate_dg の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 01:39:58] [coinxpad_cxpad] AR(5) on returns: MSE=2.839027e-04, RMSE=1.684941e-02
# [2026-04-11 01:39:58] [coinxpad_cxpad] change points (raw): [295]
# [2026-04-11 01:39:58] [coinxpad_cxpad] change points (filtered): []
#
# === coinxpad_cxpad の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 01:39:58] [spodermen_spoody] AR(5) on returns: MSE=1.481915e-04, RMSE=1.217339e-02
# [2026-04-11 01:40:16] [spodermen_spoody] change points (raw): [1290]
# [2026-04-11 01:40:16] [spodermen_spoody] change points (filtered): []
#
# === spodermen_spoody の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 01:40:16] [proof-platform_proof] AR(5) on returns: MSE=1.674198e-04, RMSE=1.293908e-02
# [2026-04-11 01:40:48] [proof-platform_proof] change points (raw): [1503]
# [2026-04-11 01:40:48] [proof-platform_proof] change points (filtered): []
#
# === proof-platform_proof の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 01:40:48] [celo-australian-dollar_audm] AR(5) on returns: MSE=1.127574e-04, RMSE=1.061873e-02
# [2026-04-11 01:42:24] [celo-australian-dollar_audm] change points (raw): [2033]
# [2026-04-11 01:42:24] [celo-australian-dollar_audm] change points (filtered): []
#
# === celo-australian-dollar_audm の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 01:42:24] [sag3-ai-by-virtuals_sag3] AR(5) on returns: MSE=1.454229e-02, RMSE=1.205914e-01
# [2026-04-11 01:42:50] [sag3-ai-by-virtuals_sag3] change points (raw): [1451]
# [2026-04-11 01:42:50] [sag3-ai-by-virtuals_sag3] change points (filtered): []
#
# === sag3-ai-by-virtuals_sag3 の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 01:42:50] [moth-2_moth] AR(5) on returns: MSE=2.688286e-04, RMSE=1.639599e-02
# [2026-04-11 01:42:50] [moth-2_moth] change points (raw): [510]
# [2026-04-11 01:42:50] [moth-2_moth] change points (filtered): []
#
# === moth-2_moth の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 01:42:50] [based-doge_bdoge] AR(5) on returns: MSE=2.060885e-04, RMSE=1.435578e-02
# [2026-04-11 01:44:34] [based-doge_bdoge] change points (raw): [2066]
# [2026-04-11 01:44:34] [based-doge_bdoge] change points (filtered): []
#
# === based-doge_bdoge の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 01:44:34] [the-1-billion-horse_unicorn] AR(5) on returns: MSE=6.411099e-03, RMSE=8.006934e-02
# [2026-04-11 01:45:48] [the-1-billion-horse_unicorn] change points (raw): [360, 1954]
# [2026-04-11 01:45:48] [the-1-billion-horse_unicorn] change points (filtered): [360]
#
# === the-1-billion-horse_unicorn の変化点候補 ===
# 1. 2026-01-17 01:01:51 付近, log_return=-0.006816
# [2026-04-11 01:45:48] [epic-chain_epic] AR(5) on returns: MSE=1.030543e-04, RMSE=1.015156e-02
# [2026-04-11 01:47:52] [epic-chain_epic] change points (raw): [2161]
# [2026-04-11 01:47:52] [epic-chain_epic] change points (filtered): []
#
# === epic-chain_epic の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 01:47:52] [fight-for-justice_ffj] AR(5) on returns: MSE=2.108326e-04, RMSE=1.452007e-02
# [2026-04-11 01:47:53] [fight-for-justice_ffj] change points (raw): [428]
# [2026-04-11 01:47:53] [fight-for-justice_ffj] change points (filtered): []
#
# === fight-for-justice_ffj の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 01:47:53] [paraswap_psp] AR(5) on returns: MSE=1.698020e-02, RMSE=1.303081e-01
# [2026-04-11 01:49:56] [paraswap_psp] change points (raw): [2160]
# [2026-04-11 01:49:56] [paraswap_psp] change points (filtered): []
#
# === paraswap_psp の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 01:49:56] [satori_sn119] AR(5) on returns: MSE=2.000134e-04, RMSE=1.414261e-02
# [2026-04-11 01:50:26] [satori_sn119] change points (raw): [1491]
# [2026-04-11 01:50:26] [satori_sn119] change points (filtered): []
#
# === satori_sn119 の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 01:50:26] [topblast_bl4st] AR(5) on returns: MSE=2.838946e-05, RMSE=5.328176e-03
# [2026-04-11 01:50:26] [topblast_bl4st] change points (raw): [25]
# [2026-04-11 01:50:26] [topblast_bl4st] change points (filtered): []
#
# === topblast_bl4st の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 01:50:26] [protoken_pro] AR(5) on returns: MSE=1.233902e-04, RMSE=1.110812e-02
# [2026-04-11 01:50:33] [protoken_pro] change points (raw): [1075]
# [2026-04-11 01:50:33] [protoken_pro] change points (filtered): []
#
# === protoken_pro の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 01:50:33] [el-gato-3_gato] AR(5) on returns: MSE=1.549879e-04, RMSE=1.244941e-02
# [2026-04-11 01:50:37] [el-gato-3_gato] change points (raw): [832]
# [2026-04-11 01:50:37] [el-gato-3_gato] change points (filtered): []
#
# === el-gato-3_gato の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 01:50:37] [titcoin-2_titcoin] AR(5) on returns: MSE=3.368146e-04, RMSE=1.835251e-02
# [2026-04-11 01:52:42] [titcoin-2_titcoin] change points (raw): [2161]
# [2026-04-11 01:52:42] [titcoin-2_titcoin] change points (filtered): []
#
# === titcoin-2_titcoin の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 01:52:42] [mooncat_mooncat] AR(5) on returns: MSE=1.316792e-03, RMSE=3.628762e-02
# [2026-04-11 01:54:43] [mooncat_mooncat] change points (raw): [545, 2143]
# [2026-04-11 01:54:43] [mooncat_mooncat] change points (filtered): [545]
#
# === mooncat_mooncat の変化点候補 ===
# 1. 2026-01-16 20:02:54 付近, log_return=-0.000290
# [2026-04-11 01:54:43] [vesper-finance_vsp] AR(5) on returns: MSE=7.581022e-04, RMSE=2.753366e-02
# [2026-04-11 01:55:16] [vesper-finance_vsp] change points (raw): [615, 1614]
# [2026-04-11 01:55:16] [vesper-finance_vsp] change points (filtered): [615]
#
# === vesper-finance_vsp の変化点候補 ===
# 1. 2026-01-20 13:03:22 付近, log_return=0.000351
# [2026-04-11 01:55:16] [nest-mineral-vault_nmnrl] AR(5) on returns: MSE=7.670242e-09, RMSE=8.757992e-05
# [2026-04-11 01:57:19] [nest-mineral-vault_nmnrl] change points (raw): [2161]
# [2026-04-11 01:57:19] [nest-mineral-vault_nmnrl] change points (filtered): []
#
# === nest-mineral-vault_nmnrl の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 01:57:19] [wifejak_wife] AR(5) on returns: MSE=4.566436e-04, RMSE=2.136922e-02
# [2026-04-11 01:59:22] [wifejak_wife] change points (raw): [2159]
# [2026-04-11 01:59:22] [wifejak_wife] change points (filtered): []
#
# === wifejak_wife の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 01:59:22] [acet-token_act] AR(5) on returns: MSE=3.941255e-04, RMSE=1.985260e-02
# [2026-04-11 02:01:26] [acet-token_act] change points (raw): [2161]
# [2026-04-11 02:01:26] [acet-token_act] change points (filtered): []
#
# === acet-token_act の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:01:26] [diemlibre_dlb] AR(5) on returns: MSE=1.670244e-04, RMSE=1.292379e-02
# [2026-04-11 02:02:31] [diemlibre_dlb] change points (raw): [2131]
# [2026-04-11 02:02:31] [diemlibre_dlb] change points (filtered): []
#
# === diemlibre_dlb の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:02:31] [starknet-brother_brother] AR(5) on returns: MSE=6.786560e-04, RMSE=2.605103e-02
# [2026-04-11 02:03:21] [starknet-brother_brother] change points (raw): [1713]
# [2026-04-11 02:03:21] [starknet-brother_brother] change points (filtered): []
#
# === starknet-brother_brother の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:03:21] [imagen-ai_image] AR(5) on returns: MSE=7.160487e-04, RMSE=2.675909e-02
# [2026-04-11 02:04:15] [imagen-ai_image] change points (raw): [1743]
# [2026-04-11 02:04:15] [imagen-ai_image] change points (filtered): []
#
# === imagen-ai_image の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:04:15] [radium_val] AR(5) on returns: MSE=5.624205e-04, RMSE=2.371541e-02
# [2026-04-11 02:06:24] [radium_val] change points (raw): [2161]
# [2026-04-11 02:06:24] [radium_val] change points (filtered): []
#
# === radium_val の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:06:24] [diamond_dmd] AR(5) on returns: MSE=6.826307e-05, RMSE=8.262147e-03
# [2026-04-11 02:08:27] [diamond_dmd] change points (raw): [2160]
# [2026-04-11 02:08:27] [diamond_dmd] change points (filtered): []
#
# === diamond_dmd の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:08:27] [solana-life_sol人生] AR(5) on returns: MSE=6.220718e-03, RMSE=7.887153e-02
# [2026-04-11 02:08:28] [solana-life_sol人生] change points (raw): [421]
# [2026-04-11 02:08:28] [solana-life_sol人生] change points (filtered): []
#
# === solana-life_sol人生 の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:08:28] [yield-yak_yak] AR(5) on returns: MSE=7.212304e-05, RMSE=8.492528e-03
# [2026-04-11 02:10:32] [yield-yak_yak] change points (raw): [2161]
# [2026-04-11 02:10:32] [yield-yak_yak] change points (filtered): []
#
# === yield-yak_yak の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:10:32] [tweetdm_inbox] AR(5) on returns: MSE=2.490094e-04, RMSE=1.578003e-02
# [2026-04-11 02:10:37] [tweetdm_inbox] change points (raw): [913]
# [2026-04-11 02:10:37] [tweetdm_inbox] change points (filtered): []
#
# === tweetdm_inbox の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:10:37] [speculate-dao_spec] AR(5) on returns: MSE=1.530362e-03, RMSE=3.911984e-02
# [2026-04-11 02:10:37] [speculate-dao_spec] change points (raw): [89]
# [2026-04-11 02:10:37] [speculate-dao_spec] change points (filtered): []
#
# === speculate-dao_spec の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:10:37] [dragonmaster-token_dmt] AR(5) on returns: MSE=8.826608e-05, RMSE=9.395003e-03
# [2026-04-11 02:12:34] [dragonmaster-token_dmt] change points (raw): [2135]
# [2026-04-11 02:12:34] [dragonmaster-token_dmt] change points (filtered): []
#
# === dragonmaster-token_dmt の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:12:34] [black-panther-fi_black] AR(5) on returns: MSE=1.106068e-04, RMSE=1.051698e-02
# [2026-04-11 02:14:40] [black-panther-fi_black] change points (raw): [2161]
# [2026-04-11 02:14:40] [black-panther-fi_black] change points (filtered): []
#
# === black-panther-fi_black の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:14:40] [ditto-staked-aptos_stapt] AR(5) on returns: MSE=8.831478e-05, RMSE=9.397595e-03
# [2026-04-11 02:15:55] [ditto-staked-aptos_stapt] change points (raw): [1909]
# [2026-04-11 02:15:55] [ditto-staked-aptos_stapt] change points (filtered): []
#
# === ditto-staked-aptos_stapt の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:15:55] [prosper_pros] AR(5) on returns: MSE=6.198846e-03, RMSE=7.873275e-02
# [2026-04-11 02:17:55] [prosper_pros] change points (raw): [2142]
# [2026-04-11 02:17:55] [prosper_pros] change points (filtered): []
#
# === prosper_pros の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:17:55] [nimiq-2_nim] AR(5) on returns: MSE=1.058717e-04, RMSE=1.028940e-02
# [2026-04-11 02:19:59] [nimiq-2_nim] change points (raw): [2161]
# [2026-04-11 02:19:59] [nimiq-2_nim] change points (filtered): []
#
# === nimiq-2_nim の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:19:59] [goztepe-s-k-fan-token_goz] AR(5) on returns: MSE=1.100345e-04, RMSE=1.048973e-02
# [2026-04-11 02:22:04] [goztepe-s-k-fan-token_goz] change points (raw): [2161]
# [2026-04-11 02:22:04] [goztepe-s-k-fan-token_goz] change points (filtered): []
#
# === goztepe-s-k-fan-token_goz の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:22:04] [dapp_dapp] AR(5) on returns: MSE=8.120663e-05, RMSE=9.011472e-03
# [2026-04-11 02:24:10] [dapp_dapp] change points (raw): [2161]
# [2026-04-11 02:24:10] [dapp_dapp] change points (filtered): []
#
# === dapp_dapp の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:24:10] [lil-bub-on-sol_bub] AR(5) on returns: MSE=7.861907e-04, RMSE=2.803909e-02
# [2026-04-11 02:24:10] [lil-bub-on-sol_bub] change points (raw): [485]
# [2026-04-11 02:24:10] [lil-bub-on-sol_bub] change points (filtered): []
#
# === lil-bub-on-sol_bub の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:24:10] [axel-win_axel] AR(5) on returns: MSE=2.841357e-04, RMSE=1.685633e-02
# [2026-04-11 02:25:05] [axel-win_axel] change points (raw): [1758]
# [2026-04-11 02:25:05] [axel-win_axel] change points (filtered): []
#
# === axel-win_axel の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:25:05] [keyfi_keyfi] AR(5) on returns: MSE=8.463400e-02, RMSE=2.909192e-01
# [2026-04-11 02:26:55] [keyfi_keyfi] change points (raw): [2093]
# [2026-04-11 02:26:55] [keyfi_keyfi] change points (filtered): []
#
# === keyfi_keyfi の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:26:55] [slurp-2_slurp] AR(5) on returns: MSE=2.859512e-04, RMSE=1.691009e-02
# [2026-04-11 02:26:55] [slurp-2_slurp] change points (raw): [557]
# [2026-04-11 02:26:55] [slurp-2_slurp] change points (filtered): []
#
# === slurp-2_slurp の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:26:55] [fuse-bridged-wbtc-fuse_wbtc] AR(5) on returns: MSE=6.978225e-04, RMSE=2.641633e-02
# [2026-04-11 02:27:01] [fuse-bridged-wbtc-fuse_wbtc] change points (raw): [973]
# [2026-04-11 02:27:01] [fuse-bridged-wbtc-fuse_wbtc] change points (filtered): []
#
# === fuse-bridged-wbtc-fuse_wbtc の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:27:01] [blobana-pet_blob] AR(5) on returns: MSE=4.349950e-04, RMSE=2.085653e-02
# [2026-04-11 02:27:01] [blobana-pet_blob] change points (raw): [514]
# [2026-04-11 02:27:01] [blobana-pet_blob] change points (filtered): []
#
# === blobana-pet_blob の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:27:01] [oddz_oddz] AR(5) on returns: MSE=9.857241e-04, RMSE=3.139624e-02
# [2026-04-11 02:27:36] [oddz_oddz] change points (raw): [1683]
# [2026-04-11 02:27:36] [oddz_oddz] change points (filtered): []
#
# === oddz_oddz の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:27:36] [productclank_$pro] AR(5) on returns: MSE=2.185383e-04, RMSE=1.478304e-02
# [2026-04-11 02:29:01] [productclank_$pro] change points (raw): [1959]
# [2026-04-11 02:29:01] [productclank_$pro] change points (filtered): []
#
# === productclank_$pro の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:29:01] [delphinus-lab_zkwasm] AR(5) on returns: MSE=2.567066e-05, RMSE=5.066622e-03
# [2026-04-11 02:31:06] [delphinus-lab_zkwasm] change points (raw): [2161]
# [2026-04-11 02:31:06] [delphinus-lab_zkwasm] change points (filtered): []
#
# === delphinus-lab_zkwasm の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:31:06] [hachiko-2_hachiko] AR(5) on returns: MSE=4.828408e-04, RMSE=2.197364e-02
# [2026-04-11 02:31:06] [hachiko-2_hachiko] change points (raw): [294]
# [2026-04-11 02:31:06] [hachiko-2_hachiko] change points (filtered): []
#
# === hachiko-2_hachiko の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:31:06] [green-shiba-inu_ginux] AR(5) on returns: MSE=6.878117e-05, RMSE=8.293441e-03
# [2026-04-11 02:31:46] [green-shiba-inu_ginux] change points (raw): [1608]
# [2026-04-11 02:31:46] [green-shiba-inu_ginux] change points (filtered): []
#
# === green-shiba-inu_ginux の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:31:46] [gelato-2_gel] AR(5) on returns: MSE=3.683824e-04, RMSE=1.919329e-02
# [2026-04-11 02:32:48] [gelato-2_gel] change points (raw): [1811]
# [2026-04-11 02:32:48] [gelato-2_gel] change points (filtered): []
#
# === gelato-2_gel の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:32:48] [stafi_fis] AR(5) on returns: MSE=2.985843e-04, RMSE=1.727959e-02
# [2026-04-11 02:34:11] [stafi_fis] change points (raw): [1150, 2161]
# [2026-04-11 02:34:11] [stafi_fis] change points (filtered): [1150]
#
# === stafi_fis の変化点候補 ===
# 1. 2026-02-11 01:02:56 付近, log_return=0.008707
# [2026-04-11 02:34:11] [nexo_nexo] AR(5) on returns: MSE=5.113426e-05, RMSE=7.150823e-03
# [2026-04-11 02:36:04] [nexo_nexo] change points (raw): [2161]
# [2026-04-11 02:36:04] [nexo_nexo] change points (filtered): []
#
# === nexo_nexo の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:36:04] [xbanana_xbanana] 対数収益率データが短すぎるため AR をスキップします
# [2026-04-11 02:36:04] [xbanana_xbanana] 変化点検知用データが短すぎるためスキップします
#
# === xbanana_xbanana の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:36:04] [saitabit_saitabit] AR(5) on returns: MSE=1.386929e-04, RMSE=1.177680e-02
# [2026-04-11 02:36:05] [saitabit_saitabit] change points (raw): [468]
# [2026-04-11 02:36:05] [saitabit_saitabit] change points (filtered): []
#
# === saitabit_saitabit の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:36:05] [regent-2_regent] AR(5) on returns: MSE=9.184755e-04, RMSE=3.030636e-02
# [2026-04-11 02:38:09] [regent-2_regent] change points (raw): [2152]
# [2026-04-11 02:38:09] [regent-2_regent] change points (filtered): []
#
# === regent-2_regent の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:38:09] [nyan-meme-coin_nyan] AR(5) on returns: MSE=2.619264e-04, RMSE=1.618414e-02
# [2026-04-11 02:38:09] [nyan-meme-coin_nyan] change points (raw): [433]
# [2026-04-11 02:38:09] [nyan-meme-coin_nyan] change points (filtered): []
#
# === nyan-meme-coin_nyan の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:38:09] [legal_legal] AR(5) on returns: MSE=1.232285e-03, RMSE=3.510391e-02
# [2026-04-11 02:38:09] [legal_legal] change points (raw): [145]
# [2026-04-11 02:38:09] [legal_legal] change points (filtered): []
#
# === legal_legal の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:38:09] [lovely-inu-finance_lovely] AR(5) on returns: MSE=2.025980e-03, RMSE=4.501089e-02
# [2026-04-11 02:38:10] [lovely-inu-finance_lovely] change points (raw): [288]
# [2026-04-11 02:38:10] [lovely-inu-finance_lovely] change points (filtered): []
#
# === lovely-inu-finance_lovely の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:38:10] [shikoku-inu_shiko] AR(5) on returns: MSE=1.001623e-04, RMSE=1.000811e-02
# [2026-04-11 02:38:10] [shikoku-inu_shiko] change points (raw): [282]
# [2026-04-11 02:38:10] [shikoku-inu_shiko] change points (filtered): []
#
# === shikoku-inu_shiko の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:38:10] [enki-2_enki] AR(5) on returns: MSE=3.092200e-04, RMSE=1.758465e-02
# [2026-04-11 02:39:00] [enki-2_enki] change points (raw): [1723]
# [2026-04-11 02:39:00] [enki-2_enki] change points (filtered): []
#
# === enki-2_enki の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:39:00] [otherdeedstrategy_deedstr] AR(5) on returns: MSE=1.735770e-04, RMSE=1.317486e-02
# [2026-04-11 02:39:06] [otherdeedstrategy_deedstr] change points (raw): [984]
# [2026-04-11 02:39:06] [otherdeedstrategy_deedstr] change points (filtered): []
#
# === otherdeedstrategy_deedstr の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:39:06] [hypr_hypr] AR(5) on returns: MSE=1.455582e-04, RMSE=1.206475e-02
# [2026-04-11 02:39:39] [hypr_hypr] change points (raw): [1528]
# [2026-04-11 02:39:39] [hypr_hypr] change points (filtered): []
#
# === hypr_hypr の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:39:39] [water-coin_water] AR(5) on returns: MSE=3.815923e-03, RMSE=6.177316e-02
# [2026-04-11 02:41:44] [water-coin_water] change points (raw): [2161]
# [2026-04-11 02:41:44] [water-coin_water] change points (filtered): []
#
# === water-coin_water の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:41:44] [mubarakah_mubarakah] AR(5) on returns: MSE=7.490750e-04, RMSE=2.736923e-02
# [2026-04-11 02:43:47] [mubarakah_mubarakah] change points (raw): [2160]
# [2026-04-11 02:43:47] [mubarakah_mubarakah] change points (filtered): []
#
# === mubarakah_mubarakah の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:43:47] [brolana_bros] AR(5) on returns: MSE=8.282332e-05, RMSE=9.100732e-03
# [2026-04-11 02:45:47] [brolana_bros] change points (raw): [2144]
# [2026-04-11 02:45:47] [brolana_bros] change points (filtered): []
#
# === brolana_bros の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:45:47] [flat-earth-coin_flat] AR(5) on returns: MSE=3.627404e-04, RMSE=1.904574e-02
# [2026-04-11 02:45:55] [flat-earth-coin_flat] change points (raw): [1056]
# [2026-04-11 02:45:55] [flat-earth-coin_flat] change points (filtered): []
#
# === flat-earth-coin_flat の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:45:55] [ixirswap_ixir] AR(5) on returns: MSE=1.818224e-04, RMSE=1.348415e-02
# [2026-04-11 02:45:55] [ixirswap_ixir] change points (raw): [228]
# [2026-04-11 02:45:55] [ixirswap_ixir] change points (filtered): []
#
# === ixirswap_ixir の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:45:55] [poncho_poncho] AR(5) on returns: MSE=4.856407e-04, RMSE=2.203726e-02
# [2026-04-11 02:47:56] [poncho_poncho] change points (raw): [2144]
# [2026-04-11 02:47:56] [poncho_poncho] change points (filtered): []
#
# === poncho_poncho の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:47:56] [franklin_fly] AR(5) on returns: MSE=1.205862e-02, RMSE=1.098118e-01
# [2026-04-11 02:47:59] [franklin_fly] change points (raw): [865]
# [2026-04-11 02:47:59] [franklin_fly] change points (filtered): []
#
# === franklin_fly の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:47:59] [lendle_lend] AR(5) on returns: MSE=5.820961e-05, RMSE=7.629522e-03
# [2026-04-11 02:49:59] [lendle_lend] change points (raw): [2144]
# [2026-04-11 02:49:59] [lendle_lend] change points (filtered): []
#
# === lendle_lend の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:49:59] [gorilla-3_gorilla] AR(5) on returns: MSE=2.381810e-04, RMSE=1.543311e-02
# [2026-04-11 02:52:04] [gorilla-3_gorilla] change points (raw): [2161]
# [2026-04-11 02:52:04] [gorilla-3_gorilla] change points (filtered): []
#
# === gorilla-3_gorilla の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:52:04] [mustang_must] AR(5) on returns: MSE=9.983393e-05, RMSE=9.991693e-03
# [2026-04-11 02:52:05] [mustang_must] change points (raw): [530]
# [2026-04-11 02:52:05] [mustang_must] change points (filtered): []
#
# === mustang_must の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:52:05] [fredwilson_fredwilson] AR(5) on returns: MSE=1.050419e-03, RMSE=3.241017e-02
# [2026-04-11 02:52:11] [fredwilson_fredwilson] change points (raw): [955]
# [2026-04-11 02:52:11] [fredwilson_fredwilson] change points (filtered): []
#
# === fredwilson_fredwilson の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:52:11] [jade-currency_jade] AR(5) on returns: MSE=3.670561e-03, RMSE=6.058516e-02
# [2026-04-11 02:53:22] [jade-currency_jade] change points (raw): [1880]
# [2026-04-11 02:53:22] [jade-currency_jade] change points (filtered): []
#
# === jade-currency_jade の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:53:22] [cat-3_cat] AR(5) on returns: MSE=2.877815e-04, RMSE=1.696412e-02
# [2026-04-11 02:53:23] [cat-3_cat] change points (raw): [505]
# [2026-04-11 02:53:23] [cat-3_cat] change points (filtered): []
#
# === cat-3_cat の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:53:23] [networkcities_cities] AR(5) on returns: MSE=2.811572e-04, RMSE=1.676774e-02
# [2026-04-11 02:53:23] [networkcities_cities] change points (raw): [561]
# [2026-04-11 02:53:23] [networkcities_cities] change points (filtered): []
#
# === networkcities_cities の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:53:23] [shroom_shroom] AR(5) on returns: MSE=9.773112e-04, RMSE=3.126198e-02
# [2026-04-11 02:54:02] [shroom_shroom] change points (raw): [1609]
# [2026-04-11 02:54:02] [shroom_shroom] change points (filtered): []
#
# === shroom_shroom の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:54:02] [d-acc-2_d_acc] AR(5) on returns: MSE=2.985360e-04, RMSE=1.727819e-02
# [2026-04-11 02:54:02] [d-acc-2_d_acc] change points (raw): [499]
# [2026-04-11 02:54:02] [d-acc-2_d_acc] change points (filtered): []
#
# === d-acc-2_d_acc の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:54:02] [psyopcartoon_psycartoon] AR(5) on returns: MSE=1.749216e-03, RMSE=4.182363e-02
# [2026-04-11 02:54:11] [psyopcartoon_psycartoon] change points (raw): [145, 1082]
# [2026-04-11 02:54:11] [psyopcartoon_psycartoon] change points (filtered): [145]
#
# === psyopcartoon_psycartoon の変化点候補 ===
# 1. 2026-01-23 03:01:45 付近, log_return=0.015886
# [2026-04-11 02:54:11] [ape-man_apeman] AR(5) on returns: MSE=8.740280e-04, RMSE=2.956396e-02
# [2026-04-11 02:54:14] [ape-man_apeman] change points (raw): [849]
# [2026-04-11 02:54:14] [ape-man_apeman] change points (filtered): []
#
# === ape-man_apeman の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:54:14] [kilt-protocol-3_pr] AR(5) on returns: MSE=1.178328e-03, RMSE=3.432678e-02
# [2026-04-11 02:55:27] [kilt-protocol-3_pr] change points (raw): [1881]
# [2026-04-11 02:55:27] [kilt-protocol-3_pr] change points (filtered): []
#
# === kilt-protocol-3_pr の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:55:27] [populous_ppt] AR(5) on returns: MSE=3.681258e-03, RMSE=6.067337e-02
# [2026-04-11 02:57:12] [populous_ppt] change points (raw): [2062]
# [2026-04-11 02:57:12] [populous_ppt] change points (filtered): []
#
# === populous_ppt の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:57:12] [btc-2x-flexible-leverage-index_btc2x-fli] AR(5) on returns: MSE=1.795150e-04, RMSE=1.339832e-02
# [2026-04-11 02:57:19] [btc-2x-flexible-leverage-index_btc2x-fli] change points (raw): [1069]
# [2026-04-11 02:57:19] [btc-2x-flexible-leverage-index_btc2x-fli] change points (filtered): []
#
# === btc-2x-flexible-leverage-index_btc2x-fli の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 02:57:19] [ski-mask-pup_skipup] AR(5) on returns: MSE=2.439559e-04, RMSE=1.561909e-02
# [2026-04-11 02:57:28] [ski-mask-pup_skipup] change points (raw): [1121]
# [2026-04-11 02:57:28] [ski-mask-pup_skipup] change points (filtered): []
#
# === ski-mask-pup_skipup の変化点候補 ===
# 変化点は検出されませんでした。
#
# ==============================
# 銘柄別サマリー
# ==============================
#                                        symbol  rows  return_rows  \
# 0                             sierra-2_sierra  2036         2035
# 1   cronos-zkevm-bridged-cro-cronos-zkevm_cro  2161         2160
# 2                            baby-bottle_bott   417          416
# 3                                    usa_usat  1357         1356
# 4                                   gata_gata  2162         2161
# ..                                        ...   ...          ...
# 86                             ape-man_apeman   850          849
# 87                         kilt-protocol-3_pr  1882         1881
# 88                               populous_ppt  2063         2062
# 89   btc-2x-flexible-leverage-index_btc2x-fli  1070         1069
# 90                        ski-mask-pup_skipup  1122         1121
#
#              start_time             end_time     min_price     max_price  \
# 0   2025-12-27 18:01:55  2026-03-25 01:23:25  9.996964e-01  1.021463e+00
# 1   2025-12-25 02:01:56  2026-03-25 01:18:18  7.106241e-02  1.109233e-01
# 2   2025-12-25 02:02:41  2026-02-03 18:02:07  2.073446e-03  3.045811e-03
# 3   2026-01-27 15:01:44  2026-03-25 01:29:16  9.966710e-01  1.001865e+00
# 4   2025-12-25 02:03:32  2026-03-25 01:34:55  1.822309e-03  9.922231e-03
# ..                  ...                  ...           ...           ...
# 86  2025-12-25 02:01:10  2026-03-25 01:23:41  1.190366e-07  2.306255e-07
# 87  2026-01-04 16:01:40  2026-03-25 01:12:09  2.337472e-04  1.195274e-03
# 88  2025-12-25 02:03:07  2026-03-25 01:31:56  2.582736e-02  2.006543e-01
# 89  2025-12-25 02:01:25  2026-03-20 16:04:20  1.461504e+01  3.650170e+01
# 90  2025-12-25 02:01:52  2026-03-24 01:03:38  1.023677e-02  3.151036e-02
#
#       last_price           mse      rmse  n_change_points  \
# 0   1.018637e+00  6.025890e-07  0.000776                0
# 1   7.525723e-02  4.096489e-05  0.006400                0
# 2   2.073446e-03  5.377472e-05  0.007333                0
# 3   9.997934e-01  4.447447e-08  0.000211                0
# 4   1.847840e-03  3.685864e-04  0.019199                2
# ..           ...           ...       ...              ...
# 86  2.075570e-07  8.740280e-04  0.029564                0
# 87  3.217363e-04  1.178328e-03  0.034327                0
# 88  3.649733e-02  3.681258e-03  0.060673                0
# 89  1.763827e+01  1.795150e-04  0.013398                0
# 90  1.283881e-02  2.439559e-04  0.015619                0
#
#                                 change_points     change_strengths
# 0
# 1
# 2
# 3
# 4   2026-01-06 15:04:15 | 2026-02-16 21:04:16  0.015321 | 0.003044
# ..                                        ...                  ...
# 86
# 87
# 88
# 89
# 90
#
# [91 rows x 13 columns]
#
# ==============================
# ランキング
# ==============================
#
# [AR RMSE が小さい上位10件]
# 1. nest-mineral-vault_nmnrl  RMSE=0.000088
# 2. usa_usat  RMSE=0.000211
# 3. sierra-2_sierra  RMSE=0.000776
# 4. delphinus-lab_zkwasm  RMSE=0.005067
# 5. topblast_bl4st  RMSE=0.005328
# 6. degate_dg  RMSE=0.005455
# 7. cronos-zkevm-bridged-cro-cronos-zkevm_cro  RMSE=0.006400
# 8. nexo_nexo  RMSE=0.007151
# 9. baby-bottle_bott  RMSE=0.007333
# 10. lendle_lend  RMSE=0.007630
#
# [AR RMSE が大きい上位10件]
# 1. keyfi_keyfi  RMSE=0.290919
# 2. paraswap_psp  RMSE=0.130308
# 3. sag3-ai-by-virtuals_sag3  RMSE=0.120591
# 4. fartful_fartful  RMSE=0.110595
# 5. franklin_fly  RMSE=0.109812
# 6. the-1-billion-horse_unicorn  RMSE=0.080069
# 7. solana-life_sol人生  RMSE=0.078872
# 8. prosper_pros  RMSE=0.078733
# 9. water-coin_water  RMSE=0.061773
# 10. populous_ppt  RMSE=0.060673
#
# [変化点が多い上位10件]
# 1. football-world-community_fwc  変化点数=3
# 2. gata_gata  変化点数=2
# 3. the-1-billion-horse_unicorn  変化点数=1
# 4. vesper-finance_vsp  変化点数=1
# 5. mooncat_mooncat  変化点数=1
# 6. psyopcartoon_psycartoon  変化点数=1
# 7. stafi_fis  変化点数=1
# 8. degate_dg  変化点数=0
# 9. cronos-zkevm-bridged-cro-cronos-zkevm_cro  変化点数=0
# 10. baby-bottle_bott  変化点数=0
#
# ==============================
# 変化点一覧 {銘柄, 日付}
# ==============================
# {gata_gata, 2026-01-06 15:04:15}
# {mooncat_mooncat, 2026-01-16 20:02:54}
# {the-1-billion-horse_unicorn, 2026-01-17 01:01:51}
# {vesper-finance_vsp, 2026-01-20 13:03:22}
# {psyopcartoon_psycartoon, 2026-01-23 03:01:45}
# {football-world-community_fwc, 2026-02-10 05:03:05}
# {stafi_fis, 2026-02-11 01:02:56}
# {gata_gata, 2026-02-16 21:04:16}
# {football-world-community_fwc, 2026-02-19 14:00:41}
# {football-world-community_fwc, 2026-03-02 10:02:48}
#
# ==============================
# summary_df
# ==============================
#                                        symbol  rows  return_rows  \
# 0                             sierra-2_sierra  2036         2035
# 1   cronos-zkevm-bridged-cro-cronos-zkevm_cro  2161         2160
# 2                            baby-bottle_bott   417          416
# 3                                    usa_usat  1357         1356
