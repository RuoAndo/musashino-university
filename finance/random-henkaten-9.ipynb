# %%
import random
from pathlib import Path
from datetime import datetime

import pandas as pd
import numpy as np
from statsmodels.tsa.ar_model import AutoReg
import ruptures as rpt


# ------------------------
# 設定
# ------------------------
NUM_COINS = 100
DATA_DIR = Path.cwd() / "coingecko_by_coin"
OUTPUT_SUMMARY_CSV = Path.cwd() / "change_point_summary.csv"
OUTPUT_PAIRS_CSV = Path.cwd() / "change_point_pairs.csv"

AR_LAGS = 5
CHANGE_MODEL = "rbf"

# 変化点を今より多めに検出しやすくする設定
CHANGE_PEN_BASE = 1.0
MIN_CHANGE_DISTANCE = 2
CHANGE_MIN_SIZE = 2
CHANGE_JUMP = 1

PRICE_COL_CANDIDATES = ["price", "Price", "close", "Close"]
TIME_COL_CANDIDATES = ["timestamp", "Timestamp", "date", "Date", "time", "Time"]


def log(msg: str):
    print(f"[{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}] {msg}")


# ------------------------
# CSV一覧を取得
# ------------------------
def find_coin_files(data_dir: Path):
    if not data_dir.exists():
        raise FileNotFoundError(f"フォルダが見つかりません: {data_dir}")

    files = sorted(data_dir.glob("*.csv"))
    if not files:
        raise FileNotFoundError(f"CSVファイルが見つかりません: {data_dir}")

    return files


# ------------------------
# 列名を自動判定
# ------------------------
def detect_column(df: pd.DataFrame, candidates: list, col_type: str):
    for c in candidates:
        if c in df.columns:
            return c
    raise ValueError(
        f"{col_type}列が見つかりません。候補: {candidates}, 実際の列: {list(df.columns)}"
    )


# ------------------------
# CSV読み込み
# ------------------------
def load_coin_csv(file_path: Path):
    df = pd.read_csv(file_path)

    time_col = detect_column(df, TIME_COL_CANDIDATES, "時刻")
    price_col = detect_column(df, PRICE_COL_CANDIDATES, "価格")

    df = df[[time_col, price_col]].copy()
    df.columns = ["timestamp", "price"]

    df["timestamp"] = pd.to_datetime(df["timestamp"], errors="coerce")
    df["price"] = pd.to_numeric(df["price"], errors="coerce")

    df = df.dropna(subset=["timestamp", "price"]).copy()
    df = df[df["price"] > 0].copy()
    df = df.drop_duplicates(subset=["timestamp"]).sort_values("timestamp").reset_index(drop=True)

    if len(df) == 0:
        raise ValueError(f"有効なデータがありません: {file_path.name}")

    return df


# ------------------------
# ファイル名から銘柄名を推定
# ------------------------
def symbol_from_filename(file_path: Path):
    return file_path.stem


# ------------------------
# 対数収益率を作成
# ------------------------
def make_log_returns(df: pd.DataFrame):
    prices = df["price"].values.astype(float)

    if len(prices) < 2:
        return pd.DataFrame(columns=["timestamp", "log_return"])

    log_returns = np.diff(np.log(prices))
    return_times = df["timestamp"].iloc[1:].reset_index(drop=True)

    ret_df = pd.DataFrame({
        "timestamp": return_times,
        "log_return": log_returns
    })

    ret_df = ret_df.replace([np.inf, -np.inf], np.nan).dropna().reset_index(drop=True)
    return ret_df


# ------------------------
# AR を対数収益率に適用
# ------------------------
def apply_ar_returns_in_sample(ret_df: pd.DataFrame, symbol: str, lags: int = 5):
    series = pd.Series(ret_df["log_return"].values.astype(float))

    if len(series) <= lags + 5:
        log(f"[{symbol}] 対数収益率データが短すぎるため AR をスキップします")
        return None, None

    model = AutoReg(series, lags=lags, old_names=False)
    res = model.fit()

    fitted = res.fittedvalues
    actual = series.iloc[lags:]

    min_len = min(len(actual), len(fitted))
    actual = actual.iloc[:min_len]
    fitted = fitted.iloc[:min_len]

    mse = float(((actual.values - fitted.values) ** 2).mean())
    rmse = float(np.sqrt(mse))

    log(f"[{symbol}] AR({lags}) on returns: MSE={mse:.6e}, RMSE={rmse:.6e}")
    return mse, rmse


# ------------------------
# 変化点の間引き
# ------------------------
def filter_change_points_by_distance(bkps, min_distance):
    filtered = []
    for b in bkps:
        if not filtered or (b - filtered[-1] >= min_distance):
            filtered.append(b)
    return filtered


# ------------------------
# 変化点検知
# ------------------------
def detect_change_points(
    ret_df: pd.DataFrame,
    symbol: str,
    model_name="rbf",
    pen_base=1.0,
    min_distance=2,
    min_size=2,
    jump=1
):
    returns = ret_df["log_return"].values.astype(float)

    if len(returns) < 10:
        log(f"[{symbol}] 変化点検知用データが短すぎるためスキップします")
        return [], [], np.array([]), pd.Series(dtype="datetime64[ns]")

    std = returns.std()
    if std < 1e-12:
        log(f"[{symbol}] 収益率の分散がほぼ0のため変化点検知をスキップします")
        return [], [], returns, ret_df["timestamp"]

    returns_scaled = (returns - returns.mean()) / (std + 1e-8)
    signal = returns_scaled.reshape(-1, 1)

    pen_value = pen_base * np.log(len(signal))

    algo = rpt.Pelt(
        model=model_name,
        min_size=min_size,
        jump=jump
    ).fit(signal)

    bkps = algo.predict(pen=pen_value)

    valid_bkps = [b for b in bkps if b < len(returns)]
    valid_bkps = filter_change_points_by_distance(valid_bkps, min_distance)

    log(f"[{symbol}] pen_value={pen_value:.6f}")
    log(f"[{symbol}] change points (raw): {bkps}")
    log(f"[{symbol}] change points (filtered): {valid_bkps}")

    return bkps, valid_bkps, returns_scaled, ret_df["timestamp"]


# ------------------------
# 変化点候補の表示
# ------------------------
def summarize_change_points(ret_df: pd.DataFrame, symbol: str, valid_bkps):
    print(f"\n=== {symbol} の変化点候補 ===")

    if not valid_bkps:
        print("変化点は検出されませんでした。")
        return

    for i, b in enumerate(valid_bkps, start=1):
        if b < len(ret_df):
            t = ret_df["timestamp"].iloc[b]
            r = ret_df["log_return"].iloc[b]
            print(f"{i}. {t.strftime('%Y-%m-%d %H:%M:%S')} 付近, log_return={r:.6f}")


# ------------------------
# 変化点の日付抽出
# ------------------------
def extract_change_point_dates(ret_df: pd.DataFrame, valid_bkps):
    dates = []
    for b in valid_bkps:
        if b < len(ret_df):
            dates.append(ret_df["timestamp"].iloc[b])
    return dates


# ------------------------
# 変化点強度抽出
# ------------------------
def extract_change_point_strengths(ret_df: pd.DataFrame, valid_bkps):
    returns = ret_df["log_return"].values.astype(float)
    strengths = []

    for b in valid_bkps:
        if 1 <= b < len(returns):
            strength = abs(returns[b] - returns[b - 1])
        elif b == 0 and len(returns) > 0:
            strength = abs(returns[b])
        else:
            strength = np.nan
        strengths.append(float(strength) if pd.notna(strength) else np.nan)

    return strengths


# ------------------------
# {銘柄, 日付} ペアを作成
# ------------------------
def build_symbol_date_pairs(change_point_summary: dict):
    pairs = []

    for symbol, rows in change_point_summary.items():
        for row in rows:
            pairs.append({
                "symbol": symbol,
                "date": row["date"],
                "strength": row["strength"],
            })

    pairs.sort(key=lambda x: (x["date"], x["symbol"]))
    return pairs


# ------------------------
# {銘柄, 日付} 形式で表示
# ------------------------
def print_pair_format(change_point_summary: dict):
    print("\n==============================")
    print("変化点一覧 {銘柄, 日付}")
    print("==============================")

    pairs = build_symbol_date_pairs(change_point_summary)

    if not pairs:
        print("データなし")
        return

    for row in pairs:
        print(f"{{{row['symbol']}, {row['date'].strftime('%Y-%m-%d %H:%M:%S')}}}")


# ------------------------
# 銘柄別サマリーDataFrame作成
# ------------------------
def build_summary_dataframe(results: list):
    rows = []

    for r in results:
        cp_dates = r.get("change_points", [])
        cp_strengths = r.get("change_strengths", [])

        cp_dates_str = " | ".join(
            [d.strftime("%Y-%m-%d %H:%M:%S") for d in cp_dates]
        ) if cp_dates else ""

        cp_strengths_str = " | ".join(
            [f"{x:.6f}" for x in cp_strengths]
        ) if cp_strengths else ""

        rows.append({
            "symbol": r.get("symbol"),
            "rows": r.get("rows"),
            "return_rows": r.get("return_rows"),
            "start_time": r.get("start_time"),
            "end_time": r.get("end_time"),
            "min_price": r.get("min_price"),
            "max_price": r.get("max_price"),
            "last_price": r.get("last_price"),
            "mse": r.get("mse"),
            "rmse": r.get("rmse"),
            "n_change_points": len(cp_dates),
            "change_points": cp_dates_str,
            "change_strengths": cp_strengths_str,
        })

    return pd.DataFrame(rows)


# ------------------------
# {銘柄, 日付} 用DataFrame作成
# ------------------------
def build_pairs_dataframe(change_point_summary: dict):
    pairs = build_symbol_date_pairs(change_point_summary)

    if not pairs:
        return pd.DataFrame(columns=["symbol", "date", "strength"])

    df_pairs = pd.DataFrame(pairs)
    df_pairs["date"] = pd.to_datetime(df_pairs["date"], errors="coerce")
    return df_pairs


# ------------------------
# ランキング表示
# ------------------------
def print_rankings(summary_df: pd.DataFrame):
    print("\n==============================")
    print("ランキング")
    print("==============================")

    valid_rmse = summary_df.dropna(subset=["rmse"]).sort_values("rmse")
    if len(valid_rmse) > 0:
        print("\n[AR RMSE が小さい上位10件]")
        for i, (_, row) in enumerate(valid_rmse.head(10).iterrows(), start=1):
            print(f"{i}. {row['symbol']}  RMSE={row['rmse']:.6f}")

        print("\n[AR RMSE が大きい上位10件]")
        for i, (_, row) in enumerate(
            valid_rmse.sort_values("rmse", ascending=False).head(10).iterrows(),
            start=1
        ):
            print(f"{i}. {row['symbol']}  RMSE={row['rmse']:.6f}")
    else:
        print("\nRMSEを計算できた銘柄がありません。")

    cp_rank = summary_df.sort_values("n_change_points", ascending=False)
    if len(cp_rank) > 0:
        print("\n[変化点が多い上位10件]")
        for i, (_, row) in enumerate(cp_rank.head(10).iterrows(), start=1):
            print(f"{i}. {row['symbol']}  変化点数={int(row['n_change_points'])}")


# ------------------------
# メイン処理
# ------------------------
def main():
    random.seed(42)
    np.random.seed(42)

    coin_files = find_coin_files(DATA_DIR)

    if NUM_COINS > len(coin_files):
        raise ValueError(f"NUM_COINS={NUM_COINS} は CSV数 {len(coin_files)} を超えています。")

    log(f"=== {DATA_DIR} からランダムに {NUM_COINS} 個選択 ===")

    selected_files = random.sample(coin_files, NUM_COINS)

    print(f"選ばれた{NUM_COINS}ファイル:")
    for f in selected_files:
        print(" -", f.name)

    dfs = {}
    returns_map = {}
    results = []
    change_point_summary = {}

    # ------------------------
    # データ読み込み
    # ------------------------
    log("=== データ読み込み開始 ===")
    for idx, file_path in enumerate(selected_files, start=1):
        symbol = symbol_from_filename(file_path)

        try:
            log(f"({idx}/{NUM_COINS}) Loading {file_path.name} ...")
            df = load_coin_csv(file_path)
            ret_df = make_log_returns(df)

            dfs[symbol] = df
            returns_map[symbol] = ret_df

            log(
                f"[{symbol}] rows={len(df)} "
                f"period={df['timestamp'].iloc[0]} -> {df['timestamp'].iloc[-1]}"
            )
        except Exception as e:
            log(f"[{symbol}] 読み込み失敗: {e}")

    if not dfs:
        log("読み込めた銘柄がありません。終了します。")
        return None, None

    # ------------------------
    # AR + 変化点検知
    # ------------------------
    log("=== AR・変化点検知開始 ===")
    for symbol, df in dfs.items():
        ret_df = returns_map[symbol]

        mse = None
        rmse = None
        cp_dates = []
        cp_strengths = []

        try:
            mse, rmse = apply_ar_returns_in_sample(ret_df, symbol, lags=AR_LAGS)
        except Exception as e:
            log(f"[{symbol}] AR失敗: {e}")

        try:
            bkps, valid_bkps, returns_scaled, return_times = detect_change_points(
                ret_df,
                symbol,
                model_name=CHANGE_MODEL,
                pen_base=CHANGE_PEN_BASE,
                min_distance=MIN_CHANGE_DISTANCE,
                min_size=CHANGE_MIN_SIZE,
                jump=CHANGE_JUMP,
            )
            summarize_change_points(ret_df, symbol, valid_bkps)
            cp_dates = extract_change_point_dates(ret_df, valid_bkps)
            cp_strengths = extract_change_point_strengths(ret_df, valid_bkps)

            change_point_summary[symbol] = [
                {"date": d, "strength": s}
                for d, s in zip(cp_dates, cp_strengths)
            ]
        except Exception as e:
            log(f"[{symbol}] 変化点検知失敗: {e}")
            change_point_summary[symbol] = []

        results.append({
            "symbol": symbol,
            "rows": len(df),
            "return_rows": len(ret_df),
            "start_time": df["timestamp"].iloc[0].strftime("%Y-%m-%d %H:%M:%S"),
            "end_time": df["timestamp"].iloc[-1].strftime("%Y-%m-%d %H:%M:%S"),
            "min_price": float(df["price"].min()),
            "max_price": float(df["price"].max()),
            "last_price": float(df["price"].iloc[-1]),
            "mse": mse,
            "rmse": rmse,
            "change_points": cp_dates,
            "change_strengths": cp_strengths,
        })

    # ------------------------
    # DataFrame化
    # ------------------------
    summary_df = build_summary_dataframe(results)
    pairs_df = build_pairs_dataframe(change_point_summary)

    # ------------------------
    # 銘柄別サマリー表示
    # ------------------------
    print("\n==============================")
    print("銘柄別サマリー")
    print("==============================")
    print(summary_df)

    # ------------------------
    # ランキング
    # ------------------------
    print_rankings(summary_df)

    # ------------------------
    # 最後に {銘柄, 日付} 形式で出力
    # ------------------------
    print_pair_format(change_point_summary)

    # ------------------------
    # DataFrame表示
    # ------------------------
    print("\n==============================")
    print("summary_df")
    print("==============================")
    print(summary_df)

    print("\n==============================")
    print("pairs_df")
    print("==============================")
    print(pairs_df)

    # ------------------------
    # CSV保存
    # ------------------------
    try:
        summary_df.to_csv(OUTPUT_SUMMARY_CSV, index=False, encoding="utf-8-sig")
        log(f"summary_df を保存しました: {OUTPUT_SUMMARY_CSV}")
    except Exception as e:
        log(f"summary_df 保存失敗: {e}")

    try:
        if len(pairs_df) > 0:
            pairs_df_to_save = pairs_df.copy()
            pairs_df_to_save["date"] = pairs_df_to_save["date"].dt.strftime("%Y-%m-%d %H:%M:%S")
            pairs_df_to_save.to_csv(OUTPUT_PAIRS_CSV, index=False, encoding="utf-8-sig")
            log(f"pairs_df を保存しました: {OUTPUT_PAIRS_CSV}")
        else:
            log("pairs_df は空のため CSV 保存をスキップしました。")
    except Exception as e:
        log(f"pairs_df 保存失敗: {e}")

    return summary_df, pairs_df


if __name__ == "__main__":
    summary_df, pairs_df = main()
# Out:
# [2026-04-11 07:29:48] === d:\musashino-university\finance\coingecko_by_coin からランダムに 100 個選択 ===
# 選ばれた100ファイル:
#  - sierra-2_sierra.csv
#  - cronos-zkevm-bridged-cro-cronos-zkevm_cro.csv
#  - baby-bottle_bott.csv
#  - usa_usat.csv
#  - gata_gata.csv
#  - football-world-community_fwc.csv
#  - fartful_fartful.csv
#  - degate_dg.csv
#  - coinxpad_cxpad.csv
#  - spodermen_spoody.csv
#  - proof-platform_proof.csv
#  - celo-australian-dollar_audm.csv
#  - sag3-ai-by-virtuals_sag3.csv
#  - moth-2_moth.csv
#  - based-doge_bdoge.csv
#  - wrapped-microstrategy-xstock_wmstrx.csv
#  - the-1-billion-horse_unicorn.csv
#  - epic-chain_epic.csv
#  - fight-for-justice_ffj.csv
#  - paraswap_psp.csv
#  - satori_sn119.csv
#  - topblast_bl4st.csv
#  - protoken_pro.csv
#  - el-gato-3_gato.csv
#  - titcoin-2_titcoin.csv
#  - mooncat_mooncat.csv
#  - vesper-finance_vsp.csv
#  - nest-mineral-vault_nmnrl.csv
#  - wifejak_wife.csv
#  - acet-token_act.csv
#  - diemlibre_dlb.csv
#  - starknet-brother_brother.csv
#  - imagen-ai_image.csv
#  - radium_val.csv
#  - diamond_dmd.csv
#  - solana-life_sol人生.csv
#  - yield-yak_yak.csv
#  - tweetdm_inbox.csv
#  - speculate-dao_spec.csv
#  - dragonmaster-token_dmt.csv
#  - black-panther-fi_black.csv
#  - ditto-staked-aptos_stapt.csv
#  - prosper_pros.csv
#  - nimiq-2_nim.csv
#  - goztepe-s-k-fan-token_goz.csv
#  - dapp_dapp.csv
#  - lil-bub-on-sol_bub.csv
#  - axel-win_axel.csv
#  - keyfi_keyfi.csv
#  - slurp-2_slurp.csv
#  - fuse-bridged-wbtc-fuse_wbtc.csv
#  - blobana-pet_blob.csv
#  - oddz_oddz.csv
#  - bifrost-voucher-eth_veth.csv
#  - productclank_$pro.csv
#  - delphinus-lab_zkwasm.csv
#  - hachiko-2_hachiko.csv
#  - green-shiba-inu_ginux.csv
# [2026-04-11 07:51:03] [gata_gata] pen_value=7.678326
# [2026-04-11 07:51:03] [gata_gata] change points (raw): [300, 1291, 2161]
# [2026-04-11 07:51:03] [gata_gata] change points (filtered): [300, 1291]
#
# === gata_gata の変化点候補 ===
# 1. 2026-01-06 15:04:15 付近, log_return=-0.001447
# 2. 2026-02-16 22:09:07 付近, log_return=0.000023
# [2026-04-11 07:51:03] [football-world-community_fwc] AR(5) on returns: MSE=3.020575e-03, RMSE=5.495975e-02
# [2026-04-11 07:52:32] [football-world-community_fwc] pen_value=7.678326
# [2026-04-11 07:52:32] [football-world-community_fwc] change points (raw): [809, 1059, 1131, 1353, 1621, 2161]
# [2026-04-11 07:52:32] [football-world-community_fwc] change points (filtered): [809, 1059, 1131, 1353, 1621]
#
# === football-world-community_fwc の変化点候補 ===
# 1. 2026-01-27 20:01:39 付近, log_return=0.051361
# 2. 2026-02-07 06:04:11 付近, log_return=0.013605
# 3. 2026-02-10 06:02:45 付近, log_return=-0.176904
# 4. 2026-02-19 12:00:48 付近, log_return=0.014818
# 5. 2026-03-02 16:03:10 付近, log_return=0.037168
# [2026-04-11 07:52:32] [fartful_fartful] AR(5) on returns: MSE=1.223118e-02, RMSE=1.105947e-01
# [2026-04-11 07:52:46] [fartful_fartful] pen_value=6.244167
# [2026-04-11 07:52:46] [fartful_fartful] change points (raw): [515]
# [2026-04-11 07:52:46] [fartful_fartful] change points (filtered): []
#
# === fartful_fartful の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 07:52:46] [degate_dg] AR(5) on returns: MSE=2.975273e-05, RMSE=5.454606e-03
# [2026-04-11 08:09:20] [degate_dg] pen_value=7.381502
# [2026-04-11 08:09:20] [degate_dg] change points (raw): [1606]
# [2026-04-11 08:09:20] [degate_dg] change points (filtered): []
#
# === degate_dg の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 08:09:20] [coinxpad_cxpad] AR(5) on returns: MSE=2.839027e-04, RMSE=1.684941e-02
# [2026-04-11 08:09:22] [coinxpad_cxpad] pen_value=5.686975
# [2026-04-11 08:09:22] [coinxpad_cxpad] change points (raw): [295]
# [2026-04-11 08:09:22] [coinxpad_cxpad] change points (filtered): []
#
# === coinxpad_cxpad の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 08:09:22] [spodermen_spoody] AR(5) on returns: MSE=1.481915e-04, RMSE=1.217339e-02
# [2026-04-11 08:13:27] [spodermen_spoody] pen_value=7.162397
# [2026-04-11 08:13:27] [spodermen_spoody] change points (raw): [1290]
# [2026-04-11 08:13:27] [spodermen_spoody] change points (filtered): []
#
# === spodermen_spoody の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 08:13:27] [proof-platform_proof] AR(5) on returns: MSE=1.674198e-04, RMSE=1.293908e-02
# [2026-04-11 08:17:07] [proof-platform_proof] pen_value=7.315218
# [2026-04-11 08:17:07] [proof-platform_proof] change points (raw): [498, 1503]
# [2026-04-11 08:17:07] [proof-platform_proof] change points (filtered): [498]
#
# === proof-platform_proof の変化点候補 ===
# 1. 2026-01-20 07:02:49 付近, log_return=-0.017901
# [2026-04-11 08:17:07] [celo-australian-dollar_audm] AR(5) on returns: MSE=1.127574e-04, RMSE=1.061873e-02
# [2026-04-11 08:23:48] [celo-australian-dollar_audm] pen_value=7.617268
# [2026-04-11 08:23:48] [celo-australian-dollar_audm] change points (raw): [904, 972, 2033]
# [2026-04-11 08:23:48] [celo-australian-dollar_audm] change points (filtered): [904, 972]
#
# === celo-australian-dollar_audm の変化点候補 ===
# 1. 2026-02-04 01:00:44 付近, log_return=0.000382
# 2. 2026-02-06 21:02:55 付近, log_return=-0.000017
# [2026-04-11 08:23:48] [sag3-ai-by-virtuals_sag3] AR(5) on returns: MSE=1.454229e-02, RMSE=1.205914e-01
# [2026-04-11 08:24:51] [sag3-ai-by-virtuals_sag3] pen_value=7.280008
# [2026-04-11 08:24:51] [sag3-ai-by-virtuals_sag3] change points (raw): [516, 644, 1451]
# [2026-04-11 08:24:51] [sag3-ai-by-virtuals_sag3] change points (filtered): [516, 644]
#
# === sag3-ai-by-virtuals_sag3 の変化点候補 ===
# 1. 2026-01-15 23:04:05 付近, log_return=-0.001029
# 2. 2026-01-21 16:03:09 付近, log_return=-4.534605
# [2026-04-11 08:24:51] [moth-2_moth] AR(5) on returns: MSE=2.688286e-04, RMSE=1.639599e-02
# [2026-04-11 08:24:58] [moth-2_moth] pen_value=6.234411
# [2026-04-11 08:24:58] [moth-2_moth] change points (raw): [510]
# [2026-04-11 08:24:58] [moth-2_moth] change points (filtered): []
#
# === moth-2_moth の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 08:24:58] [based-doge_bdoge] AR(5) on returns: MSE=2.060885e-04, RMSE=1.435578e-02
# [2026-04-11 08:38:25] [based-doge_bdoge] pen_value=7.633370
# [2026-04-11 08:38:25] [based-doge_bdoge] change points (raw): [874, 1115, 2066]
# [2026-04-11 08:38:25] [based-doge_bdoge] change points (filtered): [874, 1115]
#
# === based-doge_bdoge の変化点候補 ===
# 1. 2026-01-31 07:01:15 付近, log_return=-0.008510
# 2. 2026-02-10 08:01:27 付近, log_return=0.001035
# [2026-04-11 08:38:25] [the-1-billion-horse_unicorn] AR(5) on returns: MSE=6.411099e-03, RMSE=8.006934e-02
# [2026-04-11 08:46:22] [the-1-billion-horse_unicorn] pen_value=7.577634
# [2026-04-11 08:46:22] [the-1-billion-horse_unicorn] change points (raw): [353, 1178, 1954]
# [2026-04-11 08:46:22] [the-1-billion-horse_unicorn] change points (filtered): [353, 1178]
#
# === the-1-billion-horse_unicorn の変化点候補 ===
# 1. 2026-01-16 18:01:46 付近, log_return=0.011534
# 2. 2026-02-20 03:03:40 付近, log_return=0.001830
# [2026-04-11 08:46:22] [epic-chain_epic] AR(5) on returns: MSE=1.030543e-04, RMSE=1.015156e-02
# [2026-04-11 09:39:23] [epic-chain_epic] pen_value=7.678326
# [2026-04-11 09:39:23] [epic-chain_epic] change points (raw): [2161]
# [2026-04-11 09:39:23] [epic-chain_epic] change points (filtered): []
#
# === epic-chain_epic の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 09:39:23] [fight-for-justice_ffj] AR(5) on returns: MSE=2.108326e-04, RMSE=1.452007e-02
# [2026-04-11 09:39:32] [fight-for-justice_ffj] pen_value=6.059123
# [2026-04-11 09:39:32] [fight-for-justice_ffj] change points (raw): [353, 428]
# [2026-04-11 09:39:32] [fight-for-justice_ffj] change points (filtered): [353]
#
# === fight-for-justice_ffj の変化点候補 ===
# 1. 2026-02-01 02:03:08 付近, log_return=-0.141694
# [2026-04-11 09:39:32] [paraswap_psp] AR(5) on returns: MSE=1.698020e-02, RMSE=1.303081e-01
# [2026-04-11 10:04:36] [paraswap_psp] pen_value=7.677864
# [2026-04-11 10:04:36] [paraswap_psp] change points (raw): [846, 2160]
# [2026-04-11 10:04:36] [paraswap_psp] change points (filtered): [846]
#
# === paraswap_psp の変化点候補 ===
# 1. 2026-01-29 10:00:40 付近, log_return=-0.017533
# [2026-04-11 10:04:36] [satori_sn119] AR(5) on returns: MSE=2.000134e-04, RMSE=1.414261e-02
# [2026-04-11 10:16:29] [satori_sn119] pen_value=7.307202
# [2026-04-11 10:16:29] [satori_sn119] change points (raw): [1491]
# [2026-04-11 10:16:29] [satori_sn119] change points (filtered): []
#
# === satori_sn119 の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 10:16:29] [topblast_bl4st] AR(5) on returns: MSE=2.838946e-05, RMSE=5.328176e-03
# [2026-04-11 10:16:29] [topblast_bl4st] pen_value=3.218876
# [2026-04-11 10:16:29] [topblast_bl4st] change points (raw): [25]
# [2026-04-11 10:16:29] [topblast_bl4st] change points (filtered): []
#
# === topblast_bl4st の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 10:16:29] [protoken_pro] AR(5) on returns: MSE=1.233902e-04, RMSE=1.110812e-02
# [2026-04-11 10:19:32] [protoken_pro] pen_value=6.980076
# [2026-04-11 10:19:32] [protoken_pro] change points (raw): [1075]
# [2026-04-11 10:19:32] [protoken_pro] change points (filtered): []
#
# === protoken_pro の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 10:19:32] [el-gato-3_gato] AR(5) on returns: MSE=1.549879e-04, RMSE=1.244941e-02
# [2026-04-11 10:19:58] [el-gato-3_gato] pen_value=6.723832
# [2026-04-11 10:19:58] [el-gato-3_gato] change points (raw): [832]
# [2026-04-11 10:19:58] [el-gato-3_gato] change points (filtered): []
#
# === el-gato-3_gato の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 10:19:58] [titcoin-2_titcoin] AR(5) on returns: MSE=3.368146e-04, RMSE=1.835251e-02
# [2026-04-11 10:42:12] [titcoin-2_titcoin] pen_value=7.678326
# [2026-04-11 10:42:12] [titcoin-2_titcoin] change points (raw): [228, 389, 1234, 2161]
# [2026-04-11 10:42:12] [titcoin-2_titcoin] change points (filtered): [228, 389, 1234]
#
# === titcoin-2_titcoin の変化点候補 ===
# 1. 2026-01-03 15:01:11 付近, log_return=0.010286
# 2. 2026-01-10 08:02:11 付近, log_return=0.002315
# 3. 2026-02-14 13:03:28 付近, log_return=0.002435
# [2026-04-11 10:42:12] [mooncat_mooncat] AR(5) on returns: MSE=1.316792e-03, RMSE=3.628762e-02
# [2026-04-11 11:06:10] [mooncat_mooncat] pen_value=7.669962
# [2026-04-11 11:06:10] [mooncat_mooncat] change points (raw): [543, 2143]
# [2026-04-11 11:06:10] [mooncat_mooncat] change points (filtered): [543]
#
# === mooncat_mooncat の変化点候補 ===
# 1. 2026-01-16 18:02:35 付近, log_return=0.001572
# [2026-04-11 11:06:10] [vesper-finance_vsp] AR(5) on returns: MSE=7.581022e-04, RMSE=2.753366e-02
# [2026-04-11 11:10:18] [vesper-finance_vsp] pen_value=7.386471
# [2026-04-11 11:10:18] [vesper-finance_vsp] change points (raw): [616, 1614]
# [2026-04-11 11:10:18] [vesper-finance_vsp] change points (filtered): [616]
#
# === vesper-finance_vsp の変化点候補 ===
# 1. 2026-01-20 14:03:43 付近, log_return=-0.010140
# [2026-04-11 11:10:18] [nest-mineral-vault_nmnrl] AR(5) on returns: MSE=7.670242e-09, RMSE=8.757992e-05
# [2026-04-11 11:59:03] [nest-mineral-vault_nmnrl] pen_value=7.678326
# [2026-04-11 11:59:03] [nest-mineral-vault_nmnrl] change points (raw): [2161]
# [2026-04-11 11:59:03] [nest-mineral-vault_nmnrl] change points (filtered): []
#
# === nest-mineral-vault_nmnrl の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 11:59:03] [wifejak_wife] AR(5) on returns: MSE=4.566436e-04, RMSE=2.136922e-02
# [2026-04-11 12:48:53] [wifejak_wife] pen_value=7.677400
# [2026-04-11 12:48:53] [wifejak_wife] change points (raw): [2159]
# [2026-04-11 12:48:53] [wifejak_wife] change points (filtered): []
#
# === wifejak_wife の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 12:48:53] [acet-token_act] AR(5) on returns: MSE=3.941255e-04, RMSE=1.985260e-02
# [2026-04-11 13:25:42] [acet-token_act] pen_value=7.678326
# [2026-04-11 13:25:42] [acet-token_act] change points (raw): [2161]
# [2026-04-11 13:25:42] [acet-token_act] change points (filtered): []
#
# === acet-token_act の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 13:25:42] [diemlibre_dlb] AR(5) on returns: MSE=1.670244e-04, RMSE=1.292379e-02
# [2026-04-11 13:36:25] [diemlibre_dlb] pen_value=7.664347
# [2026-04-11 13:36:25] [diemlibre_dlb] change points (raw): [455, 600, 1649, 2131]
# [2026-04-11 13:36:25] [diemlibre_dlb] change points (filtered): [455, 600, 1649]
#
# === diemlibre_dlb の変化点候補 ===
# 1. 2026-01-13 02:00:52 付近, log_return=-0.000020
# 2. 2026-01-20 09:00:59 付近, log_return=-0.006790
# 3. 2026-03-05 01:04:39 付近, log_return=0.002944
# [2026-04-11 13:36:25] [starknet-brother_brother] AR(5) on returns: MSE=6.786560e-04, RMSE=2.605103e-02
# [2026-04-11 13:39:29] [starknet-brother_brother] pen_value=7.446001
# [2026-04-11 13:39:29] [starknet-brother_brother] change points (raw): [825, 900, 1713]
# [2026-04-11 13:39:29] [starknet-brother_brother] change points (filtered): [825, 900]
#
# === starknet-brother_brother の変化点候補 ===
# 1. 2026-01-30 11:04:11 付近, log_return=0.001865
# 2. 2026-02-04 19:02:12 付近, log_return=-0.625663
# [2026-04-11 13:39:29] [imagen-ai_image] AR(5) on returns: MSE=7.160487e-04, RMSE=2.675909e-02
# [2026-04-11 13:46:33] [imagen-ai_image] pen_value=7.463363
# [2026-04-11 13:46:33] [imagen-ai_image] change points (raw): [701, 874, 1743]
# [2026-04-11 13:46:33] [imagen-ai_image] change points (filtered): [701, 874]
#
# === imagen-ai_image の変化点候補 ===
# 1. 2026-01-31 15:04:32 付近, log_return=-0.030113
# 2. 2026-02-07 21:03:47 付近, log_return=0.004685
# [2026-04-11 13:46:33] [radium_val] AR(5) on returns: MSE=5.624205e-04, RMSE=2.371541e-02
# [2026-04-11 14:31:53] [radium_val] pen_value=7.678326
# [2026-04-11 14:31:53] [radium_val] change points (raw): [441, 2161]
# [2026-04-11 14:31:53] [radium_val] change points (filtered): [441]
#
# === radium_val の変化点候補 ===
# 1. 2026-01-12 12:03:56 付近, log_return=-0.067861
# [2026-04-11 14:31:53] [diamond_dmd] AR(5) on returns: MSE=6.826307e-05, RMSE=8.262147e-03
# [2026-04-11 14:49:17] [diamond_dmd] pen_value=7.677864
# [2026-04-11 14:49:17] [diamond_dmd] change points (raw): [765, 2160]
# [2026-04-11 14:49:17] [diamond_dmd] change points (filtered): [765]
#
# === diamond_dmd の変化点候補 ===
# 1. 2026-01-26 01:01:54 付近, log_return=-0.011532
# [2026-04-11 14:49:17] [solana-life_sol人生] AR(5) on returns: MSE=6.220718e-03, RMSE=7.887153e-02
# [2026-04-11 14:49:23] [solana-life_sol人生] pen_value=6.042633
# [2026-04-11 14:49:23] [solana-life_sol人生] change points (raw): [163, 421]
# [2026-04-11 14:49:23] [solana-life_sol人生] change points (filtered): [163]
#
# === solana-life_sol人生 の変化点候補 ===
# 1. 2026-03-13 18:03:53 付近, log_return=-0.005822
# [2026-04-11 14:49:23] [yield-yak_yak] AR(5) on returns: MSE=7.212304e-05, RMSE=8.492528e-03
# [2026-04-11 15:22:21] [yield-yak_yak] pen_value=7.678326
# [2026-04-11 15:22:21] [yield-yak_yak] change points (raw): [2161]
# [2026-04-11 15:22:21] [yield-yak_yak] change points (filtered): []
#
# === yield-yak_yak の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 15:22:21] [tweetdm_inbox] AR(5) on returns: MSE=2.490094e-04, RMSE=1.578003e-02
# [2026-04-11 15:23:03] [tweetdm_inbox] pen_value=6.816736
# [2026-04-11 15:23:03] [tweetdm_inbox] change points (raw): [707, 913]
# [2026-04-11 15:23:03] [tweetdm_inbox] change points (filtered): [707]
#
# === tweetdm_inbox の変化点候補 ===
# 1. 2026-02-05 13:03:01 付近, log_return=-0.096332
# [2026-04-11 15:23:03] [speculate-dao_spec] AR(5) on returns: MSE=1.530362e-03, RMSE=3.911984e-02
# [2026-04-11 15:23:03] [speculate-dao_spec] pen_value=4.488636
# [2026-04-11 15:23:03] [speculate-dao_spec] change points (raw): [89]
# [2026-04-11 15:23:03] [speculate-dao_spec] change points (filtered): []
#
# === speculate-dao_spec の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 15:23:03] [dragonmaster-token_dmt] AR(5) on returns: MSE=8.826608e-05, RMSE=9.395003e-03
# [2026-04-11 15:34:39] [dragonmaster-token_dmt] pen_value=7.666222
# [2026-04-11 15:34:39] [dragonmaster-token_dmt] change points (raw): [851, 2135]
# [2026-04-11 15:34:39] [dragonmaster-token_dmt] change points (filtered): [851]
#
# === dragonmaster-token_dmt の変化点候補 ===
# 1. 2026-01-29 14:01:39 付近, log_return=0.007310
# [2026-04-11 15:34:39] [black-panther-fi_black] AR(5) on returns: MSE=1.106068e-04, RMSE=1.051698e-02
# [2026-04-11 16:21:02] [black-panther-fi_black] pen_value=7.678326
# [2026-04-11 16:21:02] [black-panther-fi_black] change points (raw): [2161]
# [2026-04-11 16:21:02] [black-panther-fi_black] change points (filtered): []
#
# === black-panther-fi_black の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 16:21:02] [ditto-staked-aptos_stapt] AR(5) on returns: MSE=8.831478e-05, RMSE=9.397595e-03
# [2026-04-11 16:45:34] [ditto-staked-aptos_stapt] pen_value=7.554335
# [2026-04-11 16:45:34] [ditto-staked-aptos_stapt] change points (raw): [1909]
# [2026-04-11 16:45:34] [ditto-staked-aptos_stapt] change points (filtered): []
#
# === ditto-staked-aptos_stapt の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 16:45:34] [prosper_pros] AR(5) on returns: MSE=6.198846e-03, RMSE=7.873275e-02
# [2026-04-11 17:21:05] [prosper_pros] pen_value=7.669495
# [2026-04-11 17:21:05] [prosper_pros] change points (raw): [648, 1175, 2142]
# [2026-04-11 17:21:05] [prosper_pros] change points (filtered): [648, 1175]
#
# === prosper_pros の変化点候補 ===
# 1. 2026-01-21 03:01:06 付近, log_return=0.013421
# 2. 2026-02-12 02:03:32 付近, log_return=0.003107
# [2026-04-11 17:21:05] [nimiq-2_nim] AR(5) on returns: MSE=1.058717e-04, RMSE=1.028940e-02
# [2026-04-11 17:25:46] [nimiq-2_nim] pen_value=7.678326
# [2026-04-11 17:25:46] [nimiq-2_nim] change points (raw): [597, 1010, 1414, 1654, 2161]
# [2026-04-11 17:25:46] [nimiq-2_nim] change points (filtered): [597, 1010, 1414, 1654]
#
# === nimiq-2_nim の変化点候補 ===
# 1. 2026-01-19 00:01:47 付近, log_return=0.005887
# 2. 2026-02-05 05:01:10 付近, log_return=0.002139
# 3. 2026-02-22 01:03:09 付近, log_return=-0.008294
# 4. 2026-03-04 00:01:39 付近, log_return=-0.001573
# [2026-04-11 17:25:46] [goztepe-s-k-fan-token_goz] AR(5) on returns: MSE=1.100345e-04, RMSE=1.048973e-02
# [2026-04-11 17:44:23] [goztepe-s-k-fan-token_goz] pen_value=7.678326
# [2026-04-11 17:44:23] [goztepe-s-k-fan-token_goz] change points (raw): [417, 879, 1054, 2161]
# [2026-04-11 17:44:23] [goztepe-s-k-fan-token_goz] change points (filtered): [417, 879, 1054]
#
# === goztepe-s-k-fan-token_goz の変化点候補 ===
# 1. 2026-01-11 12:01:35 付近, log_return=-0.006977
# 2. 2026-01-30 18:00:19 付近, log_return=0.074069
# 3. 2026-02-07 01:02:24 付近, log_return=-0.002360
# [2026-04-11 17:44:23] [dapp_dapp] AR(5) on returns: MSE=8.120663e-05, RMSE=9.011472e-03
# [2026-04-11 17:54:08] [dapp_dapp] pen_value=7.678326
# [2026-04-11 17:54:08] [dapp_dapp] change points (raw): [899, 1051, 2161]
# [2026-04-11 17:54:08] [dapp_dapp] change points (filtered): [899, 1051]
#
# === dapp_dapp の変化点候補 ===
# 1. 2026-01-31 14:03:11 付近, log_return=-0.015411
# 2. 2026-02-06 22:04:07 付近, log_return=0.004498
# [2026-04-11 17:54:08] [lil-bub-on-sol_bub] AR(5) on returns: MSE=7.861907e-04, RMSE=2.803909e-02
# [2026-04-11 17:54:17] [lil-bub-on-sol_bub] pen_value=6.184149
# [2026-04-11 17:54:17] [lil-bub-on-sol_bub] change points (raw): [485]
# [2026-04-11 17:54:17] [lil-bub-on-sol_bub] change points (filtered): []
#
# === lil-bub-on-sol_bub の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 17:54:17] [axel-win_axel] AR(5) on returns: MSE=2.841357e-04, RMSE=1.685633e-02
# [2026-04-11 18:20:07] [axel-win_axel] pen_value=7.471932
# [2026-04-11 18:20:07] [axel-win_axel] change points (raw): [1758]
# [2026-04-11 18:20:07] [axel-win_axel] change points (filtered): []
#
# === axel-win_axel の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 18:20:07] [keyfi_keyfi] AR(5) on returns: MSE=8.463400e-02, RMSE=2.909192e-01
# [2026-04-11 18:48:08] [keyfi_keyfi] pen_value=7.646354
# [2026-04-11 18:48:08] [keyfi_keyfi] change points (raw): [586, 2093]
# [2026-04-11 18:48:08] [keyfi_keyfi] change points (filtered): [586]
#
# === keyfi_keyfi の変化点候補 ===
# 1. 2026-01-20 05:01:28 付近, log_return=-1.116420
# [2026-04-11 18:48:08] [slurp-2_slurp] AR(5) on returns: MSE=2.859512e-04, RMSE=1.691009e-02
# [2026-04-11 18:48:23] [slurp-2_slurp] pen_value=6.322565
# [2026-04-11 18:48:23] [slurp-2_slurp] change points (raw): [557]
# [2026-04-11 18:48:23] [slurp-2_slurp] change points (filtered): []
#
# === slurp-2_slurp の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 18:48:23] [fuse-bridged-wbtc-fuse_wbtc] AR(5) on returns: MSE=6.978225e-04, RMSE=2.641633e-02
# [2026-04-11 18:50:30] [fuse-bridged-wbtc-fuse_wbtc] pen_value=6.880384
# [2026-04-11 18:50:30] [fuse-bridged-wbtc-fuse_wbtc] change points (raw): [973]
# [2026-04-11 18:50:30] [fuse-bridged-wbtc-fuse_wbtc] change points (filtered): []
#
# === fuse-bridged-wbtc-fuse_wbtc の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 18:50:30] [blobana-pet_blob] AR(5) on returns: MSE=4.349950e-04, RMSE=2.085653e-02
# [2026-04-11 18:50:40] [blobana-pet_blob] pen_value=6.242223
# [2026-04-11 18:50:40] [blobana-pet_blob] change points (raw): [514]
# [2026-04-11 18:50:40] [blobana-pet_blob] change points (filtered): []
#
# === blobana-pet_blob の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 18:50:40] [oddz_oddz] AR(5) on returns: MSE=9.857241e-04, RMSE=3.139624e-02
# [2026-04-11 18:51:49] [oddz_oddz] pen_value=7.428333
# [2026-04-11 18:51:49] [oddz_oddz] change points (raw): [332, 537, 1001, 1145, 1683]
# [2026-04-11 18:51:49] [oddz_oddz] change points (filtered): [332, 537, 1001, 1145]
#
# === oddz_oddz の変化点候補 ===
# 1. 2026-01-07 23:01:19 付近, log_return=0.000501
# 2. 2026-02-03 19:01:58 付近, log_return=0.093460
# 3. 2026-02-24 15:02:37 付近, log_return=-0.004525
# 4. 2026-03-02 18:01:39 付近, log_return=-0.018264
# [2026-04-11 18:51:49] [productclank_$pro] AR(5) on returns: MSE=2.185383e-04, RMSE=1.478304e-02
# [2026-04-11 18:57:27] [productclank_$pro] pen_value=7.580189
# [2026-04-11 18:57:27] [productclank_$pro] change points (raw): [849, 984, 1959]
# [2026-04-11 18:57:27] [productclank_$pro] change points (filtered): [849, 984]
#
# === productclank_$pro の変化点候補 ===
# 1. 2026-01-31 15:03:13 付近, log_return=-0.031929
# 2. 2026-02-07 02:02:57 付近, log_return=0.004575
# [2026-04-11 18:57:27] [delphinus-lab_zkwasm] AR(5) on returns: MSE=2.567066e-05, RMSE=5.066622e-03
# [2026-04-11 19:07:44] [delphinus-lab_zkwasm] pen_value=7.678326
# [2026-04-11 19:07:44] [delphinus-lab_zkwasm] change points (raw): [772, 1339, 2161]
# [2026-04-11 19:07:44] [delphinus-lab_zkwasm] change points (filtered): [772, 1339]
#
# === delphinus-lab_zkwasm の変化点候補 ===
# 1. 2026-01-26 07:03:51 付近, log_return=0.002528
# 2. 2026-02-18 22:02:15 付近, log_return=0.000939
# [2026-04-11 19:07:44] [hachiko-2_hachiko] AR(5) on returns: MSE=4.828408e-04, RMSE=2.197364e-02
# [2026-04-11 19:07:46] [hachiko-2_hachiko] pen_value=5.683580
# [2026-04-11 19:07:46] [hachiko-2_hachiko] change points (raw): [294]
# [2026-04-11 19:07:46] [hachiko-2_hachiko] change points (filtered): []
#
# === hachiko-2_hachiko の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 19:07:46] [green-shiba-inu_ginux] AR(5) on returns: MSE=6.878117e-05, RMSE=8.293441e-03
# [2026-04-11 19:11:51] [green-shiba-inu_ginux] pen_value=7.382746
# [2026-04-11 19:11:51] [green-shiba-inu_ginux] change points (raw): [587, 1608]
# [2026-04-11 19:11:51] [green-shiba-inu_ginux] change points (filtered): [587]
#
# === green-shiba-inu_ginux の変化点候補 ===
# 1. 2026-01-28 15:01:15 付近, log_return=-0.004356
# [2026-04-11 19:11:51] [gelato-2_gel] AR(5) on returns: MSE=3.683824e-04, RMSE=1.919329e-02
# [2026-04-11 19:36:14] [gelato-2_gel] pen_value=7.501634
# [2026-04-11 19:36:14] [gelato-2_gel] change points (raw): [1811]
# [2026-04-11 19:36:14] [gelato-2_gel] change points (filtered): []
#
# === gelato-2_gel の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 19:36:14] [stafi_fis] AR(5) on returns: MSE=2.985843e-04, RMSE=1.727959e-02
# [2026-04-11 19:43:52] [stafi_fis] pen_value=7.678326
# [2026-04-11 19:43:52] [stafi_fis] change points (raw): [370, 1104, 2161]
# [2026-04-11 19:43:52] [stafi_fis] change points (filtered): [370, 1104]
#
# === stafi_fis の変化点候補 ===
# 1. 2026-01-09 13:01:01 付近, log_return=0.016889
# 2. 2026-02-09 03:01:35 付近, log_return=-0.000257
# [2026-04-11 19:43:52] [nexo_nexo] AR(5) on returns: MSE=5.113426e-05, RMSE=7.150823e-03
# [2026-04-11 19:58:56] [nexo_nexo] pen_value=7.678326
# [2026-04-11 19:58:56] [nexo_nexo] change points (raw): [795, 1719, 2161]
# [2026-04-11 19:58:56] [nexo_nexo] change points (filtered): [795, 1719]
#
# === nexo_nexo の変化点候補 ===
# 1. 2026-01-27 06:01:55 付近, log_return=-0.004017
# 2. 2026-03-06 17:04:07 付近, log_return=-0.002228
# [2026-04-11 19:58:57] [xbanana_xbanana] 対数収益率データが短すぎるため AR をスキップします
# [2026-04-11 19:58:57] [xbanana_xbanana] 変化点検知用データが短すぎるためスキップします
#
# === xbanana_xbanana の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 19:58:57] [saitabit_saitabit] AR(5) on returns: MSE=1.386929e-04, RMSE=1.177680e-02
# [2026-04-11 19:59:04] [saitabit_saitabit] pen_value=6.148468
# [2026-04-11 19:59:04] [saitabit_saitabit] change points (raw): [468]
# [2026-04-11 19:59:04] [saitabit_saitabit] change points (filtered): []
#
# === saitabit_saitabit の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 19:59:04] [regent-2_regent] AR(5) on returns: MSE=9.184755e-04, RMSE=3.030636e-02
# [2026-04-11 20:31:00] [regent-2_regent] pen_value=7.674153
# [2026-04-11 20:31:00] [regent-2_regent] change points (raw): [627, 1886, 2152]
# [2026-04-11 20:31:00] [regent-2_regent] change points (filtered): [627, 1886]
#
# === regent-2_regent の変化点候補 ===
# 1. 2026-01-20 07:01:06 付近, log_return=-0.016778
# 2. 2026-03-13 20:03:40 付近, log_return=0.000395
# [2026-04-11 20:31:00] [nyan-meme-coin_nyan] AR(5) on returns: MSE=2.619264e-04, RMSE=1.618414e-02
# [2026-04-11 20:31:03] [nyan-meme-coin_nyan] pen_value=6.070738
# [2026-04-11 20:31:03] [nyan-meme-coin_nyan] change points (raw): [229, 433]
# [2026-04-11 20:31:03] [nyan-meme-coin_nyan] change points (filtered): [229]
#
# === nyan-meme-coin_nyan の変化点候補 ===
# 1. 2026-01-30 00:03:46 付近, log_return=-0.037658
# [2026-04-11 20:31:03] [legal_legal] AR(5) on returns: MSE=1.232285e-03, RMSE=3.510391e-02
# [2026-04-11 20:31:03] [legal_legal] pen_value=4.976734
# [2026-04-11 20:31:03] [legal_legal] change points (raw): [145]
# [2026-04-11 20:31:03] [legal_legal] change points (filtered): []
#
# === legal_legal の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 20:31:03] [lovely-inu-finance_lovely] AR(5) on returns: MSE=2.025980e-03, RMSE=4.501089e-02
# [2026-04-11 20:31:05] [lovely-inu-finance_lovely] pen_value=5.662960
# [2026-04-11 20:31:05] [lovely-inu-finance_lovely] change points (raw): [288]
# [2026-04-11 20:31:05] [lovely-inu-finance_lovely] change points (filtered): []
#
# === lovely-inu-finance_lovely の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 20:31:05] [shikoku-inu_shiko] AR(5) on returns: MSE=1.001623e-04, RMSE=1.000811e-02
# [2026-04-11 20:31:06] [shikoku-inu_shiko] pen_value=5.641907
# [2026-04-11 20:31:06] [shikoku-inu_shiko] change points (raw): [149, 282]
# [2026-04-11 20:31:06] [shikoku-inu_shiko] change points (filtered): [149]
#
# === shikoku-inu_shiko の変化点候補 ===
# 1. 2026-01-25 15:03:24 付近, log_return=-0.053941
# [2026-04-11 20:31:06] [enki-2_enki] AR(5) on returns: MSE=3.092200e-04, RMSE=1.758465e-02
# [2026-04-11 20:51:23] [enki-2_enki] pen_value=7.451822
# [2026-04-11 20:51:23] [enki-2_enki] change points (raw): [1723]
# [2026-04-11 20:51:23] [enki-2_enki] change points (filtered): []
#
# === enki-2_enki の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 20:51:23] [otherdeedstrategy_deedstr] AR(5) on returns: MSE=1.735770e-04, RMSE=1.317486e-02
# [2026-04-11 20:51:56] [otherdeedstrategy_deedstr] pen_value=6.891626
# [2026-04-11 20:51:56] [otherdeedstrategy_deedstr] change points (raw): [507, 623, 984]
# [2026-04-11 20:51:56] [otherdeedstrategy_deedstr] change points (filtered): [507, 623]
#
# === otherdeedstrategy_deedstr の変化点候補 ===
# 1. 2026-01-31 15:01:31 付近, log_return=-0.060116
# 2. 2026-02-07 09:01:06 付近, log_return=-0.001856
# [2026-04-11 20:51:56] [hypr_hypr] AR(5) on returns: MSE=1.455582e-04, RMSE=1.206475e-02
# [2026-04-11 20:55:17] [hypr_hypr] pen_value=7.331715
# [2026-04-11 20:55:17] [hypr_hypr] change points (raw): [796, 961, 1528]
# [2026-04-11 20:55:17] [hypr_hypr] change points (filtered): [796, 961]
#
# === hypr_hypr の変化点候補 ===
# 1. 2026-01-31 08:02:36 付近, log_return=-0.009031
# 2. 2026-02-07 09:03:00 付近, log_return=-0.002357
# [2026-04-11 20:55:17] [water-coin_water] AR(5) on returns: MSE=3.815923e-03, RMSE=6.177316e-02
# [2026-04-11 21:08:38] [water-coin_water] pen_value=7.678326
# [2026-04-11 21:08:38] [water-coin_water] change points (raw): [150, 835, 2161]
# [2026-04-11 21:08:38] [water-coin_water] change points (filtered): [150, 835]
#
# === water-coin_water の変化点候補 ===
# 1. 2025-12-31 09:02:31 付近, log_return=-0.018727
# 2. 2026-01-28 22:00:02 付近, log_return=-0.005011
# ...
# 1. 2026-02-02 14:03:22 付近, log_return=-0.190270
# [2026-04-11 22:45:11] [shroom_shroom] AR(5) on returns: MSE=9.773112e-04, RMSE=3.126198e-02
# [2026-04-11 22:55:45] [shroom_shroom] pen_value=7.383368
# [2026-04-11 22:55:45] [shroom_shroom] change points (raw): [1609]
# [2026-04-11 22:55:45] [shroom_shroom] change points (filtered): []
#
# === shroom_shroom の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 22:55:45] [d-acc-2_d_acc] AR(5) on returns: MSE=2.985360e-04, RMSE=1.727819e-02
# [2026-04-11 22:56:04] [d-acc-2_d_acc] pen_value=6.212606
# [2026-04-11 22:56:04] [d-acc-2_d_acc] change points (raw): [499]
# [2026-04-11 22:56:04] [d-acc-2_d_acc] change points (filtered): []
#
# === d-acc-2_d_acc の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 22:56:04] [psyopcartoon_psycartoon] AR(5) on returns: MSE=1.749216e-03, RMSE=4.182363e-02
# [2026-04-11 23:01:26] [psyopcartoon_psycartoon] pen_value=6.986566
# [2026-04-11 23:01:26] [psyopcartoon_psycartoon] change points (raw): [149, 1082]
# [2026-04-11 23:01:26] [psyopcartoon_psycartoon] change points (filtered): [149]
#
# === psyopcartoon_psycartoon の変化点候補 ===
# 1. 2026-01-23 07:04:31 付近, log_return=-0.001414
# [2026-04-11 23:01:26] [ape-man_apeman] AR(5) on returns: MSE=8.740280e-04, RMSE=2.956396e-02
# [2026-04-11 23:02:41] [ape-man_apeman] pen_value=6.744059
# [2026-04-11 23:02:41] [ape-man_apeman] change points (raw): [849]
# [2026-04-11 23:02:41] [ape-man_apeman] change points (filtered): []
#
# === ape-man_apeman の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 23:02:41] [kilt-protocol-3_pr] AR(5) on returns: MSE=1.178328e-03, RMSE=3.432678e-02
# [2026-04-11 23:11:31] [kilt-protocol-3_pr] pen_value=7.539559
# [2026-04-11 23:11:31] [kilt-protocol-3_pr] change points (raw): [657, 1881]
# [2026-04-11 23:11:31] [kilt-protocol-3_pr] change points (filtered): [657]
#
# === kilt-protocol-3_pr の変化点候補 ===
# 1. 2026-02-01 12:01:29 付近, log_return=0.027864
# [2026-04-11 23:11:31] [populous_ppt] AR(5) on returns: MSE=3.681258e-03, RMSE=6.067337e-02
# [2026-04-11 23:42:20] [populous_ppt] pen_value=7.631432
# [2026-04-11 23:42:20] [populous_ppt] change points (raw): [1066, 2062]
# [2026-04-11 23:42:20] [populous_ppt] change points (filtered): [1066]
#
# === populous_ppt の変化点候補 ===
# 1. 2026-02-07 17:03:40 付近, log_return=-0.001574
# [2026-04-11 23:42:20] [btc-2x-flexible-leverage-index_btc2x-fli] AR(5) on returns: MSE=1.795150e-04, RMSE=1.339832e-02
# [2026-04-11 23:45:39] [btc-2x-flexible-leverage-index_btc2x-fli] pen_value=6.974479
# [2026-04-11 23:45:39] [btc-2x-flexible-leverage-index_btc2x-fli] change points (raw): [1069]
# [2026-04-11 23:45:39] [btc-2x-flexible-leverage-index_btc2x-fli] change points (filtered): []
#
# === btc-2x-flexible-leverage-index_btc2x-fli の変化点候補 ===
# 変化点は検出されませんでした。
# [2026-04-11 23:45:39] [ski-mask-pup_skipup] AR(5) on returns: MSE=2.439559e-04, RMSE=1.561909e-02
# [2026-04-11 23:46:51] [ski-mask-pup_skipup] pen_value=7.021976
# [2026-04-11 23:46:51] [ski-mask-pup_skipup] change points (raw): [698, 1121]
# [2026-04-11 23:46:51] [ski-mask-pup_skipup] change points (filtered): [698]
#
# === ski-mask-pup_skipup の変化点候補 ===
# 1. 2026-01-31 19:02:26 付近, log_return=-0.146675
#
# ==============================
# 銘柄別サマリー
# ==============================
#                                        symbol  rows  return_rows  \
# 0                             sierra-2_sierra  2036         2035
# 1   cronos-zkevm-bridged-cro-cronos-zkevm_cro  2161         2160
# 2                            baby-bottle_bott   417          416
# 3                                    usa_usat  1357         1356
# 4                                   gata_gata  2162         2161
# ..                                        ...   ...          ...
# 86                             ape-man_apeman   850          849
# 87                         kilt-protocol-3_pr  1882         1881
# 88                               populous_ppt  2063         2062
# 89   btc-2x-flexible-leverage-index_btc2x-fli  1070         1069
# 90                        ski-mask-pup_skipup  1122         1121
#
#              start_time             end_time     min_price     max_price  \
# 0   2025-12-27 18:01:55  2026-03-25 01:23:25  9.996964e-01  1.021463e+00
# 1   2025-12-25 02:01:56  2026-03-25 01:18:18  7.106241e-02  1.109233e-01
# 2   2025-12-25 02:02:41  2026-02-03 18:02:07  2.073446e-03  3.045811e-03
# 3   2026-01-27 15:01:44  2026-03-25 01:29:16  9.966710e-01  1.001865e+00
# 4   2025-12-25 02:03:32  2026-03-25 01:34:55  1.822309e-03  9.922231e-03
# 6. mubarakah_mubarakah  変化点数=3
# 7. gorilla-3_gorilla  変化点数=3
# 8. titcoin-2_titcoin  変化点数=3
# 9. based-doge_bdoge  変化点数=2
# 10. gata_gata  変化点数=2
#
# ==============================
# 変化点一覧 {銘柄, 日付}
# ==============================
# {water-coin_water, 2025-12-31 09:02:31}
# {titcoin-2_titcoin, 2026-01-03 15:01:11}
# {fredwilson_fredwilson, 2026-01-05 17:01:43}
# {poncho_poncho, 2026-01-06 05:04:44}
# {gata_gata, 2026-01-06 15:04:15}
# {oddz_oddz, 2026-01-07 23:01:19}
# {mubarakah_mubarakah, 2026-01-09 00:04:45}
# {stafi_fis, 2026-01-09 13:01:01}
# {titcoin-2_titcoin, 2026-01-10 08:02:11}
# {mustang_must, 2026-01-10 14:01:29}
# {goztepe-s-k-fan-token_goz, 2026-01-11 12:01:35}
# {radium_val, 2026-01-12 12:03:56}
# {diemlibre_dlb, 2026-01-13 02:00:52}
# {mubarakah_mubarakah, 2026-01-15 12:04:34}
# {sag3-ai-by-virtuals_sag3, 2026-01-15 23:04:05}
# {the-1-billion-horse_unicorn, 2026-01-16 18:01:46}
# {mooncat_mooncat, 2026-01-16 18:02:35}
# {nimiq-2_nim, 2026-01-19 00:01:47}
# {keyfi_keyfi, 2026-01-20 05:01:28}
# {regent-2_regent, 2026-01-20 07:01:06}
# {proof-platform_proof, 2026-01-20 07:02:49}
# {diemlibre_dlb, 2026-01-20 09:00:59}
# {vesper-finance_vsp, 2026-01-20 14:03:43}
# {prosper_pros, 2026-01-21 03:01:06}
# {sag3-ai-by-virtuals_sag3, 2026-01-21 16:03:09}
# {psyopcartoon_psycartoon, 2026-01-23 07:04:31}
# {shikoku-inu_shiko, 2026-01-25 15:03:24}
# {diamond_dmd, 2026-01-26 01:01:54}
# {delphinus-lab_zkwasm, 2026-01-26 07:03:51}
# {nexo_nexo, 2026-01-27 06:01:55}
# {football-world-community_fwc, 2026-01-27 20:01:39}
# {green-shiba-inu_ginux, 2026-01-28 15:01:15}
# {water-coin_water, 2026-01-28 22:00:02}
# {paraswap_psp, 2026-01-29 10:00:40}
# {cronos-zkevm-bridged-cro-cronos-zkevm_cro, 2026-01-29 11:01:10}
# {dragonmaster-token_dmt, 2026-01-29 14:01:39}
# {gorilla-3_gorilla, 2026-01-29 15:01:57}
# {nyan-meme-coin_nyan, 2026-01-30 00:03:46}
# {starknet-brother_brother, 2026-01-30 11:04:11}
# {goztepe-s-k-fan-token_goz, 2026-01-30 18:00:19}
# {based-doge_bdoge, 2026-01-31 07:01:15}
# {hypr_hypr, 2026-01-31 08:02:36}
# {dapp_dapp, 2026-01-31 14:03:11}
# {otherdeedstrategy_deedstr, 2026-01-31 15:01:31}
# {productclank_$pro, 2026-01-31 15:03:13}
# {lendle_lend, 2026-01-31 15:03:48}
# {imagen-ai_image, 2026-01-31 15:04:32}
# {ski-mask-pup_skipup, 2026-01-31 19:02:26}
# {jade-currency_jade, 2026-01-31 21:04:32}
# {fredwilson_fredwilson, 2026-02-01 01:03:21}
