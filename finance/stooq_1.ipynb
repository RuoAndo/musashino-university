# %%
import yfinance as yf
import matplotlib.pyplot as plt

# 日本語フォント（Windows標準）
plt.rcParams["font.family"] = "Meiryo"   # だめなら "Yu Gothic" か "MS Gothic"

company = "トヨタ自動車"
ticker  = "7203.T"

df = yf.download(ticker, start="2020-01-01", end="2024-01-01")

plt.figure(figsize=(10,4))
plt.plot(df["Close"], label="Close")
plt.title(f"{company}（{ticker}）株価推移")
plt.xlabel("日付")
plt.ylabel("終値（JPY）")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# C:\Users\flare\AppData\Local\Temp\ipykernel_8688\1759122985.py:10: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2024-01-01")
# [*********************100%***********************]  1 of 1 completed
