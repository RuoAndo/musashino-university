# %%
import pandas as pd

TXS_FEATURES = "txs_features.txt"
TXS_CLASSES  = "txs_classes.txt"
TXS_EDGES    = "txs_edgelist.txt"

def main():
    print("Loading txs_features...")
    df_features = pd.read_csv(TXS_FEATURES)
    print("  shape:", df_features.shape)
    print("  columns:", list(df_features.columns[:10]), "...")

    print("\nLoading txs_classes...")
    df_classes = pd.read_csv(TXS_CLASSES)
    print("  shape:", df_classes.shape)
    print("  class unique:", df_classes["class"].unique())

    print("\nLoading txs_edgelist...")
    df_edges = pd.read_csv(TXS_EDGES)
    print("  shape:", df_edges.shape)

    # --- ここから追加（概要） ---
    print("\n=== Features overview ===")
    print(df_features.head())
    print(df_features.describe(include="all"))
    print("missing values:", int(df_features.isnull().sum().sum()))

    print("\nDone.")

if __name__ == "__main__":
    main()
# Out:
# Loading txs_features...
#   shape: (203769, 184)
#   columns: ['txId', 'Time step', 'Local_feature_1', 'Local_feature_2', 'Local_feature_3', 'Local_feature_4', 'Local_feature_5', 'Local_feature_6', 'Local_feature_7', 'Local_feature_8'] ...
#
# Loading txs_classes...
#   shape: (203769, 2)
#   class unique: [3 2 1]
#
# Loading txs_edgelist...
#   shape: (234355, 2)
#
# === Features overview ===
#     txId  Time step  Local_feature_1  Local_feature_2  Local_feature_3  \
# 0   3321          1        -0.169615        -0.184668        -1.201369
# 1  11108          1        -0.137586        -0.184668        -1.201369
# 2  51816          1        -0.170103        -0.184668        -1.201369
# 3  68869          1        -0.114267        -0.184668        -1.201369
# 4  89273          1         5.202107        -0.210553        -1.756361
#
#    Local_feature_4  Local_feature_5  Local_feature_6  Local_feature_7  \
# 0        -0.121970        -0.043875        -0.113002        -0.061584
# 1        -0.121970        -0.043875        -0.113002        -0.061584
# 2        -0.121970        -0.043875        -0.113002        -0.061584
# 3         0.028105        -0.043875        -0.113002         0.547008
# 4        -0.121970       260.090707        -0.113002        -0.061584
#
#    Local_feature_8  ...  in_BTC_min  in_BTC_max  in_BTC_mean  in_BTC_median  \
# 0        -0.160199  ...    0.534072    0.534072     0.534072       0.534072
# 1        -0.127429  ...    5.611878    5.611878     5.611878       5.611878
# 2        -0.160699  ...    0.456608    0.456608     0.456608       0.456608
# 3        -0.161652  ...    0.308900    8.000000     3.102967       1.000000
# 4         5.335864  ...  852.164680  852.164680   852.164680     852.164680
#
#    in_BTC_total   out_BTC_min  out_BTC_max  out_BTC_mean  out_BTC_median  \
# 0      0.534072  1.668990e-01     0.367074      0.266986        0.266986
# 1      5.611878  5.861940e-01     5.025584      2.805889        2.805889
# 2      0.456608  2.279902e-01     0.228518      0.228254        0.228254
# 3      9.308900  1.229000e+00     8.079800      4.654400        4.654400
# 4    852.164680  1.300000e-07    41.264036      0.065016        0.000441
#
#    out_BTC_total
# 0       0.533972
# 1       5.611778
# 2       0.456508
# 3       9.308800
# 4     852.164680
#
# [5 rows x 184 columns]
#                txId      Time step  Local_feature_1  Local_feature_2  \
# count  2.037690e+05  203769.000000     2.037690e+05     2.037690e+05
# mean   1.711310e+08      23.843961     1.841137e-17    -1.569151e-18
# std    1.104655e+08      15.172170     1.000002e+00     1.000002e+00
# min    1.076000e+03       1.000000    -1.729826e-01    -2.105526e-01
# 25%    8.433452e+07       9.000000    -1.725317e-01    -1.803266e-01
# 50%    1.624375e+08      23.000000    -1.692045e-01    -1.328975e-01
# 75%    2.454798e+08      38.000000    -1.318553e-01    -5.524241e-02
# max    4.032446e+08      49.000000     7.168197e+01     7.359505e+01
#
#        Local_feature_3  Local_feature_4  Local_feature_5  Local_feature_6  \
# count     2.037690e+05     2.037690e+05     2.037690e+05     2.037690e+05
# mean      4.017025e-17     6.252193e-17     7.465669e-17     5.976720e-17
# std       1.000002e+00     1.000002e+00     1.000002e+00     1.000002e+00
# min      -1.756361e+00    -1.219696e-01    -6.372457e-02    -1.130020e-01
# 25%      -1.201369e+00    -1.219696e-01    -4.387455e-02    -1.130020e-01
# 50%       4.636092e-01    -1.219696e-01    -4.387455e-02    -1.130020e-01
# 75%       1.018602e+00    -1.219696e-01    -4.387455e-02    -1.130020e-01
# max       2.683580e+00     4.902760e+01     2.600907e+02     5.456518e+01
#
#        Local_feature_7  Local_feature_8  ...    in_BTC_min     in_BTC_max  \
# count     2.037690e+05     2.037690e+05  ...  2.028040e+05  202804.000000
# mean      2.901185e-17     3.459105e-17  ...  2.546778e+01      26.747930
# std       1.000002e+00     1.000002e+00  ...  1.553120e+02     157.518993
# min      -6.158379e-02    -1.636459e-01  ...  1.000000e-08       0.000014
# 25%      -6.158379e-02    -1.635168e-01  ...  2.000000e-02       0.062014
# 50%      -6.158379e-02    -1.620440e-01  ...  2.500000e-01       0.515266
# 75%      -6.158379e-02    -1.355932e-01  ...  4.380933e+00       5.888565
# max       1.134409e+02     7.335457e+01  ...  1.139186e+04   11391.856516
#
#          in_BTC_mean  in_BTC_median   in_BTC_total    out_BTC_min  \
# count  202804.000000   2.028040e+05  202804.000000  202804.000000
# mean       25.855236   2.576747e+01      27.545372       0.630816
# std       155.485269   1.554777e+02     158.906122      10.991307
# min         0.000014   1.000000e-08       0.000041       0.000000
# 25%         0.050000   4.152000e-02       0.072955       0.002700
# 50%         0.409314   3.580544e-01       0.606800       0.015000
# 75%         4.998923   4.856507e+00       6.593047       0.100195
# max     11391.856516   1.139186e+04   11391.856516    2010.466695
#
#          out_BTC_max   out_BTC_mean  out_BTC_median  out_BTC_total
# count  202804.000000  202804.000000   202804.000000  202804.000000
# mean       26.508340      11.852566       11.363664      27.544559
# std       154.563163      67.111277       65.905428     158.906034
# min         0.000006       0.000006        0.000005       0.000006
# 25%         0.059000       0.035485        0.026874       0.072398
# 50%         0.500000       0.280447        0.215289       0.606105
# 75%         5.726287       2.618991        2.157049       6.590898
# max     11311.828314    2998.404230     2998.404230   11391.855937
#
# [8 rows x 184 columns]
# missing values: 16405
#
# Done.
