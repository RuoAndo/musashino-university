# %%
import networkx as nx
import matplotlib.pyplot as plt
import random
import numpy as np
import time
from datetime import datetime

from networkx.algorithms.approximation import (
    greedy_tsp,
    simulated_annealing_tsp
)

# =========================
# パラメータ
# =========================
NUM_NODES = 100
EDGE_PROB = 0.08

# ここを増やすと、多くの疎化手法で残すエッジ数が増える
SPARSIFY_RATIO = 0.5   # 0.3 から 0.5 に変更

SEED = 42

# k-core は小さいほどエッジが残りやすい
K_CORE = 2

# 各ノードが残す近傍エッジ数
LOCAL_TOP_K = 4        # 2 から 4 に変更

# 小さいほどエッジが残りやすい
SPANNER_STRETCH = 1.5  # 2 から 1.5 に変更

MAX_TSP_NODES = 30

SA_TEMP = 100
SA_MAX_ITERATIONS = 300
SA_N_INNER = 50
SA_TRIALS = 1
SA_MOVE = "1-1"

DRAW_GRAPHS = True
DRAW_TSP_PATHS = True
DRAW_TSP_SUMMARY_PLOTS = True

random.seed(SEED)
np.random.seed(SEED)

START_TIME = time.time()


# =========================
# ログ関数
# =========================
def now_str():
    return datetime.now().strftime("%Y-%m-%d %H:%M:%S")


def elapsed_str():
    sec = int(time.time() - START_TIME)
    h = sec // 3600
    m = (sec % 3600) // 60
    s = sec % 60
    return f"+{h:02d}:{m:02d}:{s:02d}"


def log(msg):
    print(f"[{now_str()} | {elapsed_str()}] {msg}", flush=True)


# =========================
# 元グラフ生成
# =========================
log("元グラフ生成開始")

G = nx.erdos_renyi_graph(
    n=NUM_NODES,
    p=EDGE_PROB,
    seed=SEED
)

for u, v in G.edges():
    G[u][v]["weight"] = random.random()

ORIGINAL_EDGE_COUNT = G.number_of_edges()

log(
    f"元グラフ生成完了: "
    f"nodes={G.number_of_nodes()}, edges={G.number_of_edges()}"
)

log(
    f"疎化設定: SPARSIFY_RATIO={SPARSIFY_RATIO}, "
    f"LOCAL_TOP_K={LOCAL_TOP_K}, "
    f"SPANNER_STRETCH={SPANNER_STRETCH}, "
    f"K_CORE={K_CORE}"
)


# =========================
# 共通関数
# =========================
def make_graph_from_edges(G, selected_edges):
    H = nx.Graph()
    H.add_nodes_from(G.nodes())

    for u, v in selected_edges:
        if G.has_edge(u, v):
            H.add_edge(u, v, **G[u][v])
        else:
            H.add_edge(u, v, weight=1.0)

    return H


def keep_top_edges_by_score(G, edge_scores, ratio):
    edges = list(G.edges())
    num_keep = max(1, int(len(edges) * ratio))

    sorted_edges = sorted(
        edges,
        key=lambda e: edge_scores.get(tuple(sorted(e)), 0),
        reverse=True
    )

    return make_graph_from_edges(G, sorted_edges[:num_keep])


def graph_stats(H):
    avg_degree = sum(dict(H.degree()).values()) / H.number_of_nodes()

    if H.number_of_edges() > 0:
        components = nx.number_connected_components(H)
        largest_cc_size = len(max(nx.connected_components(H), key=len))
    else:
        components = H.number_of_nodes()
        largest_cc_size = 1

    return avg_degree, components, largest_cc_size


def print_graph_info(name, H):
    avg_degree, components, largest_cc_size = graph_stats(H)
    edge_ratio = H.number_of_edges() / ORIGINAL_EDGE_COUNT if ORIGINAL_EDGE_COUNT > 0 else 0

    log(
        f"{name}: nodes={H.number_of_nodes()}, "
        f"edges={H.number_of_edges()}, "
        f"edge_ratio={edge_ratio:.2f}, "
        f"avg_degree={avg_degree:.2f}, "
        f"components={components}, "
        f"largest_cc={largest_cc_size}"
    )


# =========================
# 疎化手法
# =========================
def random_sparsification(G, ratio):
    log(f"Random疎化開始: ratio={ratio}")
    edges = list(G.edges())
    num_keep = max(1, int(len(edges) * ratio))
    sampled_edges = random.sample(edges, num_keep)
    H = make_graph_from_edges(G, sampled_edges)
    log(f"Random疎化完了: edges={H.number_of_edges()}")
    return H


def degree_based_sparsification(G, ratio):
    log(f"Degree疎化開始: ratio={ratio}")
    deg = dict(G.degree())

    edge_scores = {}
    for u, v in G.edges():
        edge_scores[tuple(sorted((u, v)))] = deg[u] + deg[v]

    H = keep_top_edges_by_score(G, edge_scores, ratio)
    log(f"Degree疎化完了: edges={H.number_of_edges()}")
    return H


def pagerank_based_sparsification(G, ratio):
    log(f"PageRank疎化開始: ratio={ratio}")
    pr = nx.pagerank(G, weight="weight")

    edge_scores = {}
    for u, v in G.edges():
        edge_scores[tuple(sorted((u, v)))] = pr[u] + pr[v]

    H = keep_top_edges_by_score(G, edge_scores, ratio)
    log(f"PageRank疎化完了: edges={H.number_of_edges()}")
    return H


def edge_betweenness_sparsification(G, ratio):
    log(f"Betweenness疎化開始: ratio={ratio}")
    eb = nx.edge_betweenness_centrality(G, weight="weight")

    edge_scores = {}
    for e, score in eb.items():
        edge_scores[tuple(sorted(e))] = score

    H = keep_top_edges_by_score(G, edge_scores, ratio)
    log(f"Betweenness疎化完了: edges={H.number_of_edges()}")
    return H


def k_core_sparsification(G, k):
    log(f"k-core疎化開始: k={k}")
    core = nx.k_core(G, k=k)

    H = nx.Graph()
    H.add_nodes_from(G.nodes())

    for u, v in core.edges():
        H.add_edge(u, v, **G[u][v])

    log(f"k-core疎化完了: edges={H.number_of_edges()}")
    return H


def weight_threshold_sparsification(G, ratio):
    log(f"Weight疎化開始: ratio={ratio}")
    edges = list(G.edges(data=True))
    num_keep = max(1, int(len(edges) * ratio))

    sorted_edges = sorted(
        edges,
        key=lambda x: x[2].get("weight", 0),
        reverse=True
    )

    selected_edges = [(u, v) for u, v, _ in sorted_edges[:num_keep]]
    H = make_graph_from_edges(G, selected_edges)

    log(f"Weight疎化完了: edges={H.number_of_edges()}")
    return H


def local_top_k_sparsification(G, k):
    log(f"Local Top-k疎化開始: k={k}")
    selected_edges = set()

    for node in G.nodes():
        neighbors = list(G.neighbors(node))

        scored_neighbors = []
        for nbr in neighbors:
            score = G[node][nbr].get("weight", 1.0)
            scored_neighbors.append((nbr, score))

        scored_neighbors.sort(key=lambda x: x[1], reverse=True)

        for nbr, _ in scored_neighbors[:k]:
            selected_edges.add(tuple(sorted((node, nbr))))

    H = make_graph_from_edges(G, list(selected_edges))
    log(f"Local Top-k疎化完了: edges={H.number_of_edges()}")
    return H


def effective_resistance_like_sparsification(G, ratio):
    log(f"Resistance-like疎化開始: ratio={ratio}")
    deg = dict(G.degree())

    edge_scores = {}
    for u, v in G.edges():
        score = 1 / max(1, deg[u]) + 1 / max(1, deg[v])
        edge_scores[tuple(sorted((u, v)))] = score

    H = keep_top_edges_by_score(G, edge_scores, ratio)
    log(f"Resistance-like疎化完了: edges={H.number_of_edges()}")
    return H


def spanner_like_sparsification(G, stretch=1.5):
    log(f"Spanner-like疎化開始: stretch={stretch}")

    H = nx.Graph()
    H.add_nodes_from(G.nodes())

    edges = list(G.edges(data=True))
    random.shuffle(edges)

    for u, v, data in edges:
        if not nx.has_path(H, u, v):
            H.add_edge(u, v, **data)
        else:
            try:
                dist = nx.shortest_path_length(H, u, v, weight="weight")
                direct_weight = data.get("weight", 1.0)

                if dist > stretch * direct_weight:
                    H.add_edge(u, v, **data)

            except nx.NetworkXNoPath:
                H.add_edge(u, v, **data)

    log(f"Spanner-like疎化完了: edges={H.number_of_edges()}")
    return H


# =========================
# TSP用関数
# =========================
def get_largest_connected_subgraph(H, name):
    log(f"{name}: 連結成分確認開始")

    if H.number_of_edges() == 0:
        log(f"{name}: エッジなし。TSP対象外")
        return None

    if nx.is_connected(H):
        T = H.copy()
        log(f"{name}: 連結グラフ")
    else:
        largest_cc = max(nx.connected_components(H), key=len)
        T = H.subgraph(largest_cc).copy()
        log(
            f"{name}: 非連結。最大連結成分を使用: "
            f"nodes={T.number_of_nodes()}, edges={T.number_of_edges()}"
        )

    if T.number_of_nodes() > MAX_TSP_NODES:
        sampled_nodes = random.sample(list(T.nodes()), MAX_TSP_NODES)
        T = T.subgraph(sampled_nodes).copy()

        if T.number_of_edges() > 0:
            largest_cc = max(nx.connected_components(T), key=len)
            T = T.subgraph(largest_cc).copy()

        log(
            f"{name}: TSP対象ノード数を制限: "
            f"nodes={T.number_of_nodes()}, MAX_TSP_NODES={MAX_TSP_NODES}"
        )

    if T.number_of_nodes() < 3:
        log(f"{name}: TSP対象ノードが少なすぎる")
        return None

    return T


def make_metric_complete_graph(T, name):
    log(f"{name}: TSP用完全グラフ作成開始")

    K = nx.Graph()
    K.add_nodes_from(T.nodes())

    lengths = dict(nx.all_pairs_dijkstra_path_length(T, weight="weight"))
    nodes = list(T.nodes())

    for i, u in enumerate(nodes):
        for v in nodes[i + 1:]:
            K.add_edge(u, v, weight=lengths[u][v])

    log(
        f"{name}: TSP用完全グラフ作成完了: "
        f"nodes={K.number_of_nodes()}, edges={K.number_of_edges()}"
    )

    return K


def compute_cycle_length(K, cycle):
    total = 0.0

    for u, v in zip(cycle[:-1], cycle[1:]):
        total += K[u][v]["weight"]

    return total


def make_random_cycle(K):
    nodes = list(K.nodes())
    random.shuffle(nodes)
    nodes.append(nodes[0])
    return nodes


def cycle_to_sparse_edges(T, cycle):
    tsp_edges = []

    for u, v in zip(cycle[:-1], cycle[1:]):
        path = nx.shortest_path(T, u, v, weight="weight")
        path_edges = list(zip(path[:-1], path[1:]))
        tsp_edges.extend(path_edges)

    return tsp_edges


def cycle_preview(cycle, max_items=20):
    if cycle is None:
        return "None"

    preview = cycle[:max_items]

    if len(cycle) > max_items:
        return " -> ".join(map(str, preview)) + " -> ..."
    else:
        return " -> ".join(map(str, cycle))


def solve_tsp_greedy(name, H):
    log(f"{name}: Greedy TSP開始")

    T = get_largest_connected_subgraph(H, name)

    if T is None:
        log(f"{name}: Greedy TSPスキップ")
        return None

    try:
        K = make_metric_complete_graph(T, name)

        t0 = time.time()
        cycle = greedy_tsp(K, weight="weight")
        length = compute_cycle_length(K, cycle)

        log(
            f"{name}: Greedy TSP完了: "
            f"length={length:.4f}, time={time.time() - t0:.2f}s"
        )

        log(f"{name}: Greedy cycle: {cycle_preview(cycle)}")

        return {
            "name": name,
            "method": "Greedy",
            "nodes": T.number_of_nodes(),
            "edges": T.number_of_edges(),
            "components": nx.number_connected_components(H),
            "used_largest_component": not nx.is_connected(H),
            "tsp_length": length,
            "cycle": cycle,
            "subgraph": T,
            "metric_graph": K
        }

    except Exception as e:
        log(f"[Greedy TSP failed] {name}: {e}")
        return None


def solve_tsp_simulated_annealing(name, H):
    log(f"{name}: SA TSP開始")

    T = get_largest_connected_subgraph(H, name)

    if T is None:
        log(f"{name}: SA TSPスキップ")
        return None

    try:
        K = make_metric_complete_graph(T, name)

        best_cycle = None
        best_length = float("inf")

        for trial in range(1, SA_TRIALS + 1):
            log(
                f"{name}: SA trial {trial}/{SA_TRIALS} 開始 "
                f"temp={SA_TEMP}, max_iter={SA_MAX_ITERATIONS}, "
                f"N_inner={SA_N_INNER}, move={SA_MOVE}"
            )

            init_cycle = make_random_cycle(K)
            init_length = compute_cycle_length(K, init_cycle)

            log(f"{name}: SA trial {trial} 初期解 length={init_length:.4f}")

            t0 = time.time()

            cycle = simulated_annealing_tsp(
                K,
                init_cycle=init_cycle,
                weight="weight",
                source=init_cycle[0],
                temp=SA_TEMP,
                move=SA_MOVE,
                max_iterations=SA_MAX_ITERATIONS,
                N_inner=SA_N_INNER
            )

            length = compute_cycle_length(K, cycle)
            elapsed = time.time() - t0

            if length < best_length:
                best_length = length
                best_cycle = cycle
                updated = "BEST更新"
            else:
                updated = "BEST更新なし"

            trial_improvement = (init_length - length) / init_length * 100

            log(
                f"{name}: SA trial {trial}/{SA_TRIALS} 完了 "
                f"init={init_length:.4f}, final={length:.4f}, "
                f"trial_improvement={trial_improvement:.2f}%, "
                f"best={best_length:.4f}, time={elapsed:.2f}s, {updated}"
            )

        log(f"{name}: SA TSP完了 best_length={best_length:.4f}")
        log(f"{name}: SA cycle: {cycle_preview(best_cycle)}")

        return {
            "name": name,
            "method": "SA",
            "nodes": T.number_of_nodes(),
            "edges": T.number_of_edges(),
            "components": nx.number_connected_components(H),
            "used_largest_component": not nx.is_connected(H),
            "tsp_length": best_length,
            "cycle": best_cycle,
            "subgraph": T,
            "metric_graph": K
        }

    except Exception as e:
        log(f"[SA TSP failed] {name}: {e}")
        return None


# =========================
# 疎化実行
# =========================
log("==============================")
log("疎化実行開始")
log("==============================")

graphs = {}

graphs["Original"] = G
print_graph_info("Original", graphs["Original"])

graphs["Random"] = random_sparsification(G, SPARSIFY_RATIO)
print_graph_info("Random", graphs["Random"])

graphs["Degree"] = degree_based_sparsification(G, SPARSIFY_RATIO)
print_graph_info("Degree", graphs["Degree"])

graphs["PageRank"] = pagerank_based_sparsification(G, SPARSIFY_RATIO)
print_graph_info("PageRank", graphs["PageRank"])

graphs["Betweenness"] = edge_betweenness_sparsification(G, SPARSIFY_RATIO)
print_graph_info("Betweenness", graphs["Betweenness"])

graphs["k-core"] = k_core_sparsification(G, K_CORE)
print_graph_info("k-core", graphs["k-core"])

graphs["Weight"] = weight_threshold_sparsification(G, SPARSIFY_RATIO)
print_graph_info("Weight", graphs["Weight"])

graphs["Local Top-k"] = local_top_k_sparsification(G, LOCAL_TOP_K)
print_graph_info("Local Top-k", graphs["Local Top-k"])

graphs["Resistance-like"] = effective_resistance_like_sparsification(G, SPARSIFY_RATIO)
print_graph_info("Resistance-like", graphs["Resistance-like"])

graphs["Spanner-like"] = spanner_like_sparsification(G, SPANNER_STRETCH)
print_graph_info("Spanner-like", graphs["Spanner-like"])

log("疎化実行完了")


# =========================
# TSP実行
# =========================
log("==============================")
log("TSP Results")
log("==============================")

tsp_results = {}

total_graphs = len(graphs)

for idx, (name, H) in enumerate(graphs.items(), start=1):
    log("--------------------------------------------------")
    log(f"[{idx}/{total_graphs}] {name}: TSP処理開始")

    greedy_result = solve_tsp_greedy(name, H)
    sa_result = solve_tsp_simulated_annealing(name, H)

    tsp_results[(name, "Greedy")] = greedy_result
    tsp_results[(name, "SA")] = sa_result

    greedy_len = None if greedy_result is None else greedy_result["tsp_length"]
    sa_len = None if sa_result is None else sa_result["tsp_length"]

    if greedy_len is None and sa_len is None:
        log(f"{name:16s}: TSP failed or too small")
    else:
        base_result = greedy_result if greedy_result is not None else sa_result

        used = (
            "largest component"
            if base_result["used_largest_component"]
            else "all nodes"
        )

        log(
            f"{name:16s} "
            f"nodes={base_result['nodes']:3d} "
            f"edges={base_result['edges']:4d} "
            f"components={base_result['components']:3d} "
            f"greedy={greedy_len if greedy_len is not None else 'NA'} "
            f"SA={sa_len if sa_len is not None else 'NA'} "
            f"used={used}"
        )

    log(f"[{idx}/{total_graphs}] {name}: TSP処理完了")


# =========================
# 改善率表示
# =========================
log("==============================")
log("TSP Improvement Summary")
log("==============================")

summary_names = []
summary_greedy = []
summary_sa = []
summary_improvement = []
summary_edge_ratio = []
summary_edge_count = []
summary_sa_nodes = []
summary_components = []

for name in graphs.keys():
    greedy_result = tsp_results.get((name, "Greedy"))
    sa_result = tsp_results.get((name, "SA"))

    if greedy_result is None or sa_result is None:
        log(f"{name:16s}: skipped")
        continue

    greedy_len = greedy_result["tsp_length"]
    sa_len = sa_result["tsp_length"]
    improvement = (greedy_len - sa_len) / greedy_len * 100
    edge_count = graphs[name].number_of_edges()
    edge_ratio = edge_count / G.number_of_edges()

    summary_names.append(name)
    summary_greedy.append(greedy_len)
    summary_sa.append(sa_len)
    summary_improvement.append(improvement)
    summary_edge_ratio.append(edge_ratio)
    summary_edge_count.append(edge_count)
    summary_sa_nodes.append(sa_result["nodes"])
    summary_components.append(sa_result["components"])

    log(
        f"{name:16s} "
        f"edges={edge_count:4d} "
        f"edge_ratio={edge_ratio:.2f} "
        f"greedy={greedy_len:.4f} "
        f"SA={sa_len:.4f} "
        f"improvement={improvement:.2f}%"
    )


# =========================
# グラフ描画
# =========================
if DRAW_GRAPHS:
    log("グラフ描画開始")

    pos = nx.spring_layout(G, seed=SEED)

    num_graphs = len(graphs)
    cols = 5
    rows = int(np.ceil(num_graphs / cols))

    fig, axes = plt.subplots(rows, cols, figsize=(14, rows * 5))
    axes = axes.flatten()

    for ax, (name, H) in zip(axes, graphs.items()):
        nx.draw(
            H,
            pos,
            ax=ax,
            node_size=35,
            width=0.6,
            with_labels=False
        )

        ax.set_title(
            f"{name}\n"
            f"Edges: {H.number_of_edges()}"
        )

    for i in range(len(graphs), len(axes)):
        axes[i].axis("off")

    plt.tight_layout()
    plt.show()

    log("グラフ描画完了")


# =========================
# TSP経路描画
# =========================
if DRAW_TSP_PATHS:
    log("TSP経路描画開始")

    pos = nx.spring_layout(G, seed=SEED)

    valid_sa_results = {
        name: result
        for (name, method), result in tsp_results.items()
        if method == "SA" and result is not None
    }

    num_tsp = len(valid_sa_results)

    if num_tsp > 0:
        cols = 5
        rows = int(np.ceil(num_tsp / cols))

        fig, axes = plt.subplots(rows, cols, figsize=(14, rows * 5))

        if num_tsp == 1:
            axes = np.array([axes])

        axes = axes.flatten()

        for ax, (name, result) in zip(axes, valid_sa_results.items()):
            T = result["subgraph"]
            cycle = result["cycle"]

            tsp_edges = cycle_to_sparse_edges(T, cycle)

            nx.draw(
                T,
                pos,
                ax=ax,
                node_size=35,
                width=0.4,
                with_labels=False
            )

            nx.draw_networkx_edges(
                T,
                pos,
                edgelist=tsp_edges,
                ax=ax,
                width=2.0
            )

            ax.set_title(
                f"SA TSP: {name}\n"
                f"nodes={result['nodes']}, "
                f"edges={result['edges']}, "
                f"length={result['tsp_length']:.4f}"
            )

        for i in range(num_tsp, len(axes)):
            axes[i].axis("off")

        plt.tight_layout()
        plt.show()

    log("TSP経路描画完了")


# =========================
# TSP結果プロット
# =========================
if DRAW_TSP_SUMMARY_PLOTS and len(summary_names) > 0:
    log("TSP結果プロット開始")

    x = np.arange(len(summary_names))
    width = 0.35

    plt.figure(figsize=(12, 6))
    plt.bar(x - width / 2, summary_greedy, width, label="Greedy")
    plt.bar(x + width / 2, summary_sa, width, label="SA")
    plt.xticks(x, summary_names, rotation=30)
    plt.ylabel("TSP Distance")
    plt.title("Greedy vs Simulated Annealing TSP Distance")
    plt.legend()
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(12, 6))
    plt.bar(summary_names, summary_improvement)
    plt.xticks(rotation=30)
    plt.ylabel("Improvement (%)")
    plt.title("SA Improvement Rate over Greedy")
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(8, 6))
    plt.scatter(summary_edge_ratio, summary_sa)

    for i, name in enumerate(summary_names):
        plt.text(summary_edge_ratio[i], summary_sa[i], name)

    plt.xlabel("Edge Ratio")
    plt.ylabel("SA TSP Distance")
    plt.title("Edge Ratio vs SA TSP Distance")
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(8, 6))
    plt.scatter(summary_edge_count, summary_sa)

    for i, name in enumerate(summary_names):
        plt.text(summary_edge_count[i], summary_sa[i], name)

    plt.xlabel("Number of Edges")
    plt.ylabel("SA TSP Distance")
    plt.title("Number of Edges vs SA TSP Distance")
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(8, 6))
    plt.scatter(summary_components, summary_sa)

    for i, name in enumerate(summary_names):
        plt.text(summary_components[i], summary_sa[i], name)

    plt.xlabel("Number of Components")
    plt.ylabel("SA TSP Distance")
    plt.title("Components vs SA TSP Distance")
    plt.tight_layout()
    plt.show()

    log("TSP結果プロット完了")


log("全処理完了")
# Out:
# [2026-05-28 10:22:08 | +00:00:00] 元グラフ生成開始
# [2026-05-28 10:22:08 | +00:00:00] 元グラフ生成完了: nodes=100, edges=371
# [2026-05-28 10:22:08 | +00:00:00] 疎化設定: SPARSIFY_RATIO=0.5, LOCAL_TOP_K=4, SPANNER_STRETCH=1.5, K_CORE=2
# [2026-05-28 10:22:08 | +00:00:00] ==============================
# [2026-05-28 10:22:08 | +00:00:00] 疎化実行開始
# [2026-05-28 10:22:08 | +00:00:00] ==============================
# [2026-05-28 10:22:08 | +00:00:00] Original: nodes=100, edges=371, edge_ratio=1.00, avg_degree=7.42, components=1, largest_cc=100
# [2026-05-28 10:22:08 | +00:00:00] Random疎化開始: ratio=0.5
# [2026-05-28 10:22:08 | +00:00:00] Random疎化完了: edges=185
# [2026-05-28 10:22:08 | +00:00:00] Random: nodes=100, edges=185, edge_ratio=0.50, avg_degree=3.70, components=3, largest_cc=98
# [2026-05-28 10:22:08 | +00:00:00] Degree疎化開始: ratio=0.5
# [2026-05-28 10:22:08 | +00:00:00] Degree疎化完了: edges=185
# [2026-05-28 10:22:08 | +00:00:00] Degree: nodes=100, edges=185, edge_ratio=0.50, avg_degree=3.70, components=24, largest_cc=77
# [2026-05-28 10:22:08 | +00:00:00] PageRank疎化開始: ratio=0.5
# [2026-05-28 10:22:08 | +00:00:00] PageRank疎化完了: edges=185
# [2026-05-28 10:22:08 | +00:00:00] PageRank: nodes=100, edges=185, edge_ratio=0.50, avg_degree=3.70, components=18, largest_cc=83
# [2026-05-28 10:22:08 | +00:00:00] Betweenness疎化開始: ratio=0.5
# [2026-05-28 10:22:08 | +00:00:00] Betweenness疎化完了: edges=185
# [2026-05-28 10:22:08 | +00:00:00] Betweenness: nodes=100, edges=185, edge_ratio=0.50, avg_degree=3.70, components=1, largest_cc=100
# [2026-05-28 10:22:08 | +00:00:00] k-core疎化開始: k=2
# [2026-05-28 10:22:08 | +00:00:00] k-core疎化完了: edges=370
# [2026-05-28 10:22:08 | +00:00:00] k-core: nodes=100, edges=370, edge_ratio=1.00, avg_degree=7.40, components=2, largest_cc=99
# [2026-05-28 10:22:08 | +00:00:00] Weight疎化開始: ratio=0.5
# [2026-05-28 10:22:08 | +00:00:00] Weight疎化完了: edges=185
# [2026-05-28 10:22:08 | +00:00:00] Weight: nodes=100, edges=185, edge_ratio=0.50, avg_degree=3.70, components=2, largest_cc=99
# [2026-05-28 10:22:08 | +00:00:00] Local Top-k疎化開始: k=4
# [2026-05-28 10:22:08 | +00:00:00] Local Top-k疎化完了: edges=240
# [2026-05-28 10:22:08 | +00:00:00] Local Top-k: nodes=100, edges=240, edge_ratio=0.65, avg_degree=4.80, components=1, largest_cc=100
# [2026-05-28 10:22:08 | +00:00:00] Resistance-like疎化開始: ratio=0.5
# [2026-05-28 10:22:08 | +00:00:00] Resistance-like疎化完了: edges=185
# [2026-05-28 10:22:08 | +00:00:00] Resistance-like: nodes=100, edges=185, edge_ratio=0.50, avg_degree=3.70, components=1, largest_cc=100
# [2026-05-28 10:22:08 | +00:00:00] Spanner-like疎化開始: stretch=1.5
# [2026-05-28 10:22:08 | +00:00:00] Spanner-like疎化完了: edges=300
# [2026-05-28 10:22:08 | +00:00:00] Spanner-like: nodes=100, edges=300, edge_ratio=0.81, avg_degree=6.00, components=1, largest_cc=100
# [2026-05-28 10:22:08 | +00:00:00] 疎化実行完了
# [2026-05-28 10:22:08 | +00:00:00] ==============================
# [2026-05-28 10:22:08 | +00:00:00] TSP Results
# [2026-05-28 10:22:08 | +00:00:00] ==============================
# [2026-05-28 10:22:08 | +00:00:00] --------------------------------------------------
# [2026-05-28 10:22:08 | +00:00:00] [1/10] Original: TSP処理開始
# [2026-05-28 10:22:08 | +00:00:00] Original: Greedy TSP開始
# [2026-05-28 10:22:08 | +00:00:00] Original: 連結成分確認開始
# [2026-05-28 10:22:08 | +00:00:00] Original: 連結グラフ
# [2026-05-28 10:22:08 | +00:00:00] Original: TSP対象ノード数を制限: nodes=26, MAX_TSP_NODES=30
# [2026-05-28 10:22:08 | +00:00:00] Original: TSP用完全グラフ作成開始
# [2026-05-28 10:22:08 | +00:00:00] Original: TSP用完全グラフ作成完了: nodes=26, edges=325
# [2026-05-28 10:22:08 | +00:00:00] Original: Greedy TSP完了: length=21.3836, time=0.00s
# [2026-05-28 10:22:08 | +00:00:00] Original: Greedy cycle: 0 -> 90 -> 36 -> 95 -> 58 -> 70 -> 93 -> 24 -> 37 -> 60 -> 15 -> 65 -> 31 -> 82 -> 19 -> 34 -> 92 -> 35 -> 63 -> 43 -> ...
# [2026-05-28 10:22:08 | +00:00:00] Original: SA TSP開始
# [2026-05-28 10:22:08 | +00:00:00] Original: 連結成分確認開始
# [2026-05-28 10:22:08 | +00:00:00] Original: 連結グラフ
# [2026-05-28 10:22:08 | +00:00:00] Original: TSP対象ノード数を制限: nodes=29, MAX_TSP_NODES=30
# [2026-05-28 10:22:08 | +00:00:00] Original: TSP用完全グラフ作成開始
# [2026-05-28 10:22:08 | +00:00:00] Original: TSP用完全グラフ作成完了: nodes=29, edges=406
# [2026-05-28 10:22:08 | +00:00:00] Original: SA trial 1/1 開始 temp=100, max_iter=300, N_inner=50, move=1-1
# [2026-05-28 10:22:08 | +00:00:00] Original: SA trial 1 初期解 length=39.0240
# [2026-05-28 10:22:09 | +00:00:01] Original: SA trial 1/1 完了 init=39.0240, final=30.5941, trial_improvement=21.60%, best=30.5941, time=0.70s, BEST更新
# [2026-05-28 10:22:09 | +00:00:01] Original: SA TSP完了 best_length=30.5941
# [2026-05-28 10:22:09 | +00:00:01] Original: SA cycle: 48 -> 95 -> 70 -> 75 -> 84 -> 69 -> 63 -> 44 -> 16 -> 58 -> 49 -> 42 -> 73 -> 4 -> 52 -> 68 -> 40 -> 41 -> 30 -> 29 -> ...
# [2026-05-28 10:22:09 | +00:00:01] Original         nodes= 26 edges=  33 components=  1 greedy=21.383633328817996 SA=30.594128368845915 used=all nodes
# [2026-05-28 10:22:09 | +00:00:01] [1/10] Original: TSP処理完了
# [2026-05-28 10:22:09 | +00:00:01] --------------------------------------------------
# [2026-05-28 10:22:09 | +00:00:01] [2/10] Random: TSP処理開始
# [2026-05-28 10:22:09 | +00:00:01] Random: Greedy TSP開始
# [2026-05-28 10:22:09 | +00:00:01] Random: 連結成分確認開始
# [2026-05-28 10:22:09 | +00:00:01] Random: 非連結。最大連結成分を使用: nodes=98, edges=185
# [2026-05-28 10:22:09 | +00:00:01] Random: TSP対象ノード数を制限: nodes=10, MAX_TSP_NODES=30
# [2026-05-28 10:22:09 | +00:00:01] Random: TSP用完全グラフ作成開始
# [2026-05-28 10:22:09 | +00:00:01] Random: TSP用完全グラフ作成完了: nodes=10, edges=45
# [2026-05-28 10:22:09 | +00:00:01] Random: Greedy TSP完了: length=10.2327, time=0.00s
# [2026-05-28 10:22:09 | +00:00:01] Random: Greedy cycle: 64 -> 95 -> 41 -> 40 -> 44 -> 42 -> 11 -> 39 -> 90 -> 14 -> 64
# [2026-05-28 10:22:09 | +00:00:01] Random: SA TSP開始
# [2026-05-28 10:22:09 | +00:00:01] Random: 連結成分確認開始
# [2026-05-28 10:22:09 | +00:00:01] Random: 非連結。最大連結成分を使用: nodes=98, edges=185
# [2026-05-28 10:22:09 | +00:00:01] Random: TSP対象ノード数を制限: nodes=13, MAX_TSP_NODES=30
# [2026-05-28 10:22:09 | +00:00:01] Random: TSP用完全グラフ作成開始
# [2026-05-28 10:22:09 | +00:00:01] Random: TSP用完全グラフ作成完了: nodes=13, edges=78
# [2026-05-28 10:22:09 | +00:00:01] Random: SA trial 1/1 開始 temp=100, max_iter=300, N_inner=50, move=1-1
# [2026-05-28 10:22:09 | +00:00:01] Random: SA trial 1 初期解 length=28.6977
# [2026-05-28 10:22:09 | +00:00:01] Random: SA trial 1/1 完了 init=28.6977, final=11.4678, trial_improvement=60.04%, best=11.4678, time=0.28s, BEST更新
# [2026-05-28 10:22:09 | +00:00:01] Random: SA TSP完了 best_length=11.4678
# [2026-05-28 10:22:09 | +00:00:01] Random: SA cycle: 14 -> 41 -> 95 -> 64 -> 49 -> 5 -> 93 -> 84 -> 92 -> 10 -> 45 -> 32 -> 0 -> 14
# [2026-05-28 10:22:09 | +00:00:01] Random           nodes= 10 edges=   9 components=  3 greedy=10.23272604037546 SA=11.467784545989453 used=largest component
# [2026-05-28 10:22:09 | +00:00:01] [2/10] Random: TSP処理完了
# [2026-05-28 10:22:09 | +00:00:01] --------------------------------------------------
# [2026-05-28 10:22:09 | +00:00:01] [3/10] Degree: TSP処理開始
# [2026-05-28 10:22:09 | +00:00:01] Degree: Greedy TSP開始
# [2026-05-28 10:22:09 | +00:00:01] Degree: 連結成分確認開始
# [2026-05-28 10:22:09 | +00:00:01] Degree: 非連結。最大連結成分を使用: nodes=77, edges=185
# [2026-05-28 10:22:09 | +00:00:01] Degree: TSP対象ノード数を制限: nodes=17, MAX_TSP_NODES=30
# [2026-05-28 10:22:09 | +00:00:01] Degree: TSP用完全グラフ作成開始
# [2026-05-28 10:22:09 | +00:00:01] Degree: TSP用完全グラフ作成完了: nodes=17, edges=136
# [2026-05-28 10:22:09 | +00:00:01] Degree: Greedy TSP完了: length=13.0552, time=0.00s
# [2026-05-28 10:22:09 | +00:00:01] Degree: Greedy cycle: 10 -> 37 -> 24 -> 93 -> 77 -> 22 -> 66 -> 70 -> 62 -> 91 -> 95 -> 79 -> 90 -> 21 -> 63 -> 76 -> 92 -> 10
# [2026-05-28 10:22:09 | +00:00:01] Degree: SA TSP開始
# [2026-05-28 10:22:09 | +00:00:01] Degree: 連結成分確認開始
# [2026-05-28 10:22:09 | +00:00:01] Degree: 非連結。最大連結成分を使用: nodes=77, edges=185
# [2026-05-28 10:22:09 | +00:00:01] Degree: TSP対象ノード数を制限: nodes=23, MAX_TSP_NODES=30
# [2026-05-28 10:22:09 | +00:00:01] Degree: TSP用完全グラフ作成開始
# [2026-05-28 10:22:09 | +00:00:01] Degree: TSP用完全グラフ作成完了: nodes=23, edges=253
# [2026-05-28 10:22:09 | +00:00:01] Degree: SA trial 1/1 開始 temp=100, max_iter=300, N_inner=50, move=1-1
# [2026-05-28 10:22:09 | +00:00:01] Degree: SA trial 1 初期解 length=38.2348
# [2026-05-28 10:22:10 | +00:00:02] Degree: SA trial 1/1 完了 init=38.2348, final=28.9399, trial_improvement=24.31%, best=28.9399, time=0.66s, BEST更新
# [2026-05-28 10:22:10 | +00:00:02] Degree: SA TSP完了 best_length=28.9399
# [2026-05-28 10:22:10 | +00:00:02] Degree: SA cycle: 56 -> 65 -> 73 -> 16 -> 76 -> 52 -> 37 -> 10 -> 34 -> 1 -> 4 -> 50 -> 75 -> 67 -> 80 -> 17 -> 22 -> 74 -> 58 -> 79 -> ...
# [2026-05-28 10:22:10 | +00:00:02] Degree           nodes= 17 edges=  18 components= 24 greedy=13.055150682979686 SA=28.939895413892916 used=largest component
# [2026-05-28 10:22:10 | +00:00:02] [3/10] Degree: TSP処理完了
# [2026-05-28 10:22:10 | +00:00:02] --------------------------------------------------
# [2026-05-28 10:22:10 | +00:00:02] [4/10] PageRank: TSP処理開始
# [2026-05-28 10:22:10 | +00:00:02] PageRank: Greedy TSP開始
# [2026-05-28 10:22:10 | +00:00:02] PageRank: 連結成分確認開始
# [2026-05-28 10:22:10 | +00:00:02] PageRank: 非連結。最大連結成分を使用: nodes=83, edges=185
# [2026-05-28 10:22:10 | +00:00:02] PageRank: TSP対象ノード数を制限: nodes=16, MAX_TSP_NODES=30
# [2026-05-28 10:22:10 | +00:00:02] PageRank: TSP用完全グラフ作成開始
# [2026-05-28 10:22:10 | +00:00:02] PageRank: TSP用完全グラフ作成完了: nodes=16, edges=120
# [2026-05-28 10:22:10 | +00:00:02] PageRank: Greedy TSP完了: length=18.7214, time=0.00s
# [2026-05-28 10:22:10 | +00:00:02] PageRank: Greedy cycle: 0 -> 45 -> 50 -> 13 -> 42 -> 14 -> 93 -> 54 -> 22 -> 5 -> 84 -> 75 -> 71 -> 58 -> 16 -> 89 -> 0
# [2026-05-28 10:22:10 | +00:00:02] PageRank: SA TSP開始
# [2026-05-28 10:22:10 | +00:00:02] PageRank: 連結成分確認開始
# [2026-05-28 10:22:10 | +00:00:02] PageRank: 非連結。最大連結成分を使用: nodes=83, edges=185
# [2026-05-28 10:22:10 | +00:00:02] PageRank: TSP対象ノード数を制限: nodes=25, MAX_TSP_NODES=30
# [2026-05-28 10:22:10 | +00:00:02] PageRank: TSP用完全グラフ作成開始
# [2026-05-28 10:22:10 | +00:00:02] PageRank: TSP用完全グラフ作成完了: nodes=25, edges=300
# [2026-05-28 10:22:10 | +00:00:02] PageRank: SA trial 1/1 開始 temp=100, max_iter=300, N_inner=50, move=1-1
# [2026-05-28 10:22:10 | +00:00:02] PageRank: SA trial 1 初期解 length=34.7565
# [2026-05-28 10:22:10 | +00:00:02] PageRank: SA trial 1/1 完了 init=34.7565, final=29.0255, trial_improvement=16.49%, best=29.0255, time=0.30s, BEST更新
# [2026-05-28 10:22:10 | +00:00:02] PageRank: SA TSP完了 best_length=29.0255
# [2026-05-28 10:22:10 | +00:00:02] PageRank: SA cycle: 16 -> 82 -> 65 -> 56 -> 79 -> 90 -> 0 -> 32 -> 64 -> 30 -> 22 -> 63 -> 87 -> 37 -> 76 -> 2 -> 15 -> 93 -> 24 -> 14 -> ...
# [2026-05-28 10:22:10 | +00:00:02] PageRank         nodes= 16 edges=  15 components= 18 greedy=18.721403683244343 SA=29.025481769959462 used=largest component
# [2026-05-28 10:22:10 | +00:00:02] [4/10] PageRank: TSP処理完了
# [2026-05-28 10:22:10 | +00:00:02] --------------------------------------------------
# [2026-05-28 10:22:10 | +00:00:02] [5/10] Betweenness: TSP処理開始
# [2026-05-28 10:22:10 | +00:00:02] Betweenness: Greedy TSP開始
# [2026-05-28 10:22:10 | +00:00:02] Betweenness: 連結成分確認開始
# [2026-05-28 10:22:10 | +00:00:02] Betweenness: 連結グラフ
# [2026-05-28 10:22:10 | +00:00:02] Betweenness: TSP対象ノード数を制限: nodes=5, MAX_TSP_NODES=30
# [2026-05-28 10:22:10 | +00:00:02] Betweenness: TSP用完全グラフ作成開始
# [2026-05-28 10:22:10 | +00:00:02] Betweenness: TSP用完全グラフ作成完了: nodes=5, edges=10
# [2026-05-28 10:22:10 | +00:00:02] Betweenness: Greedy TSP完了: length=1.2004, time=0.00s
# [2026-05-28 10:22:10 | +00:00:02] Betweenness: Greedy cycle: 0 -> 10 -> 90 -> 21 -> 20 -> 0
# [2026-05-28 10:22:10 | +00:00:02] Betweenness: SA TSP開始
# [2026-05-28 10:22:10 | +00:00:02] Betweenness: 連結成分確認開始
# [2026-05-28 10:22:10 | +00:00:02] Betweenness: 連結グラフ
# [2026-05-28 10:22:10 | +00:00:02] Betweenness: TSP対象ノード数を制限: nodes=6, MAX_TSP_NODES=30
# [2026-05-28 10:22:10 | +00:00:02] Betweenness: TSP用完全グラフ作成開始
# [2026-05-28 10:22:10 | +00:00:02] Betweenness: TSP用完全グラフ作成完了: nodes=6, edges=15
# [2026-05-28 10:22:10 | +00:00:02] Betweenness: SA trial 1/1 開始 temp=100, max_iter=300, N_inner=50, move=1-1
# [2026-05-28 10:22:10 | +00:00:02] Betweenness: SA trial 1 初期解 length=1.6877
# [2026-05-28 10:22:10 | +00:00:02] Betweenness: SA trial 1/1 完了 init=1.6877, final=1.6281, trial_improvement=3.53%, best=1.6281, time=0.11s, BEST更新
# [2026-05-28 10:22:10 | +00:00:02] Betweenness: SA TSP完了 best_length=1.6281
# [2026-05-28 10:22:10 | +00:00:02] Betweenness: SA cycle: 3 -> 1 -> 39 -> 19 -> 7 -> 2 -> 3
# [2026-05-28 10:22:10 | +00:00:02] Betweenness      nodes=  5 edges=   4 components=  1 greedy=1.2004339098819299 SA=1.6281240454973696 used=all nodes
# [2026-05-28 10:22:10 | +00:00:02] [5/10] Betweenness: TSP処理完了
# [2026-05-28 10:22:10 | +00:00:02] --------------------------------------------------
# [2026-05-28 10:22:10 | +00:00:02] [6/10] k-core: TSP処理開始
# [2026-05-28 10:22:10 | +00:00:02] k-core: Greedy TSP開始
# [2026-05-28 10:22:10 | +00:00:02] k-core: 連結成分確認開始
# [2026-05-28 10:22:10 | +00:00:02] k-core: 非連結。最大連結成分を使用: nodes=99, edges=370
# [2026-05-28 10:22:10 | +00:00:02] k-core: TSP対象ノード数を制限: nodes=29, MAX_TSP_NODES=30
# [2026-05-28 10:22:10 | +00:00:02] k-core: TSP用完全グラフ作成開始
# [2026-05-28 10:22:10 | +00:00:02] k-core: TSP用完全グラフ作成完了: nodes=29, edges=406
# [2026-05-28 10:22:10 | +00:00:02] k-core: Greedy TSP完了: length=23.4201, time=0.00s
# [2026-05-28 10:22:10 | +00:00:02] k-core: Greedy cycle: 0 -> 13 -> 41 -> 59 -> 74 -> 81 -> 27 -> 1 -> 39 -> 54 -> 93 -> 36 -> 14 -> 98 -> 67 -> 71 -> 76 -> 80 -> 17 -> 6 -> ...
# [2026-05-28 10:22:10 | +00:00:02] k-core: SA TSP開始
# [2026-05-28 10:22:10 | +00:00:02] k-core: 連結成分確認開始
# [2026-05-28 10:22:10 | +00:00:02] k-core: 非連結。最大連結成分を使用: nodes=99, edges=370
# [2026-05-28 10:22:10 | +00:00:02] k-core: TSP対象ノード数を制限: nodes=26, MAX_TSP_NODES=30
# [2026-05-28 10:22:10 | +00:00:02] k-core: TSP用完全グラフ作成開始
# [2026-05-28 10:22:10 | +00:00:02] k-core: TSP用完全グラフ作成完了: nodes=26, edges=325
# [2026-05-28 10:22:10 | +00:00:02] k-core: SA trial 1/1 開始 temp=100, max_iter=300, N_inner=50, move=1-1
# [2026-05-28 10:22:10 | +00:00:02] k-core: SA trial 1 初期解 length=68.3000
# [2026-05-28 10:22:11 | +00:00:03] k-core: SA trial 1/1 完了 init=68.3000, final=43.4115, trial_improvement=36.44%, best=43.4115, time=0.61s, BEST更新
# [2026-05-28 10:22:11 | +00:00:03] k-core: SA TSP完了 best_length=43.4115
# [2026-05-28 10:22:11 | +00:00:03] k-core: SA cycle: 83 -> 50 -> 97 -> 1 -> 27 -> 37 -> 28 -> 63 -> 15 -> 74 -> 7 -> 99 -> 58 -> 2 -> 51 -> 95 -> 75 -> 20 -> 52 -> 53 -> ...
# [2026-05-28 10:22:11 | +00:00:03] k-core           nodes= 29 edges=  41 components=  2 greedy=23.420060400994355 SA=43.41146354654896 used=largest component
# [2026-05-28 10:22:11 | +00:00:03] [6/10] k-core: TSP処理完了
# [2026-05-28 10:22:11 | +00:00:03] --------------------------------------------------
# [2026-05-28 10:22:11 | +00:00:03] [7/10] Weight: TSP処理開始
# [2026-05-28 10:22:11 | +00:00:03] Weight: Greedy TSP開始
# [2026-05-28 10:22:11 | +00:00:03] Weight: 連結成分確認開始
# [2026-05-28 10:22:11 | +00:00:03] Weight: 非連結。最大連結成分を使用: nodes=99, edges=185
# [2026-05-28 10:22:11 | +00:00:03] Weight: TSP対象ノード数を制限: nodes=10, MAX_TSP_NODES=30
# [2026-05-28 10:22:11 | +00:00:03] Weight: TSP用完全グラフ作成開始
# [2026-05-28 10:22:11 | +00:00:03] Weight: TSP用完全グラフ作成完了: nodes=10, edges=45
# [2026-05-28 10:22:11 | +00:00:03] Weight: Greedy TSP完了: length=13.3404, time=0.00s
# [2026-05-28 10:22:11 | +00:00:03] Weight: Greedy cycle: 65 -> 40 -> 72 -> 25 -> 45 -> 82 -> 77 -> 12 -> 44 -> 70 -> 65
# [2026-05-28 10:22:11 | +00:00:03] Weight: SA TSP開始
# [2026-05-28 10:22:11 | +00:00:03] Weight: 連結成分確認開始
# [2026-05-28 10:22:11 | +00:00:03] Weight: 非連結。最大連結成分を使用: nodes=99, edges=185
# [2026-05-28 10:22:11 | +00:00:03] Weight: TSP対象ノード数を制限: nodes=5, MAX_TSP_NODES=30
# [2026-05-28 10:22:11 | +00:00:03] Weight: TSP用完全グラフ作成開始
# [2026-05-28 10:22:11 | +00:00:03] Weight: TSP用完全グラフ作成完了: nodes=5, edges=10
# [2026-05-28 10:22:11 | +00:00:03] Weight: SA trial 1/1 開始 temp=100, max_iter=300, N_inner=50, move=1-1
# [2026-05-28 10:22:11 | +00:00:03] Weight: SA trial 1 初期解 length=7.8243
# [2026-05-28 10:22:11 | +00:00:03] Weight: SA trial 1/1 完了 init=7.8243, final=6.0164, trial_improvement=23.11%, best=6.0164, time=0.10s, BEST更新
# [2026-05-28 10:22:11 | +00:00:03] Weight: SA TSP完了 best_length=6.0164
# [2026-05-28 10:22:11 | +00:00:03] Weight: SA cycle: 58 -> 16 -> 80 -> 7 -> 64 -> 58
# [2026-05-28 10:22:11 | +00:00:03] Weight           nodes= 10 edges=  10 components=  2 greedy=13.34041481481059 SA=6.016393966122992 used=largest component
# [2026-05-28 10:22:11 | +00:00:03] [7/10] Weight: TSP処理完了
# [2026-05-28 10:22:11 | +00:00:03] --------------------------------------------------
# [2026-05-28 10:22:11 | +00:00:03] [8/10] Local Top-k: TSP処理開始
# [2026-05-28 10:22:11 | +00:00:03] Local Top-k: Greedy TSP開始
# [2026-05-28 10:22:11 | +00:00:03] Local Top-k: 連結成分確認開始
# [2026-05-28 10:22:11 | +00:00:03] Local Top-k: 連結グラフ
# [2026-05-28 10:22:11 | +00:00:03] Local Top-k: TSP対象ノード数を制限: nodes=24, MAX_TSP_NODES=30
# [2026-05-28 10:22:11 | +00:00:03] Local Top-k: TSP用完全グラフ作成開始
# [2026-05-28 10:22:11 | +00:00:03] Local Top-k: TSP用完全グラフ作成完了: nodes=24, edges=276
# [2026-05-28 10:22:11 | +00:00:03] Local Top-k: Greedy TSP完了: length=30.6655, time=0.00s
# [2026-05-28 10:22:11 | +00:00:03] Local Top-k: Greedy cycle: 13 -> 41 -> 45 -> 59 -> 38 -> 22 -> 54 -> 21 -> 85 -> 18 -> 69 -> 77 -> 61 -> 48 -> 92 -> 24 -> 97 -> 76 -> 73 -> 71 -> ...
# [2026-05-28 10:22:11 | +00:00:03] Local Top-k: SA TSP開始
# [2026-05-28 10:22:11 | +00:00:03] Local Top-k: 連結成分確認開始
# [2026-05-28 10:22:11 | +00:00:03] Local Top-k: 連結グラフ
# [2026-05-28 10:22:11 | +00:00:03] Local Top-k: TSP対象ノード数を制限: nodes=10, MAX_TSP_NODES=30
# [2026-05-28 10:22:11 | +00:00:03] Local Top-k: TSP用完全グラフ作成開始
# [2026-05-28 10:22:11 | +00:00:03] Local Top-k: TSP用完全グラフ作成完了: nodes=10, edges=45
# [2026-05-28 10:22:11 | +00:00:03] Local Top-k: SA trial 1/1 開始 temp=100, max_iter=300, N_inner=50, move=1-1
# [2026-05-28 10:22:11 | +00:00:03] Local Top-k: SA trial 1 初期解 length=14.4207
# [2026-05-28 10:22:11 | +00:00:03] Local Top-k: SA trial 1/1 完了 init=14.4207, final=7.9829, trial_improvement=44.64%, best=7.9829, time=0.27s, BEST更新
# [2026-05-28 10:22:11 | +00:00:03] Local Top-k: SA TSP完了 best_length=7.9829
# [2026-05-28 10:22:11 | +00:00:03] Local Top-k: SA cycle: 25 -> 81 -> 31 -> 89 -> 77 -> 75 -> 53 -> 54 -> 98 -> 67 -> 25
# [2026-05-28 10:22:11 | +00:00:03] Local Top-k      nodes= 24 edges=  23 components=  1 greedy=30.665476198493945 SA=7.982880411545746 used=all nodes
# [2026-05-28 10:22:11 | +00:00:03] [8/10] Local Top-k: TSP処理完了
# [2026-05-28 10:22:11 | +00:00:03] --------------------------------------------------
# [2026-05-28 10:22:11 | +00:00:03] [9/10] Resistance-like: TSP処理開始
# [2026-05-28 10:22:11 | +00:00:03] Resistance-like: Greedy TSP開始
# [2026-05-28 10:22:11 | +00:00:03] Resistance-like: 連結成分確認開始
# [2026-05-28 10:22:11 | +00:00:03] Resistance-like: 連結グラフ
# [2026-05-28 10:22:11 | +00:00:03] Resistance-like: TSP対象ノード数を制限: nodes=7, MAX_TSP_NODES=30
# [2026-05-28 10:22:11 | +00:00:03] Resistance-like: TSP用完全グラフ作成開始
# [2026-05-28 10:22:11 | +00:00:03] Resistance-like: TSP用完全グラフ作成完了: nodes=7, edges=21
# [2026-05-28 10:22:11 | +00:00:03] Resistance-like: Greedy TSP完了: length=6.9584, time=0.00s
# [2026-05-28 10:22:11 | +00:00:03] Resistance-like: Greedy cycle: 64 -> 5 -> 25 -> 29 -> 27 -> 1 -> 95 -> 64
# [2026-05-28 10:22:11 | +00:00:03] Resistance-like: SA TSP開始
# [2026-05-28 10:22:11 | +00:00:03] Resistance-like: 連結成分確認開始
# [2026-05-28 10:22:11 | +00:00:03] Resistance-like: 連結グラフ
# [2026-05-28 10:22:11 | +00:00:03] Resistance-like: TSP対象ノード数を制限: nodes=7, MAX_TSP_NODES=30
# [2026-05-28 10:22:11 | +00:00:03] Resistance-like: TSP用完全グラフ作成開始
# [2026-05-28 10:22:11 | +00:00:03] Resistance-like: TSP用完全グラフ作成完了: nodes=7, edges=21
# [2026-05-28 10:22:11 | +00:00:03] Resistance-like: SA trial 1/1 開始 temp=100, max_iter=300, N_inner=50, move=1-1
# [2026-05-28 10:22:11 | +00:00:03] Resistance-like: SA trial 1 初期解 length=8.5805
# [2026-05-28 10:22:12 | +00:00:03] Resistance-like: SA trial 1/1 完了 init=8.5805, final=6.7877, trial_improvement=20.89%, best=6.7877, time=0.12s, BEST更新
# [2026-05-28 10:22:12 | +00:00:03] Resistance-like: SA TSP完了 best_length=6.7877
# [2026-05-28 10:22:12 | +00:00:03] Resistance-like: SA cycle: 98 -> 52 -> 51 -> 67 -> 81 -> 20 -> 33 -> 98
# [2026-05-28 10:22:12 | +00:00:03] Resistance-like  nodes=  7 edges=   6 components=  1 greedy=6.958438550365247 SA=6.787710098597346 used=all nodes
# [2026-05-28 10:22:12 | +00:00:03] [9/10] Resistance-like: TSP処理完了
# [2026-05-28 10:22:12 | +00:00:03] --------------------------------------------------
# [2026-05-28 10:22:12 | +00:00:03] [10/10] Spanner-like: TSP処理開始
# [2026-05-28 10:22:12 | +00:00:03] Spanner-like: Greedy TSP開始
# [2026-05-28 10:22:12 | +00:00:03] Spanner-like: 連結成分確認開始
# [2026-05-28 10:22:12 | +00:00:03] Spanner-like: 連結グラフ
# [2026-05-28 10:22:12 | +00:00:03] Spanner-like: TSP対象ノード数を制限: nodes=25, MAX_TSP_NODES=30
# [2026-05-28 10:22:12 | +00:00:03] Spanner-like: TSP用完全グラフ作成開始
# [2026-05-28 10:22:12 | +00:00:03] Spanner-like: TSP用完全グラフ作成完了: nodes=25, edges=300
# [2026-05-28 10:22:12 | +00:00:03] Spanner-like: Greedy TSP完了: length=11.9082, time=0.00s
# [2026-05-28 10:22:12 | +00:00:03] Spanner-like: Greedy cycle: 0 -> 10 -> 37 -> 84 -> 24 -> 78 -> 3 -> 1 -> 2 -> 80 -> 45 -> 60 -> 33 -> 72 -> 59 -> 42 -> 16 -> 20 -> 67 -> 95 -> ...
# [2026-05-28 10:22:12 | +00:00:03] Spanner-like: SA TSP開始
# [2026-05-28 10:22:12 | +00:00:03] Spanner-like: 連結成分確認開始
# [2026-05-28 10:22:12 | +00:00:03] Spanner-like: 連結グラフ
# [2026-05-28 10:22:12 | +00:00:03] Spanner-like: TSP対象ノード数を制限: nodes=26, MAX_TSP_NODES=30
# [2026-05-28 10:22:12 | +00:00:03] Spanner-like: TSP用完全グラフ作成開始
# [2026-05-28 10:22:12 | +00:00:03] Spanner-like: TSP用完全グラフ作成完了: nodes=26, edges=325
# [2026-05-28 10:22:12 | +00:00:03] Spanner-like: SA trial 1/1 開始 temp=100, max_iter=300, N_inner=50, move=1-1
# [2026-05-28 10:22:12 | +00:00:03] Spanner-like: SA trial 1 初期解 length=57.1437
# [2026-05-28 10:22:12 | +00:00:04] Spanner-like: SA trial 1/1 完了 init=57.1437, final=33.5857, trial_improvement=41.23%, best=33.5857, time=0.35s, BEST更新
# [2026-05-28 10:22:12 | +00:00:04] Spanner-like: SA TSP完了 best_length=33.5857
# [2026-05-28 10:22:12 | +00:00:04] Spanner-like: SA cycle: 95 -> 24 -> 92 -> 73 -> 78 -> 1 -> 79 -> 17 -> 99 -> 58 -> 97 -> 52 -> 13 -> 14 -> 51 -> 84 -> 71 -> 36 -> 5 -> 65 -> ...
# [2026-05-28 10:22:12 | +00:00:04] Spanner-like     nodes= 25 edges=  29 components=  1 greedy=11.908165698893969 SA=33.58568362859209 used=all nodes
# [2026-05-28 10:22:12 | +00:00:04] [10/10] Spanner-like: TSP処理完了
# [2026-05-28 10:22:12 | +00:00:04] ==============================
# [2026-05-28 10:22:12 | +00:00:04] TSP Improvement Summary
# [2026-05-28 10:22:12 | +00:00:04] ==============================
# [2026-05-28 10:22:12 | +00:00:04] Original         edges= 371 edge_ratio=1.00 greedy=21.3836 SA=30.5941 improvement=-43.07%
# [2026-05-28 10:22:12 | +00:00:04] Random           edges= 185 edge_ratio=0.50 greedy=10.2327 SA=11.4678 improvement=-12.07%
# [2026-05-28 10:22:12 | +00:00:04] Degree           edges= 185 edge_ratio=0.50 greedy=13.0552 SA=28.9399 improvement=-121.67%
# [2026-05-28 10:22:12 | +00:00:04] PageRank         edges= 185 edge_ratio=0.50 greedy=18.7214 SA=29.0255 improvement=-55.04%
# [2026-05-28 10:22:12 | +00:00:04] Betweenness      edges= 185 edge_ratio=0.50 greedy=1.2004 SA=1.6281 improvement=-35.63%
# [2026-05-28 10:22:12 | +00:00:04] k-core           edges= 370 edge_ratio=1.00 greedy=23.4201 SA=43.4115 improvement=-85.36%
# [2026-05-28 10:22:12 | +00:00:04] Weight           edges= 185 edge_ratio=0.50 greedy=13.3404 SA=6.0164 improvement=54.90%
# [2026-05-28 10:22:12 | +00:00:04] Local Top-k      edges= 240 edge_ratio=0.65 greedy=30.6655 SA=7.9829 improvement=73.97%
# [2026-05-28 10:22:12 | +00:00:04] Resistance-like  edges= 185 edge_ratio=0.50 greedy=6.9584 SA=6.7877 improvement=2.45%
# [2026-05-28 10:22:12 | +00:00:04] Spanner-like     edges= 300 edge_ratio=0.81 greedy=11.9082 SA=33.5857 improvement=-182.04%
# [2026-05-28 10:22:12 | +00:00:04] グラフ描画開始
# [2026-05-28 10:22:13 | +00:00:05] グラフ描画完了
# [2026-05-28 10:22:13 | +00:00:05] TSP経路描画開始
# [2026-05-28 10:22:14 | +00:00:05] TSP経路描画完了
# [2026-05-28 10:22:14 | +00:00:05] TSP結果プロット開始
# [2026-05-28 10:22:15 | +00:00:06] TSP結果プロット完了
# [2026-05-28 10:22:15 | +00:00:06] 全処理完了
