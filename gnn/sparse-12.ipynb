# %%
import networkx as nx
import matplotlib.pyplot as plt
import random
import numpy as np
import time
from datetime import datetime

from networkx.algorithms.approximation import (
    greedy_tsp,
    simulated_annealing_tsp
)

# ============================================================
# グラフ生成パラメータ
# ============================================================
NUM_NODES = 200
EDGE_PROB = 0.08
SEED = 42

# ============================================================
# 疎化パラメータ
# ============================================================
SPARSIFY_RATIO = 0.5
K_CORE = 2
LOCAL_TOP_K = 4
SPANNER_STRETCH = 1.5

# ============================================================
# TSPパラメータ
# ============================================================
MAX_TSP_NODES = 100

# ============================================================
# Simulated Annealing パラメータ
# ============================================================
SA_TEMP = 100
SA_MAX_ITERATIONS = 300
SA_N_INNER = 50
SA_TRIALS = 1
SA_MOVE = "1-1"

# ============================================================
# 描画設定
# ============================================================
DRAW_GRAPHS = True
DRAW_SPARSIFY_SUMMARY_PLOTS = True
DRAW_TSP_PATHS = True
DRAW_TSP_SUMMARY_PLOTS = True

# プロット列数
PLOT_COLS = 4

random.seed(SEED)
np.random.seed(SEED)

START_TIME = time.time()


# ============================================================
# ログ関数
# ============================================================
def now_str():
    return datetime.now().strftime("%Y-%m-%d %H:%M:%S")


def elapsed_str():
    sec = int(time.time() - START_TIME)
    h = sec // 3600
    m = (sec % 3600) // 60
    s = sec % 60
    return f"+{h:02d}:{m:02d}:{s:02d}"


def log(msg):
    print(f"[{now_str()} | {elapsed_str()}] {msg}", flush=True)


# ============================================================
# 元グラフ生成
# ============================================================
log("元グラフ生成開始")

G = nx.erdos_renyi_graph(
    n=NUM_NODES,
    p=EDGE_PROB,
    seed=SEED
)

for u, v in G.edges():
    G[u][v]["weight"] = random.random()

ORIGINAL_EDGE_COUNT = G.number_of_edges()

log(
    f"元グラフ生成完了: "
    f"nodes={G.number_of_nodes()}, "
    f"edges={G.number_of_edges()}"
)

log(
    f"設定: SPARSIFY_RATIO={SPARSIFY_RATIO}, "
    f"K_CORE={K_CORE}, "
    f"LOCAL_TOP_K={LOCAL_TOP_K}, "
    f"SPANNER_STRETCH={SPANNER_STRETCH}, "
    f"PLOT_COLS={PLOT_COLS}"
)


# ============================================================
# 共通関数
# ============================================================
def make_graph_from_edges(G, selected_edges):
    H = nx.Graph()
    H.add_nodes_from(G.nodes())

    for u, v in selected_edges:
        if G.has_edge(u, v):
            H.add_edge(u, v, **G[u][v])
        else:
            H.add_edge(u, v, weight=1.0)

    return H


def keep_top_edges_by_score(G, edge_scores, ratio):
    edges = list(G.edges())
    num_keep = max(1, int(len(edges) * ratio))

    sorted_edges = sorted(
        edges,
        key=lambda e: edge_scores.get(tuple(sorted(e)), 0),
        reverse=True
    )

    return make_graph_from_edges(G, sorted_edges[:num_keep])


def graph_stats(H):
    avg_degree = sum(dict(H.degree()).values()) / H.number_of_nodes()

    if H.number_of_edges() > 0:
        components = nx.number_connected_components(H)
        largest_cc_size = len(max(nx.connected_components(H), key=len))
    else:
        components = H.number_of_nodes()
        largest_cc_size = 1

    return avg_degree, components, largest_cc_size


def print_graph_info(name, H):
    avg_degree, components, largest_cc_size = graph_stats(H)

    edge_ratio = (
        H.number_of_edges() / ORIGINAL_EDGE_COUNT
        if ORIGINAL_EDGE_COUNT > 0
        else 0
    )

    log(
        f"{name}: "
        f"nodes={H.number_of_nodes()}, "
        f"edges={H.number_of_edges()}, "
        f"edge_ratio={edge_ratio:.2f}, "
        f"avg_degree={avg_degree:.2f}, "
        f"components={components}, "
        f"largest_cc={largest_cc_size}"
    )


# ============================================================
# 疎化手法
# ============================================================
def random_sparsification(G, ratio):
    log(f"Random疎化開始: ratio={ratio}")

    edges = list(G.edges())
    num_keep = max(1, int(len(edges) * ratio))
    sampled_edges = random.sample(edges, num_keep)

    H = make_graph_from_edges(G, sampled_edges)

    log(f"Random疎化完了: edges={H.number_of_edges()}")
    return H


def degree_based_sparsification(G, ratio):
    log(f"Degree疎化開始: ratio={ratio}")

    deg = dict(G.degree())

    edge_scores = {}
    for u, v in G.edges():
        edge_scores[tuple(sorted((u, v)))] = deg[u] + deg[v]

    H = keep_top_edges_by_score(G, edge_scores, ratio)

    log(f"Degree疎化完了: edges={H.number_of_edges()}")
    return H


def pagerank_based_sparsification(G, ratio):
    log(f"PageRank疎化開始: ratio={ratio}")

    pr = nx.pagerank(G, weight="weight")

    edge_scores = {}
    for u, v in G.edges():
        edge_scores[tuple(sorted((u, v)))] = pr[u] + pr[v]

    H = keep_top_edges_by_score(G, edge_scores, ratio)

    log(f"PageRank疎化完了: edges={H.number_of_edges()}")
    return H


def edge_betweenness_sparsification(G, ratio):
    log(f"Betweenness疎化開始: ratio={ratio}")

    eb = nx.edge_betweenness_centrality(G, weight="weight")

    edge_scores = {}
    for e, score in eb.items():
        edge_scores[tuple(sorted(e))] = score

    H = keep_top_edges_by_score(G, edge_scores, ratio)

    log(f"Betweenness疎化完了: edges={H.number_of_edges()}")
    return H


def k_core_sparsification(G, k):
    log(f"k-core疎化開始: k={k}")

    core = nx.k_core(G, k=k)

    H = nx.Graph()
    H.add_nodes_from(G.nodes())

    for u, v in core.edges():
        H.add_edge(u, v, **G[u][v])

    log(f"k-core疎化完了: edges={H.number_of_edges()}")
    return H


def weight_threshold_sparsification(G, ratio):
    log(f"Weight疎化開始: ratio={ratio}")

    edges = list(G.edges(data=True))
    num_keep = max(1, int(len(edges) * ratio))

    sorted_edges = sorted(
        edges,
        key=lambda x: x[2].get("weight", 0),
        reverse=True
    )

    selected_edges = [(u, v) for u, v, _ in sorted_edges[:num_keep]]

    H = make_graph_from_edges(G, selected_edges)

    log(f"Weight疎化完了: edges={H.number_of_edges()}")
    return H


def local_top_k_sparsification(G, k):
    log(f"Local Top-k疎化開始: k={k}")

    selected_edges = set()

    for node in G.nodes():
        neighbors = list(G.neighbors(node))

        scored_neighbors = []
        for nbr in neighbors:
            score = G[node][nbr].get("weight", 1.0)
            scored_neighbors.append((nbr, score))

        scored_neighbors.sort(key=lambda x: x[1], reverse=True)

        for nbr, _ in scored_neighbors[:k]:
            selected_edges.add(tuple(sorted((node, nbr))))

    H = make_graph_from_edges(G, list(selected_edges))

    log(f"Local Top-k疎化完了: edges={H.number_of_edges()}")
    return H


def effective_resistance_like_sparsification(G, ratio):
    log(f"Resistance-like疎化開始: ratio={ratio}")

    deg = dict(G.degree())

    edge_scores = {}
    for u, v in G.edges():
        score = 1 / max(1, deg[u]) + 1 / max(1, deg[v])
        edge_scores[tuple(sorted((u, v)))] = score

    H = keep_top_edges_by_score(G, edge_scores, ratio)

    log(f"Resistance-like疎化完了: edges={H.number_of_edges()}")
    return H


def spanner_like_sparsification(G, stretch):
    log(f"Spanner-like疎化開始: stretch={stretch}")

    H = nx.Graph()
    H.add_nodes_from(G.nodes())

    edges = list(G.edges(data=True))
    random.shuffle(edges)

    for u, v, data in edges:
        if not nx.has_path(H, u, v):
            H.add_edge(u, v, **data)
        else:
            try:
                dist = nx.shortest_path_length(H, u, v, weight="weight")
                direct_weight = data.get("weight", 1.0)

                if dist > stretch * direct_weight:
                    H.add_edge(u, v, **data)

            except nx.NetworkXNoPath:
                H.add_edge(u, v, **data)

    log(f"Spanner-like疎化完了: edges={H.number_of_edges()}")
    return H


# ============================================================
# TSP用関数
# ============================================================
def get_largest_connected_subgraph(H, name):
    log(f"{name}: 連結成分確認開始")

    if H.number_of_edges() == 0:
        log(f"{name}: エッジなし。TSP対象外")
        return None

    if nx.is_connected(H):
        T = H.copy()
        log(f"{name}: 連結グラフ")
    else:
        largest_cc = max(nx.connected_components(H), key=len)
        T = H.subgraph(largest_cc).copy()

        log(
            f"{name}: 非連結。最大連結成分を使用: "
            f"nodes={T.number_of_nodes()}, "
            f"edges={T.number_of_edges()}"
        )

    if T.number_of_nodes() > MAX_TSP_NODES:
        sampled_nodes = random.sample(list(T.nodes()), MAX_TSP_NODES)
        T = T.subgraph(sampled_nodes).copy()

        if T.number_of_edges() > 0:
            largest_cc = max(nx.connected_components(T), key=len)
            T = T.subgraph(largest_cc).copy()

        log(
            f"{name}: TSP対象ノード数を制限: "
            f"nodes={T.number_of_nodes()}, "
            f"MAX_TSP_NODES={MAX_TSP_NODES}"
        )

    if T.number_of_nodes() < 3:
        log(f"{name}: TSP対象ノードが少なすぎる")
        return None

    return T


def make_metric_complete_graph(T, name):
    log(f"{name}: TSP用完全グラフ作成開始")

    K = nx.Graph()
    K.add_nodes_from(T.nodes())

    lengths = dict(nx.all_pairs_dijkstra_path_length(T, weight="weight"))
    nodes = list(T.nodes())

    for i, u in enumerate(nodes):
        for v in nodes[i + 1:]:
            K.add_edge(u, v, weight=lengths[u][v])

    log(
        f"{name}: TSP用完全グラフ作成完了: "
        f"nodes={K.number_of_nodes()}, "
        f"edges={K.number_of_edges()}"
    )

    return K


def compute_cycle_length(K, cycle):
    total = 0.0

    for u, v in zip(cycle[:-1], cycle[1:]):
        total += K[u][v]["weight"]

    return total


def make_random_cycle(K):
    nodes = list(K.nodes())
    random.shuffle(nodes)
    nodes.append(nodes[0])
    return nodes


def cycle_to_sparse_edges(T, cycle):
    tsp_edges = []

    for u, v in zip(cycle[:-1], cycle[1:]):
        path = nx.shortest_path(T, u, v, weight="weight")
        tsp_edges.extend(list(zip(path[:-1], path[1:])))

    return tsp_edges


def cycle_preview(cycle, max_items=20):
    if cycle is None:
        return "None"

    preview = cycle[:max_items]

    if len(cycle) > max_items:
        return " -> ".join(map(str, preview)) + " -> ..."
    else:
        return " -> ".join(map(str, cycle))


def solve_tsp_greedy(name, H):
    log(f"{name}: Greedy TSP開始")

    T = get_largest_connected_subgraph(H, name)

    if T is None:
        log(f"{name}: Greedy TSPスキップ")
        return None

    try:
        K = make_metric_complete_graph(T, name)

        t0 = time.time()
        cycle = greedy_tsp(K, weight="weight")
        length = compute_cycle_length(K, cycle)

        log(
            f"{name}: Greedy TSP完了: "
            f"length={length:.4f}, "
            f"time={time.time() - t0:.2f}s"
        )

        return {
            "name": name,
            "method": "Greedy",
            "nodes": T.number_of_nodes(),
            "edges": T.number_of_edges(),
            "components": nx.number_connected_components(H),
            "used_largest_component": not nx.is_connected(H),
            "tsp_length": length,
            "cycle": cycle,
            "subgraph": T,
            "metric_graph": K
        }

    except Exception as e:
        log(f"[Greedy TSP failed] {name}: {e}")
        return None


def solve_tsp_simulated_annealing(name, H):
    log(f"{name}: SA TSP開始")

    T = get_largest_connected_subgraph(H, name)

    if T is None:
        log(f"{name}: SA TSPスキップ")
        return None

    try:
        K = make_metric_complete_graph(T, name)

        best_cycle = None
        best_length = float("inf")

        for trial in range(1, SA_TRIALS + 1):
            log(
                f"{name}: SA trial {trial}/{SA_TRIALS} 開始 "
                f"temp={SA_TEMP}, "
                f"max_iter={SA_MAX_ITERATIONS}, "
                f"N_inner={SA_N_INNER}, "
                f"move={SA_MOVE}"
            )

            init_cycle = make_random_cycle(K)
            init_length = compute_cycle_length(K, init_cycle)

            t0 = time.time()

            cycle = simulated_annealing_tsp(
                K,
                init_cycle=init_cycle,
                weight="weight",
                source=init_cycle[0],
                temp=SA_TEMP,
                move=SA_MOVE,
                max_iterations=SA_MAX_ITERATIONS,
                N_inner=SA_N_INNER
            )

            length = compute_cycle_length(K, cycle)
            elapsed = time.time() - t0

            if length < best_length:
                best_length = length
                best_cycle = cycle
                updated = "BEST更新"
            else:
                updated = "BEST更新なし"

            trial_improvement = (init_length - length) / init_length * 100

            log(
                f"{name}: SA trial {trial}/{SA_TRIALS} 完了 "
                f"init={init_length:.4f}, "
                f"final={length:.4f}, "
                f"trial_improvement={trial_improvement:.2f}%, "
                f"best={best_length:.4f}, "
                f"time={elapsed:.2f}s, "
                f"{updated}"
            )

        return {
            "name": name,
            "method": "SA",
            "nodes": T.number_of_nodes(),
            "edges": T.number_of_edges(),
            "components": nx.number_connected_components(H),
            "used_largest_component": not nx.is_connected(H),
            "tsp_length": best_length,
            "cycle": best_cycle,
            "subgraph": T,
            "metric_graph": K
        }

    except Exception as e:
        log(f"[SA TSP failed] {name}: {e}")
        return None


# ============================================================
# 疎化実行
# ============================================================
log("==============================")
log("疎化実行開始")
log("==============================")

graphs = {}

graphs["Original"] = G
print_graph_info("Original", graphs["Original"])

graphs["Random"] = random_sparsification(G, SPARSIFY_RATIO)
print_graph_info("Random", graphs["Random"])

graphs["Degree"] = degree_based_sparsification(G, SPARSIFY_RATIO)
print_graph_info("Degree", graphs["Degree"])

graphs["PageRank"] = pagerank_based_sparsification(G, SPARSIFY_RATIO)
print_graph_info("PageRank", graphs["PageRank"])

graphs["Betweenness"] = edge_betweenness_sparsification(G, SPARSIFY_RATIO)
print_graph_info("Betweenness", graphs["Betweenness"])

graphs["k-core"] = k_core_sparsification(G, K_CORE)
print_graph_info("k-core", graphs["k-core"])

graphs["Weight"] = weight_threshold_sparsification(G, SPARSIFY_RATIO)
print_graph_info("Weight", graphs["Weight"])

graphs["Local Top-k"] = local_top_k_sparsification(G, LOCAL_TOP_K)
print_graph_info("Local Top-k", graphs["Local Top-k"])

graphs["Resistance-like"] = effective_resistance_like_sparsification(G, SPARSIFY_RATIO)
print_graph_info("Resistance-like", graphs["Resistance-like"])

graphs["Spanner-like"] = spanner_like_sparsification(G, SPANNER_STRETCH)
print_graph_info("Spanner-like", graphs["Spanner-like"])

log("疎化実行完了")


# ============================================================
# 疎化後サマリーデータ
# ============================================================
sparsify_names = []
sparsify_edge_counts = []
sparsify_edge_ratios = []
sparsify_avg_degrees = []
sparsify_components = []
sparsify_largest_cc = []

for name, H in graphs.items():
    avg_degree, components, largest_cc_size = graph_stats(H)

    sparsify_names.append(name)
    sparsify_edge_counts.append(H.number_of_edges())
    sparsify_edge_ratios.append(H.number_of_edges() / ORIGINAL_EDGE_COUNT)
    sparsify_avg_degrees.append(avg_degree)
    sparsify_components.append(components)
    sparsify_largest_cc.append(largest_cc_size)


# ============================================================
# グラフ描画
# ============================================================
if DRAW_GRAPHS:
    log("グラフ描画開始")

    pos = nx.spring_layout(G, seed=SEED)

    num_graphs = len(graphs)
    cols = PLOT_COLS
    rows = int(np.ceil(num_graphs / cols))

    fig, axes = plt.subplots(
        rows,
        cols,
        figsize=(16, rows * 5)
    )

    axes = np.array(axes).flatten()

    for ax, (name, H) in zip(axes, graphs.items()):
        nx.draw(
            H,
            pos,
            ax=ax,
            node_size=35,
            width=0.6,
            with_labels=False
        )

        ax.set_title(
            f"{name}\n"
            f"Edges={H.number_of_edges()}"
        )

    for i in range(len(graphs), len(axes)):
        axes[i].axis("off")

    plt.tight_layout()
    plt.show()

    log("グラフ描画完了")


# ============================================================
# 疎化後サマリープロット
# ============================================================
if DRAW_SPARSIFY_SUMMARY_PLOTS:
    log("疎化後サマリープロット開始")

    plt.figure(figsize=(12, 6))
    plt.bar(sparsify_names, sparsify_edge_counts)
    plt.xticks(rotation=30)
    plt.ylabel("Number of Edges")
    plt.title("Edge Count after Sparsification")
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(12, 6))
    plt.bar(sparsify_names, sparsify_edge_ratios)
    plt.xticks(rotation=30)
    plt.ylabel("Edge Ratio")
    plt.title("Edge Ratio after Sparsification")
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(12, 6))
    plt.bar(sparsify_names, sparsify_avg_degrees)
    plt.xticks(rotation=30)
    plt.ylabel("Average Degree")
    plt.title("Average Degree after Sparsification")
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(12, 6))
    plt.bar(sparsify_names, sparsify_components)
    plt.xticks(rotation=30)
    plt.ylabel("Number of Components")
    plt.title("Connected Components after Sparsification")
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(12, 6))
    plt.bar(sparsify_names, sparsify_largest_cc)
    plt.xticks(rotation=30)
    plt.ylabel("Largest Connected Component Size")
    plt.title("Largest Connected Component after Sparsification")
    plt.tight_layout()
    plt.show()

    log("疎化後サマリープロット完了")


# ============================================================
# TSP実行
# ============================================================
log("==============================")
log("TSP Results")
log("==============================")

tsp_results = {}

total_graphs = len(graphs)

for idx, (name, H) in enumerate(graphs.items(), start=1):
    log("--------------------------------------------------")
    log(f"[{idx}/{total_graphs}] {name}: TSP処理開始")

    greedy_result = solve_tsp_greedy(name, H)
    sa_result = solve_tsp_simulated_annealing(name, H)

    tsp_results[(name, "Greedy")] = greedy_result
    tsp_results[(name, "SA")] = sa_result

    greedy_len = None if greedy_result is None else greedy_result["tsp_length"]
    sa_len = None if sa_result is None else sa_result["tsp_length"]

    if greedy_len is None and sa_len is None:
        log(f"{name:16s}: TSP failed or too small")
    else:
        base_result = greedy_result if greedy_result is not None else sa_result

        used = (
            "largest component"
            if base_result["used_largest_component"]
            else "all nodes"
        )

        log(
            f"{name:16s} "
            f"nodes={base_result['nodes']:3d} "
            f"edges={base_result['edges']:4d} "
            f"components={base_result['components']:3d} "
            f"greedy={greedy_len if greedy_len is not None else 'NA'} "
            f"SA={sa_len if sa_len is not None else 'NA'} "
            f"used={used}"
        )

    log(f"[{idx}/{total_graphs}] {name}: TSP処理完了")


# ============================================================
# TSPサマリーデータ
# ============================================================
log("==============================")
log("TSP Improvement Summary")
log("==============================")

summary_names = []
summary_greedy = []
summary_sa = []
summary_improvement = []
summary_edge_ratio = []
summary_edge_count = []
summary_sa_nodes = []
summary_components = []

for name in graphs.keys():
    greedy_result = tsp_results.get((name, "Greedy"))
    sa_result = tsp_results.get((name, "SA"))

    if greedy_result is None or sa_result is None:
        log(f"{name:16s}: skipped")
        continue

    greedy_len = greedy_result["tsp_length"]
    sa_len = sa_result["tsp_length"]
    improvement = (greedy_len - sa_len) / greedy_len * 100

    edge_count = graphs[name].number_of_edges()
    edge_ratio = edge_count / G.number_of_edges()

    summary_names.append(name)
    summary_greedy.append(greedy_len)
    summary_sa.append(sa_len)
    summary_improvement.append(improvement)
    summary_edge_ratio.append(edge_ratio)
    summary_edge_count.append(edge_count)
    summary_sa_nodes.append(sa_result["nodes"])
    summary_components.append(sa_result["components"])

    log(
        f"{name:16s} "
        f"edges={edge_count:4d} "
        f"edge_ratio={edge_ratio:.2f} "
        f"greedy={greedy_len:.4f} "
        f"SA={sa_len:.4f} "
        f"improvement={improvement:.2f}%"
    )


# ============================================================
# TSP経路描画
# ============================================================
if DRAW_TSP_PATHS:
    log("TSP経路描画開始")

    pos = nx.spring_layout(G, seed=SEED)

    valid_sa_results = {
        name: result
        for (name, method), result in tsp_results.items()
        if method == "SA" and result is not None
    }

    num_tsp = len(valid_sa_results)

    if num_tsp > 0:
        cols = PLOT_COLS
        rows = int(np.ceil(num_tsp / cols))

        fig, axes = plt.subplots(
            rows,
            cols,
            figsize=(16, rows * 5)
        )

        axes = np.array(axes).flatten()

        for ax, (name, result) in zip(axes, valid_sa_results.items()):
            T = result["subgraph"]
            cycle = result["cycle"]

            tsp_edges = cycle_to_sparse_edges(T, cycle)

            nx.draw(
                T,
                pos,
                ax=ax,
                node_size=35,
                width=0.4,
                with_labels=False
            )

            nx.draw_networkx_edges(
                T,
                pos,
                edgelist=tsp_edges,
                ax=ax,
                width=2.0
            )

            ax.set_title(
                f"SA TSP: {name}\n"
                f"nodes={result['nodes']}, "
                f"edges={result['edges']}, "
                f"length={result['tsp_length']:.4f}"
            )

        for i in range(num_tsp, len(axes)):
            axes[i].axis("off")

        plt.tight_layout()
        plt.show()

    log("TSP経路描画完了")


# ============================================================
# TSP計算後サマリープロット
# ============================================================
if DRAW_TSP_SUMMARY_PLOTS and len(summary_names) > 0:
    log("TSP計算後サマリープロット開始")

    x = np.arange(len(summary_names))
    width = 0.35

    plt.figure(figsize=(12, 6))
    plt.bar(x - width / 2, summary_greedy, width, label="Greedy")
    plt.bar(x + width / 2, summary_sa, width, label="SA")
    plt.xticks(x, summary_names, rotation=30)
    plt.ylabel("TSP Distance")
    plt.title("Greedy vs Simulated Annealing TSP Distance")
    plt.legend()
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(12, 6))
    plt.bar(summary_names, summary_improvement)
    plt.xticks(rotation=30)
    plt.ylabel("Improvement (%)")
    plt.title("SA Improvement Rate over Greedy")
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(8, 6))
    plt.scatter(summary_edge_ratio, summary_sa)

    for i, name in enumerate(summary_names):
        plt.text(summary_edge_ratio[i], summary_sa[i], name)

    plt.xlabel("Edge Ratio")
    plt.ylabel("SA TSP Distance")
    plt.title("Edge Ratio vs SA TSP Distance")
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(8, 6))
    plt.scatter(summary_edge_count, summary_sa)

    for i, name in enumerate(summary_names):
        plt.text(summary_edge_count[i], summary_sa[i], name)

    plt.xlabel("Number of Edges")
    plt.ylabel("SA TSP Distance")
    plt.title("Number of Edges vs SA TSP Distance")
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(8, 6))
    plt.scatter(summary_components, summary_sa)

    for i, name in enumerate(summary_names):
        plt.text(summary_components[i], summary_sa[i], name)

    plt.xlabel("Number of Components")
    plt.ylabel("SA TSP Distance")
    plt.title("Components vs SA TSP Distance")
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(8, 6))
    plt.scatter(summary_sa_nodes, summary_sa)

    for i, name in enumerate(summary_names):
        plt.text(summary_sa_nodes[i], summary_sa[i], name)

    plt.xlabel("TSP Nodes")
    plt.ylabel("SA TSP Distance")
    plt.title("TSP Nodes vs SA TSP Distance")
    plt.tight_layout()
    plt.show()

    log("TSP計算後サマリープロット完了")


log("全処理完了")
# Out:
# [2026-05-29 11:28:52 | +00:00:00] 元グラフ生成開始
# [2026-05-29 11:28:52 | +00:00:00] 元グラフ生成完了: nodes=200, edges=1530
# [2026-05-29 11:28:52 | +00:00:00] 設定: SPARSIFY_RATIO=0.5, K_CORE=2, LOCAL_TOP_K=4, SPANNER_STRETCH=1.5, PLOT_COLS=4
# [2026-05-29 11:28:52 | +00:00:00] ==============================
# [2026-05-29 11:28:52 | +00:00:00] 疎化実行開始
# [2026-05-29 11:28:52 | +00:00:00] ==============================
# [2026-05-29 11:28:52 | +00:00:00] Original: nodes=200, edges=1530, edge_ratio=1.00, avg_degree=15.30, components=1, largest_cc=200
# [2026-05-29 11:28:52 | +00:00:00] Random疎化開始: ratio=0.5
# [2026-05-29 11:28:52 | +00:00:00] Random疎化完了: edges=765
# [2026-05-29 11:28:52 | +00:00:00] Random: nodes=200, edges=765, edge_ratio=0.50, avg_degree=7.65, components=1, largest_cc=200
# [2026-05-29 11:28:52 | +00:00:00] Degree疎化開始: ratio=0.5
# [2026-05-29 11:28:52 | +00:00:00] Degree疎化完了: edges=765
# [2026-05-29 11:28:52 | +00:00:00] Degree: nodes=200, edges=765, edge_ratio=0.50, avg_degree=7.65, components=21, largest_cc=180
# [2026-05-29 11:28:52 | +00:00:00] PageRank疎化開始: ratio=0.5
# [2026-05-29 11:28:52 | +00:00:00] PageRank疎化完了: edges=765
# [2026-05-29 11:28:52 | +00:00:00] PageRank: nodes=200, edges=765, edge_ratio=0.50, avg_degree=7.65, components=15, largest_cc=186
# [2026-05-29 11:28:52 | +00:00:00] Betweenness疎化開始: ratio=0.5
# [2026-05-29 11:28:53 | +00:00:00] Betweenness疎化完了: edges=765
# [2026-05-29 11:28:53 | +00:00:00] Betweenness: nodes=200, edges=765, edge_ratio=0.50, avg_degree=7.65, components=1, largest_cc=200
# [2026-05-29 11:28:53 | +00:00:00] k-core疎化開始: k=2
# [2026-05-29 11:28:53 | +00:00:00] k-core疎化完了: edges=1530
# [2026-05-29 11:28:53 | +00:00:00] k-core: nodes=200, edges=1530, edge_ratio=1.00, avg_degree=15.30, components=1, largest_cc=200
# [2026-05-29 11:28:53 | +00:00:00] Weight疎化開始: ratio=0.5
# [2026-05-29 11:28:53 | +00:00:00] Weight疎化完了: edges=765
# [2026-05-29 11:28:53 | +00:00:00] Weight: nodes=200, edges=765, edge_ratio=0.50, avg_degree=7.65, components=1, largest_cc=200
# [2026-05-29 11:28:53 | +00:00:00] Local Top-k疎化開始: k=4
# [2026-05-29 11:28:53 | +00:00:00] Local Top-k疎化完了: edges=518
# [2026-05-29 11:28:53 | +00:00:00] Local Top-k: nodes=200, edges=518, edge_ratio=0.34, avg_degree=5.18, components=1, largest_cc=200
# [2026-05-29 11:28:53 | +00:00:00] Resistance-like疎化開始: ratio=0.5
# [2026-05-29 11:28:53 | +00:00:00] Resistance-like疎化完了: edges=765
# [2026-05-29 11:28:53 | +00:00:00] Resistance-like: nodes=200, edges=765, edge_ratio=0.50, avg_degree=7.65, components=2, largest_cc=199
# [2026-05-29 11:28:53 | +00:00:00] Spanner-like疎化開始: stretch=1.5
# [2026-05-29 11:28:53 | +00:00:01] Spanner-like疎化完了: edges=935
# [2026-05-29 11:28:53 | +00:00:01] Spanner-like: nodes=200, edges=935, edge_ratio=0.61, avg_degree=9.35, components=1, largest_cc=200
# [2026-05-29 11:28:53 | +00:00:01] 疎化実行完了
# [2026-05-29 11:28:53 | +00:00:01] グラフ描画開始
# [2026-05-29 11:28:55 | +00:00:02] グラフ描画完了
# [2026-05-29 11:28:55 | +00:00:02] 疎化後サマリープロット開始
# [2026-05-29 11:28:56 | +00:00:03] 疎化後サマリープロット完了
# [2026-05-29 11:28:56 | +00:00:03] ==============================
# [2026-05-29 11:28:56 | +00:00:03] TSP Results
# [2026-05-29 11:28:56 | +00:00:03] ==============================
# [2026-05-29 11:28:56 | +00:00:03] --------------------------------------------------
# [2026-05-29 11:28:56 | +00:00:03] [1/10] Original: TSP処理開始
# [2026-05-29 11:28:56 | +00:00:03] Original: Greedy TSP開始
# [2026-05-29 11:28:56 | +00:00:03] Original: 連結成分確認開始
# [2026-05-29 11:28:56 | +00:00:03] Original: 連結グラフ
# [2026-05-29 11:28:56 | +00:00:03] Original: TSP対象ノード数を制限: nodes=100, MAX_TSP_NODES=100
# [2026-05-29 11:28:56 | +00:00:03] Original: TSP用完全グラフ作成開始
# [2026-05-29 11:28:56 | +00:00:03] Original: TSP用完全グラフ作成完了: nodes=100, edges=4950
# [2026-05-29 11:28:56 | +00:00:03] Original: Greedy TSP完了: length=31.4741, time=0.00s
# [2026-05-29 11:28:56 | +00:00:03] Original: SA TSP開始
# [2026-05-29 11:28:56 | +00:00:03] Original: 連結成分確認開始
# [2026-05-29 11:28:56 | +00:00:03] Original: 連結グラフ
# [2026-05-29 11:28:56 | +00:00:03] Original: TSP対象ノード数を制限: nodes=100, MAX_TSP_NODES=100
# [2026-05-29 11:28:56 | +00:00:03] Original: TSP用完全グラフ作成開始
# [2026-05-29 11:28:56 | +00:00:03] Original: TSP用完全グラフ作成完了: nodes=100, edges=4950
# [2026-05-29 11:28:56 | +00:00:03] Original: SA trial 1/1 開始 temp=100, max_iter=300, N_inner=50, move=1-1
# [2026-05-29 11:28:57 | +00:00:04] Original: SA trial 1/1 完了 init=69.0726, final=62.9588, trial_improvement=8.85%, best=62.9588, time=1.13s, BEST更新
# [2026-05-29 11:28:57 | +00:00:04] Original         nodes=100 edges= 375 components=  1 greedy=31.474080196035516 SA=62.95883760638212 used=all nodes
# [2026-05-29 11:28:57 | +00:00:04] [1/10] Original: TSP処理完了
# [2026-05-29 11:28:57 | +00:00:04] --------------------------------------------------
# [2026-05-29 11:28:57 | +00:00:04] [2/10] Random: TSP処理開始
# [2026-05-29 11:28:57 | +00:00:04] Random: Greedy TSP開始
# [2026-05-29 11:28:57 | +00:00:04] Random: 連結成分確認開始
# [2026-05-29 11:28:57 | +00:00:04] Random: 連結グラフ
# [2026-05-29 11:28:57 | +00:00:05] Random: TSP対象ノード数を制限: nodes=99, MAX_TSP_NODES=100
# [2026-05-29 11:28:57 | +00:00:05] Random: TSP用完全グラフ作成開始
# [2026-05-29 11:28:57 | +00:00:05] Random: TSP用完全グラフ作成完了: nodes=99, edges=4851
# [2026-05-29 11:28:57 | +00:00:05] Random: Greedy TSP完了: length=52.6341, time=0.00s
# [2026-05-29 11:28:57 | +00:00:05] Random: SA TSP開始
# [2026-05-29 11:28:57 | +00:00:05] Random: 連結成分確認開始
# [2026-05-29 11:28:57 | +00:00:05] Random: 連結グラフ
# [2026-05-29 11:28:57 | +00:00:05] Random: TSP対象ノード数を制限: nodes=99, MAX_TSP_NODES=100
# [2026-05-29 11:28:57 | +00:00:05] Random: TSP用完全グラフ作成開始
# [2026-05-29 11:28:57 | +00:00:05] Random: TSP用完全グラフ作成完了: nodes=99, edges=4851
# [2026-05-29 11:28:57 | +00:00:05] Random: SA trial 1/1 開始 temp=100, max_iter=300, N_inner=50, move=1-1
# [2026-05-29 11:28:59 | +00:00:06] Random: SA trial 1/1 完了 init=149.1295, final=131.3023, trial_improvement=11.95%, best=131.3023, time=1.41s, BEST更新
# [2026-05-29 11:28:59 | +00:00:06] Random           nodes= 99 edges= 195 components=  1 greedy=52.63409290307374 SA=131.30232334033323 used=all nodes
# [2026-05-29 11:28:59 | +00:00:06] [2/10] Random: TSP処理完了
# [2026-05-29 11:28:59 | +00:00:06] --------------------------------------------------
# [2026-05-29 11:28:59 | +00:00:06] [3/10] Degree: TSP処理開始
# [2026-05-29 11:28:59 | +00:00:06] Degree: Greedy TSP開始
# [2026-05-29 11:28:59 | +00:00:06] Degree: 連結成分確認開始
# [2026-05-29 11:28:59 | +00:00:06] Degree: 非連結。最大連結成分を使用: nodes=180, edges=765
# [2026-05-29 11:28:59 | +00:00:06] Degree: TSP対象ノード数を制限: nodes=98, MAX_TSP_NODES=100
# [2026-05-29 11:28:59 | +00:00:06] Degree: TSP用完全グラフ作成開始
# [2026-05-29 11:28:59 | +00:00:06] Degree: TSP用完全グラフ作成完了: nodes=98, edges=4753
# [2026-05-29 11:28:59 | +00:00:06] Degree: Greedy TSP完了: length=47.7587, time=0.00s
# [2026-05-29 11:28:59 | +00:00:06] Degree: SA TSP開始
# [2026-05-29 11:28:59 | +00:00:06] Degree: 連結成分確認開始
# [2026-05-29 11:28:59 | +00:00:06] Degree: 非連結。最大連結成分を使用: nodes=180, edges=765
# [2026-05-29 11:28:59 | +00:00:06] Degree: TSP対象ノード数を制限: nodes=88, MAX_TSP_NODES=100
# [2026-05-29 11:28:59 | +00:00:06] Degree: TSP用完全グラフ作成開始
# [2026-05-29 11:28:59 | +00:00:06] Degree: TSP用完全グラフ作成完了: nodes=88, edges=3828
# [2026-05-29 11:28:59 | +00:00:06] Degree: SA trial 1/1 開始 temp=100, max_iter=300, N_inner=50, move=1-1
# [2026-05-29 11:29:00 | +00:00:07] Degree: SA trial 1/1 完了 init=79.4422, final=71.6272, trial_improvement=9.84%, best=71.6272, time=1.30s, BEST更新
# [2026-05-29 11:29:00 | +00:00:07] Degree           nodes= 98 edges= 271 components= 21 greedy=47.758665234270524 SA=71.6272164845623 used=largest component
# [2026-05-29 11:29:00 | +00:00:07] [3/10] Degree: TSP処理完了
# [2026-05-29 11:29:00 | +00:00:07] --------------------------------------------------
# [2026-05-29 11:29:00 | +00:00:07] [4/10] PageRank: TSP処理開始
# [2026-05-29 11:29:00 | +00:00:07] PageRank: Greedy TSP開始
# [2026-05-29 11:29:00 | +00:00:07] PageRank: 連結成分確認開始
# [2026-05-29 11:29:00 | +00:00:07] PageRank: 非連結。最大連結成分を使用: nodes=186, edges=765
# [2026-05-29 11:29:00 | +00:00:07] PageRank: TSP対象ノード数を制限: nodes=96, MAX_TSP_NODES=100
# [2026-05-29 11:29:00 | +00:00:07] PageRank: TSP用完全グラフ作成開始
# [2026-05-29 11:29:00 | +00:00:07] PageRank: TSP用完全グラフ作成完了: nodes=96, edges=4560
# [2026-05-29 11:29:00 | +00:00:07] PageRank: Greedy TSP完了: length=56.6062, time=0.00s
# [2026-05-29 11:29:00 | +00:00:07] PageRank: SA TSP開始
# [2026-05-29 11:29:00 | +00:00:07] PageRank: 連結成分確認開始
# [2026-05-29 11:29:00 | +00:00:07] PageRank: 非連結。最大連結成分を使用: nodes=186, edges=765
# [2026-05-29 11:29:00 | +00:00:08] PageRank: TSP対象ノード数を制限: nodes=89, MAX_TSP_NODES=100
# [2026-05-29 11:29:00 | +00:00:08] PageRank: TSP用完全グラフ作成開始
# [2026-05-29 11:29:00 | +00:00:08] PageRank: TSP用完全グラフ作成完了: nodes=89, edges=3916
# [2026-05-29 11:29:00 | +00:00:08] PageRank: SA trial 1/1 開始 temp=100, max_iter=300, N_inner=50, move=1-1
# [2026-05-29 11:29:01 | +00:00:09] PageRank: SA trial 1/1 完了 init=89.7489, final=81.1232, trial_improvement=9.61%, best=81.1232, time=1.14s, BEST更新
# [2026-05-29 11:29:01 | +00:00:09] PageRank         nodes= 96 edges= 225 components= 15 greedy=56.60618838049556 SA=81.12319991761242 used=largest component
# [2026-05-29 11:29:01 | +00:00:09] [4/10] PageRank: TSP処理完了
# [2026-05-29 11:29:01 | +00:00:09] --------------------------------------------------
# [2026-05-29 11:29:01 | +00:00:09] [5/10] Betweenness: TSP処理開始
# [2026-05-29 11:29:01 | +00:00:09] Betweenness: Greedy TSP開始
# [2026-05-29 11:29:01 | +00:00:09] Betweenness: 連結成分確認開始
# [2026-05-29 11:29:01 | +00:00:09] Betweenness: 連結グラフ
# [2026-05-29 11:29:02 | +00:00:09] Betweenness: TSP対象ノード数を制限: nodes=98, MAX_TSP_NODES=100
# [2026-05-29 11:29:02 | +00:00:09] Betweenness: TSP用完全グラフ作成開始
# [2026-05-29 11:29:02 | +00:00:09] Betweenness: TSP用完全グラフ作成完了: nodes=98, edges=4753
# [2026-05-29 11:29:02 | +00:00:09] Betweenness: Greedy TSP完了: length=33.3276, time=0.00s
# [2026-05-29 11:29:02 | +00:00:09] Betweenness: SA TSP開始
# [2026-05-29 11:29:02 | +00:00:09] Betweenness: 連結成分確認開始
# [2026-05-29 11:29:02 | +00:00:09] Betweenness: 連結グラフ
# [2026-05-29 11:29:02 | +00:00:09] Betweenness: TSP対象ノード数を制限: nodes=96, MAX_TSP_NODES=100
# [2026-05-29 11:29:02 | +00:00:09] Betweenness: TSP用完全グラフ作成開始
# [2026-05-29 11:29:02 | +00:00:09] Betweenness: TSP用完全グラフ作成完了: nodes=96, edges=4560
# [2026-05-29 11:29:02 | +00:00:09] Betweenness: SA trial 1/1 開始 temp=100, max_iter=300, N_inner=50, move=1-1
# [2026-05-29 11:29:03 | +00:00:11] Betweenness: SA trial 1/1 完了 init=78.1320, final=70.3380, trial_improvement=9.98%, best=70.3380, time=1.74s, BEST更新
# [2026-05-29 11:29:03 | +00:00:11] Betweenness      nodes= 98 edges= 181 components=  1 greedy=33.32761907217343 SA=70.33803894266764 used=all nodes
# [2026-05-29 11:29:03 | +00:00:11] [5/10] Betweenness: TSP処理完了
# [2026-05-29 11:29:03 | +00:00:11] --------------------------------------------------
# [2026-05-29 11:29:03 | +00:00:11] [6/10] k-core: TSP処理開始
# [2026-05-29 11:29:03 | +00:00:11] k-core: Greedy TSP開始
# [2026-05-29 11:29:03 | +00:00:11] k-core: 連結成分確認開始
# [2026-05-29 11:29:03 | +00:00:11] k-core: 連結グラフ
# [2026-05-29 11:29:03 | +00:00:11] k-core: TSP対象ノード数を制限: nodes=100, MAX_TSP_NODES=100
# [2026-05-29 11:29:03 | +00:00:11] k-core: TSP用完全グラフ作成開始
# [2026-05-29 11:29:03 | +00:00:11] k-core: TSP用完全グラフ作成完了: nodes=100, edges=4950
# [2026-05-29 11:29:04 | +00:00:11] k-core: Greedy TSP完了: length=25.4775, time=0.00s
# [2026-05-29 11:29:04 | +00:00:11] k-core: SA TSP開始
# [2026-05-29 11:29:04 | +00:00:11] k-core: 連結成分確認開始
# [2026-05-29 11:29:04 | +00:00:11] k-core: 連結グラフ
# [2026-05-29 11:29:04 | +00:00:11] k-core: TSP対象ノード数を制限: nodes=100, MAX_TSP_NODES=100
# [2026-05-29 11:29:04 | +00:00:11] k-core: TSP用完全グラフ作成開始
# [2026-05-29 11:29:04 | +00:00:11] k-core: TSP用完全グラフ作成完了: nodes=100, edges=4950
# [2026-05-29 11:29:04 | +00:00:11] k-core: SA trial 1/1 開始 temp=100, max_iter=300, N_inner=50, move=1-1
# [2026-05-29 11:29:06 | +00:00:13] k-core: SA trial 1/1 完了 init=77.3756, final=68.1709, trial_improvement=11.90%, best=68.1709, time=2.20s, BEST更新
# [2026-05-29 11:29:06 | +00:00:13] k-core           nodes=100 edges= 390 components=  1 greedy=25.477493349582332 SA=68.17087138526304 used=all nodes
# [2026-05-29 11:29:06 | +00:00:13] [6/10] k-core: TSP処理完了
# [2026-05-29 11:29:06 | +00:00:13] --------------------------------------------------
# [2026-05-29 11:29:06 | +00:00:13] [7/10] Weight: TSP処理開始
# [2026-05-29 11:29:06 | +00:00:13] Weight: Greedy TSP開始
# [2026-05-29 11:29:06 | +00:00:13] Weight: 連結成分確認開始
# [2026-05-29 11:29:06 | +00:00:13] Weight: 連結グラフ
# [2026-05-29 11:29:06 | +00:00:13] Weight: TSP対象ノード数を制限: nodes=99, MAX_TSP_NODES=100
# [2026-05-29 11:29:06 | +00:00:13] Weight: TSP用完全グラフ作成開始
# [2026-05-29 11:29:06 | +00:00:13] Weight: TSP用完全グラフ作成完了: nodes=99, edges=4851
# [2026-05-29 11:29:06 | +00:00:13] Weight: Greedy TSP完了: length=92.0544, time=0.00s
# [2026-05-29 11:29:06 | +00:00:13] Weight: SA TSP開始
# [2026-05-29 11:29:06 | +00:00:13] Weight: 連結成分確認開始
# [2026-05-29 11:29:06 | +00:00:13] Weight: 連結グラフ
# [2026-05-29 11:29:06 | +00:00:13] Weight: TSP対象ノード数を制限: nodes=98, MAX_TSP_NODES=100
# [2026-05-29 11:29:06 | +00:00:13] Weight: TSP用完全グラフ作成開始
# [2026-05-29 11:29:06 | +00:00:13] Weight: TSP用完全グラフ作成完了: nodes=98, edges=4753
# [2026-05-29 11:29:06 | +00:00:13] Weight: SA trial 1/1 開始 temp=100, max_iter=300, N_inner=50, move=1-1
# [2026-05-29 11:29:07 | +00:00:15] Weight: SA trial 1/1 完了 init=247.7465, final=217.6305, trial_improvement=12.16%, best=217.6305, time=1.52s, BEST更新
# [2026-05-29 11:29:07 | +00:00:15] Weight           nodes= 99 edges= 202 components=  1 greedy=92.05437508159996 SA=217.63052566986036 used=all nodes
# [2026-05-29 11:29:07 | +00:00:15] [7/10] Weight: TSP処理完了
# [2026-05-29 11:29:07 | +00:00:15] --------------------------------------------------
# [2026-05-29 11:29:07 | +00:00:15] [8/10] Local Top-k: TSP処理開始
# [2026-05-29 11:29:07 | +00:00:15] Local Top-k: Greedy TSP開始
# [2026-05-29 11:29:07 | +00:00:15] Local Top-k: 連結成分確認開始
# [2026-05-29 11:29:07 | +00:00:15] Local Top-k: 連結グラフ
# [2026-05-29 11:29:07 | +00:00:15] Local Top-k: TSP対象ノード数を制限: nodes=97, MAX_TSP_NODES=100
# [2026-05-29 11:29:07 | +00:00:15] Local Top-k: TSP用完全グラフ作成開始
# [2026-05-29 11:29:07 | +00:00:15] Local Top-k: TSP用完全グラフ作成完了: nodes=97, edges=4656
# [2026-05-29 11:29:07 | +00:00:15] Local Top-k: Greedy TSP完了: length=110.1735, time=0.00s
# [2026-05-29 11:29:07 | +00:00:15] Local Top-k: SA TSP開始
# [2026-05-29 11:29:07 | +00:00:15] Local Top-k: 連結成分確認開始
# [2026-05-29 11:29:07 | +00:00:15] Local Top-k: 連結グラフ
# [2026-05-29 11:29:07 | +00:00:15] Local Top-k: TSP対象ノード数を制限: nodes=94, MAX_TSP_NODES=100
# [2026-05-29 11:29:07 | +00:00:15] Local Top-k: TSP用完全グラフ作成開始
# [2026-05-29 11:29:08 | +00:00:15] Local Top-k: TSP用完全グラフ作成完了: nodes=94, edges=4371
# [2026-05-29 11:29:08 | +00:00:15] Local Top-k: SA trial 1/1 開始 temp=100, max_iter=300, N_inner=50, move=1-1
# [2026-05-29 11:29:09 | +00:00:16] Local Top-k: SA trial 1/1 完了 init=373.9941, final=328.2796, trial_improvement=12.22%, best=328.2796, time=1.58s, BEST更新
# [2026-05-29 11:29:09 | +00:00:16] Local Top-k      nodes= 97 edges= 130 components=  1 greedy=110.17353501077696 SA=328.27957874412357 used=all nodes
# [2026-05-29 11:29:09 | +00:00:16] [8/10] Local Top-k: TSP処理完了
# [2026-05-29 11:29:09 | +00:00:16] --------------------------------------------------
# [2026-05-29 11:29:09 | +00:00:16] [9/10] Resistance-like: TSP処理開始
# [2026-05-29 11:29:09 | +00:00:16] Resistance-like: Greedy TSP開始
# [2026-05-29 11:29:09 | +00:00:16] Resistance-like: 連結成分確認開始
# [2026-05-29 11:29:09 | +00:00:16] Resistance-like: 非連結。最大連結成分を使用: nodes=199, edges=765
# [2026-05-29 11:29:09 | +00:00:16] Resistance-like: TSP対象ノード数を制限: nodes=100, MAX_TSP_NODES=100
# [2026-05-29 11:29:09 | +00:00:16] Resistance-like: TSP用完全グラフ作成開始
# [2026-05-29 11:29:09 | +00:00:16] Resistance-like: TSP用完全グラフ作成完了: nodes=100, edges=4950
# [2026-05-29 11:29:09 | +00:00:16] Resistance-like: Greedy TSP完了: length=58.3982, time=0.00s
# [2026-05-29 11:29:09 | +00:00:16] Resistance-like: SA TSP開始
# [2026-05-29 11:29:09 | +00:00:16] Resistance-like: 連結成分確認開始
# [2026-05-29 11:29:09 | +00:00:16] Resistance-like: 非連結。最大連結成分を使用: nodes=199, edges=765
# [2026-05-29 11:29:09 | +00:00:16] Resistance-like: TSP対象ノード数を制限: nodes=97, MAX_TSP_NODES=100
# [2026-05-29 11:29:09 | +00:00:16] Resistance-like: TSP用完全グラフ作成開始
# [2026-05-29 11:29:09 | +00:00:16] Resistance-like: TSP用完全グラフ作成完了: nodes=97, edges=4656
# [2026-05-29 11:29:09 | +00:00:16] Resistance-like: SA trial 1/1 開始 temp=100, max_iter=300, N_inner=50, move=1-1
# [2026-05-29 11:29:11 | +00:00:18] Resistance-like: SA trial 1/1 完了 init=132.2015, final=115.0483, trial_improvement=12.98%, best=115.0483, time=1.82s, BEST更新
# [2026-05-29 11:29:11 | +00:00:18] Resistance-like  nodes=100 edges= 202 components=  2 greedy=58.3981588327748 SA=115.04833847599859 used=largest component
# [2026-05-29 11:29:11 | +00:00:18] [9/10] Resistance-like: TSP処理完了
# [2026-05-29 11:29:11 | +00:00:18] --------------------------------------------------
# [2026-05-29 11:29:11 | +00:00:18] [10/10] Spanner-like: TSP処理開始
# [2026-05-29 11:29:11 | +00:00:18] Spanner-like: Greedy TSP開始
# [2026-05-29 11:29:11 | +00:00:18] Spanner-like: 連結成分確認開始
# [2026-05-29 11:29:11 | +00:00:18] Spanner-like: 連結グラフ
# [2026-05-29 11:29:11 | +00:00:18] Spanner-like: TSP対象ノード数を制限: nodes=100, MAX_TSP_NODES=100
# [2026-05-29 11:29:11 | +00:00:18] Spanner-like: TSP用完全グラフ作成開始
# [2026-05-29 11:29:11 | +00:00:18] Spanner-like: TSP用完全グラフ作成完了: nodes=100, edges=4950
# [2026-05-29 11:29:11 | +00:00:18] Spanner-like: Greedy TSP完了: length=28.1690, time=0.00s
# [2026-05-29 11:29:11 | +00:00:18] Spanner-like: SA TSP開始
# [2026-05-29 11:29:11 | +00:00:18] Spanner-like: 連結成分確認開始
# [2026-05-29 11:29:11 | +00:00:18] Spanner-like: 連結グラフ
# [2026-05-29 11:29:11 | +00:00:18] Spanner-like: TSP対象ノード数を制限: nodes=98, MAX_TSP_NODES=100
# [2026-05-29 11:29:11 | +00:00:18] Spanner-like: TSP用完全グラフ作成開始
# [2026-05-29 11:29:11 | +00:00:18] Spanner-like: TSP用完全グラフ作成完了: nodes=98, edges=4753
# [2026-05-29 11:29:11 | +00:00:18] Spanner-like: SA trial 1/1 開始 temp=100, max_iter=300, N_inner=50, move=1-1
# [2026-05-29 11:29:13 | +00:00:20] Spanner-like: SA trial 1/1 完了 init=84.9810, final=76.1257, trial_improvement=10.42%, best=76.1257, time=1.71s, BEST更新
# [2026-05-29 11:29:13 | +00:00:20] Spanner-like     nodes=100 edges= 249 components=  1 greedy=28.169041189191393 SA=76.1256605850372 used=all nodes
# [2026-05-29 11:29:13 | +00:00:20] [10/10] Spanner-like: TSP処理完了
# [2026-05-29 11:29:13 | +00:00:20] ==============================
# [2026-05-29 11:29:13 | +00:00:20] TSP Improvement Summary
# [2026-05-29 11:29:13 | +00:00:20] ==============================
# [2026-05-29 11:29:13 | +00:00:20] Original         edges=1530 edge_ratio=1.00 greedy=31.4741 SA=62.9588 improvement=-100.03%
# [2026-05-29 11:29:13 | +00:00:20] Random           edges= 765 edge_ratio=0.50 greedy=52.6341 SA=131.3023 improvement=-149.46%
# [2026-05-29 11:29:13 | +00:00:20] Degree           edges= 765 edge_ratio=0.50 greedy=47.7587 SA=71.6272 improvement=-49.98%
# [2026-05-29 11:29:13 | +00:00:20] PageRank         edges= 765 edge_ratio=0.50 greedy=56.6062 SA=81.1232 improvement=-43.31%
# [2026-05-29 11:29:13 | +00:00:20] Betweenness      edges= 765 edge_ratio=0.50 greedy=33.3276 SA=70.3380 improvement=-111.05%
# [2026-05-29 11:29:13 | +00:00:20] k-core           edges=1530 edge_ratio=1.00 greedy=25.4775 SA=68.1709 improvement=-167.57%
# [2026-05-29 11:29:13 | +00:00:20] Weight           edges= 765 edge_ratio=0.50 greedy=92.0544 SA=217.6305 improvement=-136.42%
# [2026-05-29 11:29:13 | +00:00:20] Local Top-k      edges= 518 edge_ratio=0.34 greedy=110.1735 SA=328.2796 improvement=-197.97%
# [2026-05-29 11:29:13 | +00:00:20] Resistance-like  edges= 765 edge_ratio=0.50 greedy=58.3982 SA=115.0483 improvement=-97.01%
# [2026-05-29 11:29:13 | +00:00:20] Spanner-like     edges= 935 edge_ratio=0.61 greedy=28.1690 SA=76.1257 improvement=-170.25%
# [2026-05-29 11:29:13 | +00:00:20] TSP経路描画開始
# [2026-05-29 11:29:14 | +00:00:22] TSP経路描画完了
# [2026-05-29 11:29:14 | +00:00:22] TSP計算後サマリープロット開始
# [2026-05-29 11:29:16 | +00:00:23] TSP計算後サマリープロット完了
# [2026-05-29 11:29:16 | +00:00:23] 全処理完了
