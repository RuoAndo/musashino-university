# %%
import networkx as nx
import matplotlib.pyplot as plt
import random
import numpy as np
import time
from datetime import datetime

from networkx.algorithms.approximation import (
    greedy_tsp,
    simulated_annealing_tsp
)

# =========================
# パラメータ
# =========================
NUM_NODES = 100
EDGE_PROB = 0.08
SPARSIFY_RATIO = 0.3
SEED = 42

K_CORE = 2
LOCAL_TOP_K = 2
SPANNER_STRETCH = 2

# TSP対象ノード数を制限
MAX_TSP_NODES = 30

# SA軽量設定
SA_TEMP = 100
SA_MAX_ITERATIONS = 300
SA_N_INNER = 50
SA_TRIALS = 1
SA_MOVE = "1-1"

DRAW_GRAPHS = True
DRAW_TSP = False

random.seed(SEED)
np.random.seed(SEED)

START_TIME = time.time()

# =========================
# ログ関数
# =========================
def now_str():
    return datetime.now().strftime("%Y-%m-%d %H:%M:%S")


def elapsed_str():
    sec = int(time.time() - START_TIME)
    h = sec // 3600
    m = (sec % 3600) // 60
    s = sec % 60
    return f"+{h:02d}:{m:02d}:{s:02d}"


def log(msg):
    print(f"[{now_str()} | {elapsed_str()}] {msg}", flush=True)


# =========================
# 元グラフ生成
# =========================
log("元グラフ生成開始")

G = nx.erdos_renyi_graph(
    n=NUM_NODES,
    p=EDGE_PROB,
    seed=SEED
)

for u, v in G.edges():
    G[u][v]["weight"] = random.random()

log(f"元グラフ生成完了: nodes={G.number_of_nodes()}, edges={G.number_of_edges()}")


# =========================
# 共通関数
# =========================
def make_graph_from_edges(G, selected_edges):
    H = nx.Graph()
    H.add_nodes_from(G.nodes())

    for u, v in selected_edges:
        if G.has_edge(u, v):
            H.add_edge(u, v, **G[u][v])
        else:
            H.add_edge(u, v, weight=1.0)

    return H


def keep_top_edges_by_score(G, edge_scores, ratio):
    edges = list(G.edges())
    num_keep = max(1, int(len(edges) * ratio))

    sorted_edges = sorted(
        edges,
        key=lambda e: edge_scores.get(tuple(sorted(e)), 0),
        reverse=True
    )

    return make_graph_from_edges(G, sorted_edges[:num_keep])


def graph_stats(H):
    avg_degree = sum(dict(H.degree()).values()) / H.number_of_nodes()

    if H.number_of_edges() > 0:
        components = nx.number_connected_components(H)
        largest_cc_size = len(max(nx.connected_components(H), key=len))
    else:
        components = H.number_of_nodes()
        largest_cc_size = 1

    return avg_degree, components, largest_cc_size


def print_graph_info(name, H):
    avg_degree, components, largest_cc_size = graph_stats(H)

    log(
        f"{name}: nodes={H.number_of_nodes()}, "
        f"edges={H.number_of_edges()}, "
        f"avg_degree={avg_degree:.2f}, "
        f"components={components}, "
        f"largest_cc={largest_cc_size}"
    )


# =========================
# 疎化手法
# =========================
def random_sparsification(G, ratio):
    log("Random疎化開始")
    edges = list(G.edges())
    num_keep = max(1, int(len(edges) * ratio))
    sampled_edges = random.sample(edges, num_keep)
    H = make_graph_from_edges(G, sampled_edges)
    log(f"Random疎化完了: edges={H.number_of_edges()}")
    return H


def degree_based_sparsification(G, ratio):
    log("Degree疎化開始")
    deg = dict(G.degree())

    edge_scores = {}
    for u, v in G.edges():
        edge_scores[tuple(sorted((u, v)))] = deg[u] + deg[v]

    H = keep_top_edges_by_score(G, edge_scores, ratio)
    log(f"Degree疎化完了: edges={H.number_of_edges()}")
    return H


def pagerank_based_sparsification(G, ratio):
    log("PageRank疎化開始")
    pr = nx.pagerank(G, weight="weight")

    edge_scores = {}
    for u, v in G.edges():
        edge_scores[tuple(sorted((u, v)))] = pr[u] + pr[v]

    H = keep_top_edges_by_score(G, edge_scores, ratio)
    log(f"PageRank疎化完了: edges={H.number_of_edges()}")
    return H


def edge_betweenness_sparsification(G, ratio):
    log("Betweenness疎化開始")
    eb = nx.edge_betweenness_centrality(G, weight="weight")

    edge_scores = {}
    for e, score in eb.items():
        edge_scores[tuple(sorted(e))] = score

    H = keep_top_edges_by_score(G, edge_scores, ratio)
    log(f"Betweenness疎化完了: edges={H.number_of_edges()}")
    return H


def k_core_sparsification(G, k):
    log(f"k-core疎化開始: k={k}")
    core = nx.k_core(G, k=k)

    H = nx.Graph()
    H.add_nodes_from(G.nodes())

    for u, v in core.edges():
        H.add_edge(u, v, **G[u][v])

    log(f"k-core疎化完了: edges={H.number_of_edges()}")
    return H


def weight_threshold_sparsification(G, ratio):
    log("Weight疎化開始")
    edges = list(G.edges(data=True))
    num_keep = max(1, int(len(edges) * ratio))

    sorted_edges = sorted(
        edges,
        key=lambda x: x[2].get("weight", 0),
        reverse=True
    )

    selected_edges = [(u, v) for u, v, _ in sorted_edges[:num_keep]]
    H = make_graph_from_edges(G, selected_edges)

    log(f"Weight疎化完了: edges={H.number_of_edges()}")
    return H


def local_top_k_sparsification(G, k):
    log(f"Local Top-k疎化開始: k={k}")
    selected_edges = set()

    for node in G.nodes():
        neighbors = list(G.neighbors(node))

        scored_neighbors = []
        for nbr in neighbors:
            score = G[node][nbr].get("weight", 1.0)
            scored_neighbors.append((nbr, score))

        scored_neighbors.sort(key=lambda x: x[1], reverse=True)

        for nbr, _ in scored_neighbors[:k]:
            selected_edges.add(tuple(sorted((node, nbr))))

    H = make_graph_from_edges(G, list(selected_edges))
    log(f"Local Top-k疎化完了: edges={H.number_of_edges()}")
    return H


def effective_resistance_like_sparsification(G, ratio):
    log("Resistance-like疎化開始")
    deg = dict(G.degree())

    edge_scores = {}
    for u, v in G.edges():
        score = 1 / max(1, deg[u]) + 1 / max(1, deg[v])
        edge_scores[tuple(sorted((u, v)))] = score

    H = keep_top_edges_by_score(G, edge_scores, ratio)
    log(f"Resistance-like疎化完了: edges={H.number_of_edges()}")
    return H


def spanner_like_sparsification(G, stretch=2):
    log(f"Spanner-like疎化開始: stretch={stretch}")

    H = nx.Graph()
    H.add_nodes_from(G.nodes())

    edges = list(G.edges(data=True))
    random.shuffle(edges)

    for u, v, data in edges:
        if not nx.has_path(H, u, v):
            H.add_edge(u, v, **data)
        else:
            try:
                dist = nx.shortest_path_length(H, u, v, weight="weight")
                direct_weight = data.get("weight", 1.0)

                if dist > stretch * direct_weight:
                    H.add_edge(u, v, **data)

            except nx.NetworkXNoPath:
                H.add_edge(u, v, **data)

    log(f"Spanner-like疎化完了: edges={H.number_of_edges()}")
    return H


# =========================
# TSP用関数
# =========================
def get_largest_connected_subgraph(H, name):
    log(f"{name}: 連結成分確認開始")

    if H.number_of_edges() == 0:
        log(f"{name}: エッジなし。TSP対象外")
        return None

    if nx.is_connected(H):
        T = H.copy()
        log(f"{name}: 連結グラフ")
    else:
        largest_cc = max(nx.connected_components(H), key=len)
        T = H.subgraph(largest_cc).copy()
        log(
            f"{name}: 非連結。最大連結成分を使用: "
            f"nodes={T.number_of_nodes()}, edges={T.number_of_edges()}"
        )

    if T.number_of_nodes() > MAX_TSP_NODES:
        sampled_nodes = random.sample(list(T.nodes()), MAX_TSP_NODES)
        T = T.subgraph(sampled_nodes).copy()

        if T.number_of_edges() > 0:
            largest_cc = max(nx.connected_components(T), key=len)
            T = T.subgraph(largest_cc).copy()

        log(
            f"{name}: TSP対象ノード数を制限: "
            f"nodes={T.number_of_nodes()}, MAX_TSP_NODES={MAX_TSP_NODES}"
        )

    if T.number_of_nodes() < 3:
        log(f"{name}: TSP対象ノードが少なすぎる")
        return None

    return T


def make_metric_complete_graph(T, name):
    log(f"{name}: TSP用完全グラフ作成開始")

    K = nx.Graph()
    K.add_nodes_from(T.nodes())

    lengths = dict(nx.all_pairs_dijkstra_path_length(T, weight="weight"))
    nodes = list(T.nodes())

    for i, u in enumerate(nodes):
        for v in nodes[i + 1:]:
            K.add_edge(u, v, weight=lengths[u][v])

    log(
        f"{name}: TSP用完全グラフ作成完了: "
        f"nodes={K.number_of_nodes()}, edges={K.number_of_edges()}"
    )

    return K


def compute_cycle_length(K, cycle):
    total = 0.0

    for u, v in zip(cycle[:-1], cycle[1:]):
        total += K[u][v]["weight"]

    return total


def make_random_cycle(K):
    nodes = list(K.nodes())
    random.shuffle(nodes)
    nodes.append(nodes[0])
    return nodes


def solve_tsp_greedy(name, H):
    log(f"{name}: Greedy TSP開始")

    T = get_largest_connected_subgraph(H, name)

    if T is None:
        log(f"{name}: Greedy TSPスキップ")
        return None

    try:
        K = make_metric_complete_graph(T, name)

        t0 = time.time()
        cycle = greedy_tsp(K, weight="weight")
        length = compute_cycle_length(K, cycle)

        log(
            f"{name}: Greedy TSP完了: "
            f"length={length:.4f}, time={time.time() - t0:.2f}s"
        )

        return {
            "name": name,
            "method": "Greedy",
            "nodes": T.number_of_nodes(),
            "edges": T.number_of_edges(),
            "components": nx.number_connected_components(H),
            "used_largest_component": not nx.is_connected(H),
            "tsp_length": length,
            "cycle": cycle,
            "subgraph": T,
            "metric_graph": K
        }

    except Exception as e:
        log(f"[Greedy TSP failed] {name}: {e}")
        return None


def solve_tsp_simulated_annealing(name, H):
    log(f"{name}: SA TSP開始")

    T = get_largest_connected_subgraph(H, name)

    if T is None:
        log(f"{name}: SA TSPスキップ")
        return None

    try:
        K = make_metric_complete_graph(T, name)

        best_cycle = None
        best_length = float("inf")

        for trial in range(1, SA_TRIALS + 1):
            log(
                f"{name}: SA trial {trial}/{SA_TRIALS} 開始 "
                f"temp={SA_TEMP}, max_iter={SA_MAX_ITERATIONS}, "
                f"N_inner={SA_N_INNER}, move={SA_MOVE}"
            )

            init_cycle = make_random_cycle(K)
            init_length = compute_cycle_length(K, init_cycle)

            log(f"{name}: SA trial {trial} 初期解 length={init_length:.4f}")

            t0 = time.time()

            cycle = simulated_annealing_tsp(
                K,
                init_cycle=init_cycle,
                weight="weight",
                source=init_cycle[0],
                temp=SA_TEMP,
                move=SA_MOVE,
                max_iterations=SA_MAX_ITERATIONS,
                N_inner=SA_N_INNER
            )

            length = compute_cycle_length(K, cycle)
            elapsed = time.time() - t0

            if length < best_length:
                best_length = length
                best_cycle = cycle
                updated = "BEST更新"
            else:
                updated = "BEST更新なし"

            log(
                f"{name}: SA trial {trial}/{SA_TRIALS} 完了 "
                f"length={length:.4f}, best={best_length:.4f}, "
                f"time={elapsed:.2f}s, {updated}"
            )

        log(f"{name}: SA TSP完了 best_length={best_length:.4f}")

        return {
            "name": name,
            "method": "SA",
            "nodes": T.number_of_nodes(),
            "edges": T.number_of_edges(),
            "components": nx.number_connected_components(H),
            "used_largest_component": not nx.is_connected(H),
            "tsp_length": best_length,
            "cycle": best_cycle,
            "subgraph": T,
            "metric_graph": K
        }

    except Exception as e:
        log(f"[SA TSP failed] {name}: {e}")
        return None


# =========================
# 疎化実行
# =========================
log("==============================")
log("疎化実行開始")
log("==============================")

graphs = {}

graphs["Original"] = G
print_graph_info("Original", graphs["Original"])

graphs["Random"] = random_sparsification(G, SPARSIFY_RATIO)
print_graph_info("Random", graphs["Random"])

graphs["Degree"] = degree_based_sparsification(G, SPARSIFY_RATIO)
print_graph_info("Degree", graphs["Degree"])

graphs["PageRank"] = pagerank_based_sparsification(G, SPARSIFY_RATIO)
print_graph_info("PageRank", graphs["PageRank"])

graphs["Betweenness"] = edge_betweenness_sparsification(G, SPARSIFY_RATIO)
print_graph_info("Betweenness", graphs["Betweenness"])

graphs["k-core"] = k_core_sparsification(G, K_CORE)
print_graph_info("k-core", graphs["k-core"])

graphs["Weight"] = weight_threshold_sparsification(G, SPARSIFY_RATIO)
print_graph_info("Weight", graphs["Weight"])

graphs["Local Top-k"] = local_top_k_sparsification(G, LOCAL_TOP_K)
print_graph_info("Local Top-k", graphs["Local Top-k"])

graphs["Resistance-like"] = effective_resistance_like_sparsification(G, SPARSIFY_RATIO)
print_graph_info("Resistance-like", graphs["Resistance-like"])

graphs["Spanner-like"] = spanner_like_sparsification(G, SPANNER_STRETCH)
print_graph_info("Spanner-like", graphs["Spanner-like"])

log("疎化実行完了")

# =========================
# TSP実行
# =========================
log("==============================")
log("TSP Results")
log("==============================")

tsp_results = {}

total_graphs = len(graphs)

for idx, (name, H) in enumerate(graphs.items(), start=1):
    log("--------------------------------------------------")
    log(f"[{idx}/{total_graphs}] {name}: TSP処理開始")

    greedy_result = solve_tsp_greedy(name, H)
    sa_result = solve_tsp_simulated_annealing(name, H)

    tsp_results[(name, "Greedy")] = greedy_result
    tsp_results[(name, "SA")] = sa_result

    greedy_len = None if greedy_result is None else greedy_result["tsp_length"]
    sa_len = None if sa_result is None else sa_result["tsp_length"]

    if greedy_len is None and sa_len is None:
        log(f"{name:16s}: TSP failed or too small")
    else:
        base_result = greedy_result if greedy_result is not None else sa_result

        used = (
            "largest component"
            if base_result["used_largest_component"]
            else "all nodes"
        )

        log(
            f"{name:16s} "
            f"nodes={base_result['nodes']:3d} "
            f"edges={base_result['edges']:4d} "
            f"components={base_result['components']:3d} "
            f"greedy={greedy_len if greedy_len is not None else 'NA'} "
            f"SA={sa_len if sa_len is not None else 'NA'} "
            f"used={used}"
        )

    log(f"[{idx}/{total_graphs}] {name}: TSP処理完了")

# =========================
# 改善率表示
# =========================
log("==============================")
log("TSP Improvement Summary")
log("==============================")

for name in graphs.keys():
    greedy_result = tsp_results.get((name, "Greedy"))
    sa_result = tsp_results.get((name, "SA"))

    if greedy_result is None or sa_result is None:
        log(f"{name:16s}: skipped")
        continue

    greedy_len = greedy_result["tsp_length"]
    sa_len = sa_result["tsp_length"]

    improvement = (greedy_len - sa_len) / greedy_len * 100

    log(
        f"{name:16s} "
        f"greedy={greedy_len:.4f} "
        f"SA={sa_len:.4f} "
        f"improvement={improvement:.2f}%"
    )

# =========================
# グラフ描画
# =========================
if DRAW_GRAPHS:
    log("グラフ描画開始")

    pos = nx.spring_layout(G, seed=SEED)

    num_graphs = len(graphs)
    cols = 2
    rows = int(np.ceil(num_graphs / cols))

    fig, axes = plt.subplots(rows, cols, figsize=(14, rows * 5))
    axes = axes.flatten()

    for ax, (name, H) in zip(axes, graphs.items()):
        nx.draw(
            H,
            pos,
            ax=ax,
            node_size=35,
            width=0.6,
            with_labels=False
        )

        ax.set_title(
            f"{name}\n"
            f"Edges: {H.number_of_edges()}"
        )

    for i in range(len(graphs), len(axes)):
        axes[i].axis("off")

    plt.tight_layout()
    plt.show()

    log("グラフ描画完了")

log("全処理完了")
# Out:
# [2026-05-26 09:07:23 | +00:00:00] 元グラフ生成開始
# [2026-05-26 09:07:23 | +00:00:00] 元グラフ生成完了: nodes=100, edges=371
# [2026-05-26 09:07:23 | +00:00:00] ==============================
# [2026-05-26 09:07:23 | +00:00:00] 疎化実行開始
# [2026-05-26 09:07:23 | +00:00:00] ==============================
# [2026-05-26 09:07:23 | +00:00:00] Original: nodes=100, edges=371, avg_degree=7.42, components=1, largest_cc=100
# [2026-05-26 09:07:23 | +00:00:00] Random疎化開始
# [2026-05-26 09:07:23 | +00:00:00] Random疎化完了: edges=111
# [2026-05-26 09:07:23 | +00:00:00] Random: nodes=100, edges=111, avg_degree=2.22, components=8, largest_cc=92
# [2026-05-26 09:07:23 | +00:00:00] Degree疎化開始
# [2026-05-26 09:07:23 | +00:00:00] Degree疎化完了: edges=111
# [2026-05-26 09:07:23 | +00:00:00] Degree: nodes=100, edges=111, avg_degree=2.22, components=45, largest_cc=56
# [2026-05-26 09:07:23 | +00:00:00] PageRank疎化開始
# [2026-05-26 09:07:24 | +00:00:00] PageRank疎化完了: edges=111
# [2026-05-26 09:07:24 | +00:00:00] PageRank: nodes=100, edges=111, avg_degree=2.22, components=41, largest_cc=60
# [2026-05-26 09:07:24 | +00:00:00] Betweenness疎化開始
# [2026-05-26 09:07:24 | +00:00:00] Betweenness疎化完了: edges=111
# [2026-05-26 09:07:24 | +00:00:00] Betweenness: nodes=100, edges=111, avg_degree=2.22, components=9, largest_cc=92
# [2026-05-26 09:07:24 | +00:00:00] k-core疎化開始: k=2
# [2026-05-26 09:07:24 | +00:00:00] k-core疎化完了: edges=370
# [2026-05-26 09:07:24 | +00:00:00] k-core: nodes=100, edges=370, avg_degree=7.40, components=2, largest_cc=99
# [2026-05-26 09:07:24 | +00:00:00] Weight疎化開始
# [2026-05-26 09:07:24 | +00:00:00] Weight疎化完了: edges=111
# [2026-05-26 09:07:24 | +00:00:00] Weight: nodes=100, edges=111, avg_degree=2.22, components=10, largest_cc=88
# [2026-05-26 09:07:24 | +00:00:00] Local Top-k疎化開始: k=2
# [2026-05-26 09:07:24 | +00:00:00] Local Top-k疎化完了: edges=130
# [2026-05-26 09:07:24 | +00:00:00] Local Top-k: nodes=100, edges=130, avg_degree=2.60, components=1, largest_cc=100
# [2026-05-26 09:07:24 | +00:00:00] Resistance-like疎化開始
# [2026-05-26 09:07:24 | +00:00:00] Resistance-like疎化完了: edges=111
# [2026-05-26 09:07:24 | +00:00:00] Resistance-like: nodes=100, edges=111, avg_degree=2.22, components=15, largest_cc=86
# [2026-05-26 09:07:24 | +00:00:00] Spanner-like疎化開始: stretch=2
# [2026-05-26 09:07:24 | +00:00:00] Spanner-like疎化完了: edges=278
# [2026-05-26 09:07:24 | +00:00:00] Spanner-like: nodes=100, edges=278, avg_degree=5.56, components=1, largest_cc=100
# [2026-05-26 09:07:24 | +00:00:00] 疎化実行完了
# [2026-05-26 09:07:24 | +00:00:00] ==============================
# [2026-05-26 09:07:24 | +00:00:00] TSP Results
# [2026-05-26 09:07:24 | +00:00:00] ==============================
# [2026-05-26 09:07:24 | +00:00:00] --------------------------------------------------
# [2026-05-26 09:07:24 | +00:00:00] [1/10] Original: TSP処理開始
# [2026-05-26 09:07:24 | +00:00:00] Original: Greedy TSP開始
# [2026-05-26 09:07:24 | +00:00:00] Original: 連結成分確認開始
# [2026-05-26 09:07:24 | +00:00:00] Original: 連結グラフ
# [2026-05-26 09:07:24 | +00:00:00] Original: TSP対象ノード数を制限: nodes=27, MAX_TSP_NODES=30
# [2026-05-26 09:07:24 | +00:00:00] Original: TSP用完全グラフ作成開始
# [2026-05-26 09:07:24 | +00:00:00] Original: TSP用完全グラフ作成完了: nodes=27, edges=351
# [2026-05-26 09:07:24 | +00:00:00] Original: Greedy TSP完了: length=21.8333, time=0.00s
# [2026-05-26 09:07:24 | +00:00:00] Original: SA TSP開始
# [2026-05-26 09:07:24 | +00:00:00] Original: 連結成分確認開始
# [2026-05-26 09:07:24 | +00:00:00] Original: 連結グラフ
# [2026-05-26 09:07:24 | +00:00:00] Original: TSP対象ノード数を制限: nodes=29, MAX_TSP_NODES=30
# [2026-05-26 09:07:24 | +00:00:00] Original: TSP用完全グラフ作成開始
# [2026-05-26 09:07:24 | +00:00:00] Original: TSP用完全グラフ作成完了: nodes=29, edges=406
# [2026-05-26 09:07:24 | +00:00:00] Original: SA trial 1/1 開始 temp=100, max_iter=300, N_inner=50, move=1-1
# [2026-05-26 09:07:24 | +00:00:00] Original: SA trial 1 初期解 length=36.8685
# [2026-05-26 09:07:24 | +00:00:01] Original: SA trial 1/1 完了 length=28.3760, best=28.3760, time=0.53s, BEST更新
# [2026-05-26 09:07:24 | +00:00:01] Original: SA TSP完了 best_length=28.3760
# [2026-05-26 09:07:24 | +00:00:01] Original         nodes= 27 edges=  37 components=  1 greedy=21.833276965897213 SA=28.3759831530238 used=all nodes
# [2026-05-26 09:07:24 | +00:00:01] [1/10] Original: TSP処理完了
# [2026-05-26 09:07:24 | +00:00:01] --------------------------------------------------
# [2026-05-26 09:07:24 | +00:00:01] [2/10] Random: TSP処理開始
# [2026-05-26 09:07:24 | +00:00:01] Random: Greedy TSP開始
# [2026-05-26 09:07:24 | +00:00:01] Random: 連結成分確認開始
# [2026-05-26 09:07:24 | +00:00:01] Random: 非連結。最大連結成分を使用: nodes=92, edges=110
# [2026-05-26 09:07:24 | +00:00:01] Random: TSP対象ノード数を制限: nodes=10, MAX_TSP_NODES=30
# [2026-05-26 09:07:24 | +00:00:01] Random: TSP用完全グラフ作成開始
# [2026-05-26 09:07:24 | +00:00:01] Random: TSP用完全グラフ作成完了: nodes=10, edges=45
# [2026-05-26 09:07:24 | +00:00:01] Random: Greedy TSP完了: length=7.7141, time=0.00s
# [2026-05-26 09:07:24 | +00:00:01] Random: SA TSP開始
# [2026-05-26 09:07:24 | +00:00:01] Random: 連結成分確認開始
# [2026-05-26 09:07:24 | +00:00:01] Random: 非連結。最大連結成分を使用: nodes=92, edges=110
# [2026-05-26 09:07:24 | +00:00:01] Random: TSP対象ノード数を制限: nodes=4, MAX_TSP_NODES=30
# [2026-05-26 09:07:24 | +00:00:01] Random: TSP用完全グラフ作成開始
# [2026-05-26 09:07:24 | +00:00:01] Random: TSP用完全グラフ作成完了: nodes=4, edges=6
# [2026-05-26 09:07:24 | +00:00:01] Random: SA trial 1/1 開始 temp=100, max_iter=300, N_inner=50, move=1-1
# [2026-05-26 09:07:24 | +00:00:01] Random: SA trial 1 初期解 length=4.3172
# [2026-05-26 09:07:25 | +00:00:01] Random: SA trial 1/1 完了 length=4.3172, best=4.3172, time=0.17s, BEST更新
# [2026-05-26 09:07:25 | +00:00:01] Random: SA TSP完了 best_length=4.3172
# [2026-05-26 09:07:25 | +00:00:01] Random           nodes= 10 edges=   9 components=  8 greedy=7.714139177763904 SA=4.317182328697227 used=largest component
# [2026-05-26 09:07:25 | +00:00:01] [2/10] Random: TSP処理完了
# [2026-05-26 09:07:25 | +00:00:01] --------------------------------------------------
# [2026-05-26 09:07:25 | +00:00:01] [3/10] Degree: TSP処理開始
# [2026-05-26 09:07:25 | +00:00:01] Degree: Greedy TSP開始
# [2026-05-26 09:07:25 | +00:00:01] Degree: 連結成分確認開始
# [2026-05-26 09:07:25 | +00:00:01] Degree: 非連結。最大連結成分を使用: nodes=56, edges=111
# [2026-05-26 09:07:25 | +00:00:01] Degree: TSP対象ノード数を制限: nodes=25, MAX_TSP_NODES=30
# [2026-05-26 09:07:25 | +00:00:01] Degree: TSP用完全グラフ作成開始
# [2026-05-26 09:07:25 | +00:00:01] Degree: TSP用完全グラフ作成完了: nodes=25, edges=300
# [2026-05-26 09:07:25 | +00:00:01] Degree: Greedy TSP完了: length=23.7403, time=0.00s
# [2026-05-26 09:07:25 | +00:00:01] Degree: SA TSP開始
# [2026-05-26 09:07:25 | +00:00:01] Degree: 連結成分確認開始
# [2026-05-26 09:07:25 | +00:00:01] Degree: 非連結。最大連結成分を使用: nodes=56, edges=111
# [2026-05-26 09:07:25 | +00:00:01] Degree: TSP対象ノード数を制限: nodes=25, MAX_TSP_NODES=30
# [2026-05-26 09:07:25 | +00:00:01] Degree: TSP用完全グラフ作成開始
# [2026-05-26 09:07:25 | +00:00:01] Degree: TSP用完全グラフ作成完了: nodes=25, edges=300
# [2026-05-26 09:07:25 | +00:00:01] Degree: SA trial 1/1 開始 temp=100, max_iter=300, N_inner=50, move=1-1
# [2026-05-26 09:07:25 | +00:00:01] Degree: SA trial 1 初期解 length=35.7769
# [2026-05-26 09:07:26 | +00:00:02] Degree: SA trial 1/1 完了 length=23.8498, best=23.8498, time=0.96s, BEST更新
# [2026-05-26 09:07:26 | +00:00:02] Degree: SA TSP完了 best_length=23.8498
# [2026-05-26 09:07:26 | +00:00:02] Degree           nodes= 25 edges=  31 components= 45 greedy=23.740343247959057 SA=23.849791824325944 used=largest component
# [2026-05-26 09:07:26 | +00:00:02] [3/10] Degree: TSP処理完了
# [2026-05-26 09:07:26 | +00:00:02] --------------------------------------------------
# [2026-05-26 09:07:26 | +00:00:02] [4/10] PageRank: TSP処理開始
# [2026-05-26 09:07:26 | +00:00:02] PageRank: Greedy TSP開始
# [2026-05-26 09:07:26 | +00:00:02] PageRank: 連結成分確認開始
# [2026-05-26 09:07:26 | +00:00:02] PageRank: 非連結。最大連結成分を使用: nodes=60, edges=111
# [2026-05-26 09:07:26 | +00:00:02] PageRank: TSP対象ノード数を制限: nodes=16, MAX_TSP_NODES=30
# [2026-05-26 09:07:26 | +00:00:02] PageRank: TSP用完全グラフ作成開始
# [2026-05-26 09:07:26 | +00:00:02] PageRank: TSP用完全グラフ作成完了: nodes=16, edges=120
# [2026-05-26 09:07:26 | +00:00:02] PageRank: Greedy TSP完了: length=15.8990, time=0.00s
# [2026-05-26 09:07:26 | +00:00:02] PageRank: SA TSP開始
# [2026-05-26 09:07:26 | +00:00:02] PageRank: 連結成分確認開始
# [2026-05-26 09:07:26 | +00:00:02] PageRank: 非連結。最大連結成分を使用: nodes=60, edges=111
# [2026-05-26 09:07:26 | +00:00:02] PageRank: TSP対象ノード数を制限: nodes=16, MAX_TSP_NODES=30
# [2026-05-26 09:07:26 | +00:00:02] PageRank: TSP用完全グラフ作成開始
# [2026-05-26 09:07:26 | +00:00:02] PageRank: TSP用完全グラフ作成完了: nodes=16, edges=120
# [2026-05-26 09:07:26 | +00:00:02] PageRank: SA trial 1/1 開始 temp=100, max_iter=300, N_inner=50, move=1-1
# [2026-05-26 09:07:26 | +00:00:02] PageRank: SA trial 1 初期解 length=35.2394
# [2026-05-26 09:07:26 | +00:00:02] PageRank: SA trial 1/1 完了 length=23.1156, best=23.1156, time=0.36s, BEST更新
# [2026-05-26 09:07:26 | +00:00:02] PageRank: SA TSP完了 best_length=23.1156
# [2026-05-26 09:07:26 | +00:00:02] PageRank         nodes= 16 edges=  17 components= 41 greedy=15.89900566039903 SA=23.11562267293118 used=largest component
# [2026-05-26 09:07:26 | +00:00:02] [4/10] PageRank: TSP処理完了
# [2026-05-26 09:07:26 | +00:00:02] --------------------------------------------------
# [2026-05-26 09:07:26 | +00:00:02] [5/10] Betweenness: TSP処理開始
# [2026-05-26 09:07:26 | +00:00:02] Betweenness: Greedy TSP開始
# [2026-05-26 09:07:26 | +00:00:02] Betweenness: 連結成分確認開始
# [2026-05-26 09:07:26 | +00:00:02] Betweenness: 非連結。最大連結成分を使用: nodes=92, edges=111
# [2026-05-26 09:07:26 | +00:00:02] Betweenness: TSP対象ノード数を制限: nodes=7, MAX_TSP_NODES=30
# [2026-05-26 09:07:26 | +00:00:02] Betweenness: TSP用完全グラフ作成開始
# [2026-05-26 09:07:26 | +00:00:02] Betweenness: TSP用完全グラフ作成完了: nodes=7, edges=21
# [2026-05-26 09:07:26 | +00:00:02] Betweenness: Greedy TSP完了: length=2.3186, time=0.00s
# [2026-05-26 09:07:26 | +00:00:02] Betweenness: SA TSP開始
# [2026-05-26 09:07:26 | +00:00:02] Betweenness: 連結成分確認開始
# [2026-05-26 09:07:26 | +00:00:02] Betweenness: 非連結。最大連結成分を使用: nodes=92, edges=111
# [2026-05-26 09:07:26 | +00:00:02] Betweenness: TSP対象ノード数を制限: nodes=7, MAX_TSP_NODES=30
# [2026-05-26 09:07:26 | +00:00:02] Betweenness: TSP用完全グラフ作成開始
# [2026-05-26 09:07:26 | +00:00:02] Betweenness: TSP用完全グラフ作成完了: nodes=7, edges=21
# [2026-05-26 09:07:26 | +00:00:02] Betweenness: SA trial 1/1 開始 temp=100, max_iter=300, N_inner=50, move=1-1
# [2026-05-26 09:07:26 | +00:00:02] Betweenness: SA trial 1 初期解 length=2.1746
# [2026-05-26 09:07:26 | +00:00:02] Betweenness: SA trial 1/1 完了 length=2.1746, best=2.1746, time=0.21s, BEST更新
# [2026-05-26 09:07:26 | +00:00:02] Betweenness: SA TSP完了 best_length=2.1746
# [2026-05-26 09:07:26 | +00:00:03] Betweenness      nodes=  7 edges=   6 components=  9 greedy=2.318581535418884 SA=2.174551200604854 used=largest component
# [2026-05-26 09:07:26 | +00:00:03] [5/10] Betweenness: TSP処理完了
# [2026-05-26 09:07:26 | +00:00:03] --------------------------------------------------
# [2026-05-26 09:07:26 | +00:00:03] [6/10] k-core: TSP処理開始
# [2026-05-26 09:07:26 | +00:00:03] k-core: Greedy TSP開始
# [2026-05-26 09:07:26 | +00:00:03] k-core: 連結成分確認開始
# [2026-05-26 09:07:26 | +00:00:03] k-core: 非連結。最大連結成分を使用: nodes=99, edges=370
# [2026-05-26 09:07:26 | +00:00:03] k-core: TSP対象ノード数を制限: nodes=28, MAX_TSP_NODES=30
# [2026-05-26 09:07:26 | +00:00:03] k-core: TSP用完全グラフ作成開始
# [2026-05-26 09:07:26 | +00:00:03] k-core: TSP用完全グラフ作成完了: nodes=28, edges=378
# [2026-05-26 09:07:26 | +00:00:03] k-core: Greedy TSP完了: length=25.3172, time=0.00s
# [2026-05-26 09:07:26 | +00:00:03] k-core: SA TSP開始
# [2026-05-26 09:07:26 | +00:00:03] k-core: 連結成分確認開始
# [2026-05-26 09:07:26 | +00:00:03] k-core: 非連結。最大連結成分を使用: nodes=99, edges=370
# [2026-05-26 09:07:26 | +00:00:03] k-core: TSP対象ノード数を制限: nodes=23, MAX_TSP_NODES=30
# [2026-05-26 09:07:26 | +00:00:03] k-core: TSP用完全グラフ作成開始
# [2026-05-26 09:07:26 | +00:00:03] k-core: TSP用完全グラフ作成完了: nodes=23, edges=253
# [2026-05-26 09:07:26 | +00:00:03] k-core: SA trial 1/1 開始 temp=100, max_iter=300, N_inner=50, move=1-1
# [2026-05-26 09:07:26 | +00:00:03] k-core: SA trial 1 初期解 length=25.6568
# [2026-05-26 09:07:28 | +00:00:04] k-core: SA trial 1/1 完了 length=20.1209, best=20.1209, time=1.19s, BEST更新
# [2026-05-26 09:07:28 | +00:00:04] k-core: SA TSP完了 best_length=20.1209
# [2026-05-26 09:07:28 | +00:00:04] k-core           nodes= 28 edges=  35 components=  2 greedy=25.31720071072892 SA=20.12093251174746 used=largest component
# [2026-05-26 09:07:28 | +00:00:04] [6/10] k-core: TSP処理完了
# [2026-05-26 09:07:28 | +00:00:04] --------------------------------------------------
# [2026-05-26 09:07:28 | +00:00:04] [7/10] Weight: TSP処理開始
# [2026-05-26 09:07:28 | +00:00:04] Weight: Greedy TSP開始
# [2026-05-26 09:07:28 | +00:00:04] Weight: 連結成分確認開始
# [2026-05-26 09:07:28 | +00:00:04] Weight: 非連結。最大連結成分を使用: nodes=88, edges=108
# [2026-05-26 09:07:28 | +00:00:04] Weight: TSP対象ノード数を制限: nodes=5, MAX_TSP_NODES=30
# [2026-05-26 09:07:28 | +00:00:04] Weight: TSP用完全グラフ作成開始
# [2026-05-26 09:07:28 | +00:00:04] Weight: TSP用完全グラフ作成完了: nodes=5, edges=10
# [2026-05-26 09:07:28 | +00:00:04] Weight: Greedy TSP完了: length=7.1643, time=0.00s
# [2026-05-26 09:07:28 | +00:00:04] Weight: SA TSP開始
# [2026-05-26 09:07:28 | +00:00:04] Weight: 連結成分確認開始
# [2026-05-26 09:07:28 | +00:00:04] Weight: 非連結。最大連結成分を使用: nodes=88, edges=108
# [2026-05-26 09:07:28 | +00:00:04] Weight: TSP対象ノード数を制限: nodes=6, MAX_TSP_NODES=30
# [2026-05-26 09:07:28 | +00:00:04] Weight: TSP用完全グラフ作成開始
# [2026-05-26 09:07:28 | +00:00:04] Weight: TSP用完全グラフ作成完了: nodes=6, edges=15
# [2026-05-26 09:07:28 | +00:00:04] Weight: SA trial 1/1 開始 temp=100, max_iter=300, N_inner=50, move=1-1
# [2026-05-26 09:07:28 | +00:00:04] Weight: SA trial 1 初期解 length=12.3975
# [2026-05-26 09:07:28 | +00:00:04] Weight: SA trial 1/1 完了 length=9.0545, best=9.0545, time=0.18s, BEST更新
# [2026-05-26 09:07:28 | +00:00:04] Weight: SA TSP完了 best_length=9.0545
# [2026-05-26 09:07:28 | +00:00:04] Weight           nodes=  5 edges=   4 components= 10 greedy=7.164261525644024 SA=9.054548579194638 used=largest component
# [2026-05-26 09:07:28 | +00:00:04] [7/10] Weight: TSP処理完了
# [2026-05-26 09:07:28 | +00:00:04] --------------------------------------------------
# [2026-05-26 09:07:28 | +00:00:04] [8/10] Local Top-k: TSP処理開始
# [2026-05-26 09:07:28 | +00:00:04] Local Top-k: Greedy TSP開始
# [2026-05-26 09:07:28 | +00:00:04] Local Top-k: 連結成分確認開始
# [2026-05-26 09:07:28 | +00:00:04] Local Top-k: 連結グラフ
# [2026-05-26 09:07:28 | +00:00:04] Local Top-k: TSP対象ノード数を制限: nodes=4, MAX_TSP_NODES=30
# [2026-05-26 09:07:28 | +00:00:04] Local Top-k: TSP用完全グラフ作成開始
# [2026-05-26 09:07:28 | +00:00:04] Local Top-k: TSP用完全グラフ作成完了: nodes=4, edges=6
# [2026-05-26 09:07:28 | +00:00:04] Local Top-k: Greedy TSP完了: length=5.0691, time=0.00s
# [2026-05-26 09:07:28 | +00:00:04] Local Top-k: SA TSP開始
# [2026-05-26 09:07:28 | +00:00:04] Local Top-k: 連結成分確認開始
# [2026-05-26 09:07:28 | +00:00:04] Local Top-k: 連結グラフ
# [2026-05-26 09:07:28 | +00:00:04] Local Top-k: TSP対象ノード数を制限: nodes=4, MAX_TSP_NODES=30
# [2026-05-26 09:07:28 | +00:00:04] Local Top-k: TSP用完全グラフ作成開始
# [2026-05-26 09:07:28 | +00:00:04] Local Top-k: TSP用完全グラフ作成完了: nodes=4, edges=6
# [2026-05-26 09:07:28 | +00:00:04] Local Top-k: SA trial 1/1 開始 temp=100, max_iter=300, N_inner=50, move=1-1
# [2026-05-26 09:07:28 | +00:00:04] Local Top-k: SA trial 1 初期解 length=3.6636
# [2026-05-26 09:07:28 | +00:00:04] Local Top-k: SA trial 1/1 完了 length=3.6636, best=3.6636, time=0.15s, BEST更新
# [2026-05-26 09:07:28 | +00:00:04] Local Top-k: SA TSP完了 best_length=3.6636
# [2026-05-26 09:07:28 | +00:00:04] Local Top-k      nodes=  4 edges=   3 components=  1 greedy=5.069070207185163 SA=3.663628587221633 used=all nodes
# [2026-05-26 09:07:28 | +00:00:04] [8/10] Local Top-k: TSP処理完了
# [2026-05-26 09:07:28 | +00:00:04] --------------------------------------------------
# [2026-05-26 09:07:28 | +00:00:04] [9/10] Resistance-like: TSP処理開始
# [2026-05-26 09:07:28 | +00:00:04] Resistance-like: Greedy TSP開始
# [2026-05-26 09:07:28 | +00:00:04] Resistance-like: 連結成分確認開始
# [2026-05-26 09:07:28 | +00:00:04] Resistance-like: 非連結。最大連結成分を使用: nodes=86, edges=111
# [2026-05-26 09:07:28 | +00:00:04] Resistance-like: TSP対象ノード数を制限: nodes=3, MAX_TSP_NODES=30
# [2026-05-26 09:07:28 | +00:00:04] Resistance-like: TSP用完全グラフ作成開始
# [2026-05-26 09:07:28 | +00:00:04] Resistance-like: TSP用完全グラフ作成完了: nodes=3, edges=3
# [2026-05-26 09:07:28 | +00:00:04] Resistance-like: Greedy TSP完了: length=3.3151, time=0.00s
# [2026-05-26 09:07:28 | +00:00:04] Resistance-like: SA TSP開始
# [2026-05-26 09:07:28 | +00:00:04] Resistance-like: 連結成分確認開始
# [2026-05-26 09:07:28 | +00:00:04] Resistance-like: 非連結。最大連結成分を使用: nodes=86, edges=111
# [2026-05-26 09:07:28 | +00:00:04] Resistance-like: TSP対象ノード数を制限: nodes=6, MAX_TSP_NODES=30
# [2026-05-26 09:07:28 | +00:00:04] Resistance-like: TSP用完全グラフ作成開始
# [2026-05-26 09:07:28 | +00:00:04] Resistance-like: TSP用完全グラフ作成完了: nodes=6, edges=15
# [2026-05-26 09:07:28 | +00:00:04] Resistance-like: SA trial 1/1 開始 temp=100, max_iter=300, N_inner=50, move=1-1
# [2026-05-26 09:07:28 | +00:00:04] Resistance-like: SA trial 1 初期解 length=3.9215
# [2026-05-26 09:07:28 | +00:00:05] Resistance-like: SA trial 1/1 完了 length=3.3736, best=3.3736, time=0.33s, BEST更新
# [2026-05-26 09:07:28 | +00:00:05] Resistance-like: SA TSP完了 best_length=3.3736
# [2026-05-26 09:07:28 | +00:00:05] Resistance-like  nodes=  3 edges=   2 components= 15 greedy=3.3150595173185353 SA=3.3736049017362175 used=largest component
# [2026-05-26 09:07:28 | +00:00:05] [9/10] Resistance-like: TSP処理完了
# [2026-05-26 09:07:28 | +00:00:05] --------------------------------------------------
# [2026-05-26 09:07:28 | +00:00:05] [10/10] Spanner-like: TSP処理開始
# [2026-05-26 09:07:28 | +00:00:05] Spanner-like: Greedy TSP開始
# [2026-05-26 09:07:28 | +00:00:05] Spanner-like: 連結成分確認開始
# [2026-05-26 09:07:28 | +00:00:05] Spanner-like: 連結グラフ
# [2026-05-26 09:07:28 | +00:00:05] Spanner-like: TSP対象ノード数を制限: nodes=24, MAX_TSP_NODES=30
# [2026-05-26 09:07:28 | +00:00:05] Spanner-like: TSP用完全グラフ作成開始
# [2026-05-26 09:07:28 | +00:00:05] Spanner-like: TSP用完全グラフ作成完了: nodes=24, edges=276
# [2026-05-26 09:07:28 | +00:00:05] Spanner-like: Greedy TSP完了: length=14.7491, time=0.00s
# [2026-05-26 09:07:28 | +00:00:05] Spanner-like: SA TSP開始
# [2026-05-26 09:07:28 | +00:00:05] Spanner-like: 連結成分確認開始
# [2026-05-26 09:07:28 | +00:00:05] Spanner-like: 連結グラフ
# [2026-05-26 09:07:28 | +00:00:05] Spanner-like: TSP対象ノード数を制限: nodes=16, MAX_TSP_NODES=30
# [2026-05-26 09:07:28 | +00:00:05] Spanner-like: TSP用完全グラフ作成開始
# [2026-05-26 09:07:28 | +00:00:05] Spanner-like: TSP用完全グラフ作成完了: nodes=16, edges=120
# [2026-05-26 09:07:28 | +00:00:05] Spanner-like: SA trial 1/1 開始 temp=100, max_iter=300, N_inner=50, move=1-1
# [2026-05-26 09:07:28 | +00:00:05] Spanner-like: SA trial 1 初期解 length=26.2392
# [2026-05-26 09:07:29 | +00:00:05] Spanner-like: SA trial 1/1 完了 length=15.4951, best=15.4951, time=0.45s, BEST更新
# [2026-05-26 09:07:29 | +00:00:05] Spanner-like: SA TSP完了 best_length=15.4951
# [2026-05-26 09:07:29 | +00:00:05] Spanner-like     nodes= 24 edges=  26 components=  1 greedy=14.749069305867142 SA=15.495097813457733 used=all nodes
# [2026-05-26 09:07:29 | +00:00:05] [10/10] Spanner-like: TSP処理完了
# [2026-05-26 09:07:29 | +00:00:05] ==============================
# [2026-05-26 09:07:29 | +00:00:05] TSP Improvement Summary
# [2026-05-26 09:07:29 | +00:00:05] ==============================
# [2026-05-26 09:07:29 | +00:00:05] Original         greedy=21.8333 SA=28.3760 improvement=-29.97%
# [2026-05-26 09:07:29 | +00:00:05] Random           greedy=7.7141 SA=4.3172 improvement=44.04%
# [2026-05-26 09:07:29 | +00:00:05] Degree           greedy=23.7403 SA=23.8498 improvement=-0.46%
# [2026-05-26 09:07:29 | +00:00:05] PageRank         greedy=15.8990 SA=23.1156 improvement=-45.39%
# [2026-05-26 09:07:29 | +00:00:05] Betweenness      greedy=2.3186 SA=2.1746 improvement=6.21%
# [2026-05-26 09:07:29 | +00:00:05] k-core           greedy=25.3172 SA=20.1209 improvement=20.52%
# [2026-05-26 09:07:29 | +00:00:05] Weight           greedy=7.1643 SA=9.0545 improvement=-26.38%
# [2026-05-26 09:07:29 | +00:00:05] Local Top-k      greedy=5.0691 SA=3.6636 improvement=27.73%
# [2026-05-26 09:07:29 | +00:00:05] Resistance-like  greedy=3.3151 SA=3.3736 improvement=-1.77%
# [2026-05-26 09:07:29 | +00:00:05] Spanner-like     greedy=14.7491 SA=15.4951 improvement=-5.06%
# [2026-05-26 09:07:29 | +00:00:05] グラフ描画開始
# [2026-05-26 09:07:31 | +00:00:07] グラフ描画完了
# [2026-05-26 09:07:31 | +00:00:07] 全処理完了
